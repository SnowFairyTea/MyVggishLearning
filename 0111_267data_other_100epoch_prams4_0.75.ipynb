# %%
from mylibs.dataloader_dict import *
from mylibs.trainer import *
import torch
import torch.nn as nn
import os
import torch.utils.data as data
from importlib import import_module
import matplotlib.pyplot as plt
import torch.optim as optim
import copy

vggish_input=import_module(".torchvggish.vggish_input","torchvggish-master_changed")
use_pretrained = True

#GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))
# Out:
# vggish/embedding:0
# vggish/embedding:0
# Using cuda device

# %%
labels=["Car","Siren","other_MusicAnimalSpeech"]
mymodel=trainer(_print=False,_lr=0.01,_labels=labels,
                _classfilter=nn.Sequential(
                            nn.Linear(128,64),
                            nn.Dropout(p=0.75),
                            nn.Sigmoid(),
                            nn.Linear(64,3),
                            nn.Softmax(dim=1)
                            ) ,
                    _update_param_names=["embeddings.4.weight","embeddings.4.bias",'classfilter.0.weight', 'classfilter.0.bias', 
                          'classfilter.2.weight','classfilter.2.bias'])
# Out:
# vggish/embedding:0

# %%
dataloader_dict=get_dataloader_dict(labels,datatype="267_trainMusicAnimalSpeech",num_data=267)
# Out:
# C:\Users\hase\git\MyVggishLearning\mylibs\dataloaders ['C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\100_trainSirens100AnimalCarCivil defense sirenFire engine, fire truck (siren)MusicPolice car (siren)Speech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\100_trainSirens100CarCivil defense sirenFire engine, fire truck (siren)Police car (siren)other_MusicAnimalSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\100_trainSirens100CarCivil defense sirenFire engine, fire truck (siren)Police car (siren)Speechother_MusicAnimal.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1210_emergency100AnimalCarEmergency vehicleMusicSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1214_emergency100AnimalCarEmergency vehicleMusic.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1215_emergency250AnimalBuzzerCarEmergency vehicleMotor vehicle (road)Rail transportWater.jb', 'C:\\Users\\has
# ...

# %%
mymodel.train(dataloader_dict,_print=True,_num_epochs=4000)
#mymodel.loadModel(addname="1_177datas")
# Out:
# Epoch 1/1000
# epoch_loss:1.0870670412253582
# epoch_corrects:1362.0,epochsize:3554
# train Loss: 1.087067 Acc: 0.383230
# epoch_loss:1.0867229169798067
# epoch_corrects:1026.0,epochsize:2810
# valid Loss: 1.086723 Acc: 0.365125
# Epoch 2/1000
# epoch_loss:1.0844845637620402
# epoch_corrects:1414.0,epochsize:3554
# train Loss: 1.084485 Acc: 0.397862
# epoch_loss:1.0836035628335756
# epoch_corrects:1062.0,epochsize:2810
# valid Loss: 1.083604 Acc: 0.377936
# Epoch 3/1000
# epoch_loss:1.0815552506610524
# epoch_corrects:1541.0,epochsize:3554
# train Loss: 1.081555 Acc: 0.433596
# epoch_loss:1.0802642132463829
# epoch_corrects:1328.0,epochsize:2810
# valid Loss: 1.080264 Acc: 0.472598
# Epoch 4/1000
# epoch_loss:1.0791071912312549
# epoch_corrects:1663.0,epochsize:3554
# train Loss: 1.079107 Acc: 0.467923
# epoch_loss:1.0766473715839862
# epoch_corrects:1513.0,epochsize:2810
# valid Loss: 1.076647 Acc: 0.538434
# Epoch 5/1000
# epoch_loss:1.076044242101636
# ...

# %%
mymodel.graph()

mymodel.eval(dataloader_dict)
mymodel.getKondou()
# Out:
# 正解数/入力数:2274/2810
# 正解率:0.809
#                            Car  Siren  other_MusicAnimalSpeech
# Car                      908.0   24.0                    133.0
# Siren                     99.0  499.0                    122.0
# other_MusicAnimalSpeech  135.0   23.0                    867.0

# %%
mymodel.saveModel(addname="267otherMusicAnimalSpeech")
