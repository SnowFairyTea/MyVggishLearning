# %%
from mylibs.dataloader_dict import *
from mylibs.trainer import *
import torch
import torch.nn as nn
import os
import torch.utils.data as data
from importlib import import_module
import matplotlib.pyplot as plt
import torch.optim as optim
import copy

vggish_input=import_module(".torchvggish.vggish_input","torchvggish-master_changed")
use_pretrained = True

#GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))
# Out:
# vggish/embedding:0
# vggish/embedding:0
# Using cuda device

# %%
labels=["Car","Emergency vehicle","Tools","Water","Animal","Rail transport","Glass"]
mymodel=trainer(_print=False,_lr=0.01,_labels=labels,
                _classfilter=nn.Sequential(
                            nn.Linear(128,64),
                            nn.Dropout(p=0.75),
                            nn.Sigmoid(),
                            nn.Linear(64,7),
                            nn.Softmax(dim=1)
                            ) )
# Out:
# vggish/embedding:0

# %%
dataloader_dict=get_dataloader_dict(labels,datatype="1215_emergency",num_data=250)
# Out:
# C:\Users\hase\git\MyVggishLearning\mylibs\dataloaders ['C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\100_trainSirens100AnimalCarCivil defense sirenFire engine, fire truck (siren)MusicPolice car (siren)Speech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\100_trainSirens100CarCivil defense sirenFire engine, fire truck (siren)Police car (siren)other_MusicAnimalSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\100_trainSirens100CarCivil defense sirenFire engine, fire truck (siren)Police car (siren)Speechother_MusicAnimal.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1210_emergency100AnimalCarEmergency vehicleMusicSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1214_emergency100AnimalCarEmergency vehicleMusic.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1215_emergency250AnimalCarEmergency vehicleMusic.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1215_emergency250CarEmergency vehicleother_MusicAnimal.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1215_emergency250CarEmergency vehicleSpeechother_MusicAnimal.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\177_train177AnimalCarMusicSirenSpeechVehicle.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\177_trainMusicAnimalSpeech177CarSirenother_MusicAnimalSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\267_trainMusicAnimalSpeech267CarSirenother_MusicAnimalSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\267_trainMusicAnimalSpeech5AnimalCarMusicSirenSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\267_trainMusicAnimalSpeech5CarSirenother_MusicAnimalSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\evalMusicSilenceSirenSpeechVehicleWind.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\oikomi_train500CarSirenSpeechother_MusicAnimal.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\oikomi_trainMusicAnimalSpeech500CarSirenother_MusicAnimalSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\train177AnimalCarMusicSirenSpeechVehicle.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\train300AnimalCarDogMusicSirenSpeechVehicleWind.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\trainMusic100Speech100.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\trainMusic10Speech10.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\trainMusicSilenceSirenSpeechVehicle.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\trainMusicSilenceSirenSpeechVehicleWind.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\trainMusicSirenSpeechVehicle.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\trainMusicSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\train_print_test177AnimalCarMusicSirenSpeechVehicle.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\train_print_test500AnimalCarMusicSirenSpeechVehicle.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\train_test177AnimalCarMusicSirenSpeechVehicle.jb']
# 新しく作ります
# Car
# train[0]: -jBWkHhQNew.wav
# valid[0]: -0RWZT-miFs.wav
# train[0]: -K4R9SXZZsk.wav
# valid[0]: -7eDqv-6AKQ.wav
# train[0]: -oYYvzarYDs.wav
# valid[0]: -aOxR6ILsw8.wav
# train[0]: -t1zgGxlhPM.wav
# valid[0]: -HWygXWSNRA.wav
# class: Car
# Emergency vehicle
# train[0]: -4RWqM0UCCY.wav
# valid[0]: 02Ak1eIyj3M.wav
# train[0]: -gKNRXbpAKs.wav
# valid[0]: 03Q2SbeP_cw.wav
# train[0]: -Y1qiiugnk8.wav
# valid[0]: 0N0C0Wbe6AI.wav
# train[0]: -z47zN0YyE4.wav
# valid[0]: 0xDlT_u31fg.wav
# class: Emergency vehicle
# Tools
# train[0]: -UNPp3fEWSE.wav
# valid[0]: -bZ4yrpTcjw.wav
# train[0]: 0Ly5mdtHGzE.wav
# valid[0]: 1IlgE0S4t3E.wav
# train[0]: 3C5qHj5WW1E.wav
# valid[0]: 1UFU5SfQOX4.wav
# train[0]: 3Gjt5oUIvyc.wav
# valid[0]: 2pYtX-Stpys.wav
# class: Tools
# Water
# train[0]: -0DdlOuIFUI.wav
# valid[0]: -1EXhfqLLwQ.wav
# train[0]: -5GhUbDLYkQ.wav
# valid[0]: -DSNfC2EJhU.wav
# train[0]: -8_HpHg6nCw.wav
# valid[0]: -Gr9P8Abnlk.wav
# train[0]: -gfBxHm8lhg.wav
# valid[0]: -NRx0SBMjo0.wav
# class: Water
# Animal
# train[0]: -3IYpJfLVJk.wav
# valid[0]: --4gqARaEJE.wav
# train[0]: -By_0iIghuE.wav
# valid[0]: -0jeONf82dE.wav
# train[0]: -efgThyiXWI.wav
# valid[0]: -1EXhfqLLwQ.wav
# train[0]: -fnhkx-XXeI.wav
# valid[0]: -8pCMgGKZY8.wav
# class: Animal
# Rail transport
# train[0]: 0omVgdC33FQ.wav
# valid[0]: -ANxUxvGASw.wav
# train[0]: 0SkccP8H-fQ.wav
# valid[0]: -HAoExLVs6Q.wav
# train[0]: 1kplUdxiw3s.wav
# valid[0]: -kPDH9n0PG4.wav
# train[0]: 1yRMYH8cSFM.wav
# valid[0]: 0g-KosNgMYA.wav
# class: Rail transport
# Glass
# train[0]: 0maiaspDy5k.wav
# valid[0]: 0noFcocWRzw.wav
# train[0]: 1fJNudB6faA.wav
# valid[0]: 10lWpHyN0Ok.wav
# train[0]: 1OJ3grdpoD0.wav
# valid[0]: 25RWrqQol7Y.wav
# train[0]: 2aDcV6zKmF8.wav
# valid[0]: 45iNSkfzOwM.wav
# class: Glass
# train,valid: 1137 , 1018
# 1:GetAudiosetSample/result/eval/Emergency vehicle/0N0C0Wbe6AI.wav:miss!
# train用データの数：569
# valid用データの数：509

# %%
mymodel.train(dataloader_dict,_print=True,_num_epochs=3000)
#mymodel.loadModel(addname="1_177datas")
# Out:
# Epoch 1/3000
# epoch_loss:1.9481495542465832
# epoch_corrects:838.0,epochsize:5683
# train Loss: 1.948150 Acc: 0.147457
# epoch_loss:1.9471442916602946
# epoch_corrects:791.0,epochsize:5083
# valid Loss: 1.947144 Acc: 0.155617
# Epoch 2/3000
# epoch_loss:1.9475306696650976
# epoch_corrects:898.0,epochsize:5683
# train Loss: 1.947531 Acc: 0.158015
# epoch_loss:1.9463570914164365
# epoch_corrects:835.0,epochsize:5083
# valid Loss: 1.946357 Acc: 0.164273
# Epoch 3/3000
# epoch_loss:1.946762745992495
# epoch_corrects:933.0,epochsize:5683
# train Loss: 1.946763 Acc: 0.164174
# epoch_loss:1.9455612784831655
# epoch_corrects:920.0,epochsize:5083
# valid Loss: 1.945561 Acc: 0.180995
# Epoch 4/3000
# epoch_loss:1.9461232661865304
# epoch_corrects:971.0,epochsize:5683
# train Loss: 1.946123 Acc: 0.170860
# epoch_loss:1.944785995110972
# epoch_corrects:1002.0,epochsize:5083
# valid Loss: 1.944786 Acc: 0.197128
# Epoch 5/3000
# epoch_loss:1.945357367267874
# epoch_corrects:1059.0,epochsize:5683
# train Loss: 1.945357 Acc: 0.186345
# epoch_loss:1.944014539874353
# epoch_corrects:1095.0,epochsize:5083
# valid Loss: 1.944015 Acc: 0.215424
# Epoch 6/3000
# epoch_loss:1.9444653441237665
# epoch_corrects:1100.0,epochsize:5683
# train Loss: 1.944465 Acc: 0.193560
# epoch_loss:1.9432648484359312
# epoch_corrects:1170.0,epochsize:5083
# valid Loss: 1.943265 Acc: 0.230179
# Epoch 7/3000
# epoch_loss:1.9440287847072542
# epoch_corrects:1138.0,epochsize:5683
# train Loss: 1.944029 Acc: 0.200246
# epoch_loss:1.9425129711498972
# epoch_corrects:1240.0,epochsize:5083
# valid Loss: 1.942513 Acc: 0.243950
# Epoch 8/3000
# epoch_loss:1.9433321679706161
# epoch_corrects:1191.0,epochsize:5683
# train Loss: 1.943332 Acc: 0.209572
# epoch_loss:1.9417741574242948
# epoch_corrects:1286.0,epochsize:5083
# valid Loss: 1.941774 Acc: 0.253000
# Epoch 9/3000
# epoch_loss:1.9426843503946656
# epoch_corrects:1232.0,epochsize:5683
# train Loss: 1.942684 Acc: 0.216787
# epoch_loss:1.9410442960982293
# epoch_corrects:1330.0,epochsize:5083
# valid Loss: 1.941044 Acc: 0.261657
# Epoch 10/3000
# epoch_loss:1.9420398839988822
# epoch_corrects:1228.0,epochsize:5683
# train Loss: 1.942040 Acc: 0.216083
# epoch_loss:1.9403256008105791
# epoch_corrects:1355.0,epochsize:5083
# valid Loss: 1.940326 Acc: 0.266575
# Epoch 11/3000
# epoch_loss:1.9415016141383346
# epoch_corrects:1322.0,epochsize:5683
# train Loss: 1.941502 Acc: 0.232624
# epoch_loss:1.9396211720582375
# epoch_corrects:1367.0,epochsize:5083
# valid Loss: 1.939621 Acc: 0.268936
# Epoch 12/3000
# epoch_loss:1.9410043492737568
# epoch_corrects:1317.0,epochsize:5683
# train Loss: 1.941004 Acc: 0.231744
# epoch_loss:1.938933163629187
# epoch_corrects:1384.0,epochsize:5083
# valid Loss: 1.938933 Acc: 0.272280
# Epoch 13/3000
# epoch_loss:1.9404191571433171
# epoch_corrects:1387.0,epochsize:5683
# train Loss: 1.940419 Acc: 0.244061
# epoch_loss:1.9382590389899
# epoch_corrects:1398.0,epochsize:5083
# valid Loss: 1.938259 Acc: 0.275034
# Epoch 14/3000
# epoch_loss:1.9398179556646755
# epoch_corrects:1331.0,epochsize:5683
# train Loss: 1.939818 Acc: 0.234207
# epoch_loss:1.93759814498698
# epoch_corrects:1401.0,epochsize:5083
# valid Loss: 1.937598 Acc: 0.275625
# Epoch 15/3000
# epoch_loss:1.939353170433494
# epoch_corrects:1408.0,epochsize:5683
# train Loss: 1.939353 Acc: 0.247756
# epoch_loss:1.936957933549545
# epoch_corrects:1403.0,epochsize:5083
# valid Loss: 1.936958 Acc: 0.276018
# Epoch 16/3000
# epoch_loss:1.938703648456276
# epoch_corrects:1444.0,epochsize:5683
# train Loss: 1.938704 Acc: 0.254091
# epoch_loss:1.9363255423634582
# epoch_corrects:1405.0,epochsize:5083
# valid Loss: 1.936326 Acc: 0.276412
# Epoch 17/3000
# epoch_loss:1.9386054960833496
# epoch_corrects:1389.0,epochsize:5683
# train Loss: 1.938605 Acc: 0.244413
# epoch_loss:1.9357173792987084
# epoch_corrects:1398.0,epochsize:5083
# valid Loss: 1.935717 Acc: 0.275034
# Epoch 18/3000
# epoch_loss:1.938077279490609
# epoch_corrects:1450.0,epochsize:5683
# train Loss: 1.938077 Acc: 0.255147
# epoch_loss:1.935107106161521
# epoch_corrects:1396.0,epochsize:5083
# valid Loss: 1.935107 Acc: 0.274641
# Epoch 19/3000
# epoch_loss:1.9375189286647665
# epoch_corrects:1460.0,epochsize:5683
# train Loss: 1.937519 Acc: 0.256907
# epoch_loss:1.93451457248296
# epoch_corrects:1402.0,epochsize:5083
# valid Loss: 1.934515 Acc: 0.275821
# Epoch 20/3000
# epoch_loss:1.9372501247851714
# epoch_corrects:1498.0,epochsize:5683
# train Loss: 1.937250 Acc: 0.263593
# epoch_loss:1.933936506773622
# epoch_corrects:1394.0,epochsize:5083
# valid Loss: 1.933937 Acc: 0.274247
# Epoch 21/3000
# epoch_loss:1.9367618199785934
# epoch_corrects:1493.0,epochsize:5683
# train Loss: 1.936762 Acc: 0.262713
# epoch_loss:1.9333670075287295
# epoch_corrects:1394.0,epochsize:5083
# valid Loss: 1.933367 Acc: 0.274247
# Epoch 22/3000
# epoch_loss:1.9364871603071154
# epoch_corrects:1480.0,epochsize:5683
# train Loss: 1.936487 Acc: 0.260426
# epoch_loss:1.9328184693952069
# epoch_corrects:1396.0,epochsize:5083
# valid Loss: 1.932818 Acc: 0.274641
# Epoch 23/3000
# epoch_loss:1.936004306278702
# epoch_corrects:1496.0,epochsize:5683
# train Loss: 1.936004 Acc: 0.263241
# epoch_loss:1.9322723934037371
# epoch_corrects:1406.0,epochsize:5083
# valid Loss: 1.932272 Acc: 0.276608
# Epoch 24/3000
# epoch_loss:1.9356968161213592
# epoch_corrects:1528.0,epochsize:5683
# train Loss: 1.935697 Acc: 0.268872
# epoch_loss:1.9317445886104614
# epoch_corrects:1405.0,epochsize:5083
# valid Loss: 1.931745 Acc: 0.276412
# Epoch 25/3000
# epoch_loss:1.934947710987046
# epoch_corrects:1555.0,epochsize:5683
# train Loss: 1.934948 Acc: 0.273623
# epoch_loss:1.931216239225623
# epoch_corrects:1408.0,epochsize:5083
# valid Loss: 1.931216 Acc: 0.277002
# Epoch 26/3000
# epoch_loss:1.935015569370061
# epoch_corrects:1524.0,epochsize:5683
# train Loss: 1.935016 Acc: 0.268168
# epoch_loss:1.9307095801152514
# epoch_corrects:1414.0,epochsize:5083
# valid Loss: 1.930710 Acc: 0.278182
# Epoch 27/3000
# epoch_loss:1.934567445876333
# epoch_corrects:1554.0,epochsize:5683
# train Loss: 1.934567 Acc: 0.273447
# epoch_loss:1.9302014021476657
# epoch_corrects:1424.0,epochsize:5083
# valid Loss: 1.930201 Acc: 0.280150
# Epoch 28/3000
# epoch_loss:1.9342071593237788
# epoch_corrects:1602.0,epochsize:5683
# train Loss: 1.934207 Acc: 0.281893
# epoch_loss:1.9297063305179551
# epoch_corrects:1427.0,epochsize:5083
# valid Loss: 1.929706 Acc: 0.280740
# Epoch 29/3000
# epoch_loss:1.9342856935982382
# epoch_corrects:1543.0,epochsize:5683
# train Loss: 1.934286 Acc: 0.271512
# epoch_loss:1.929229432617659
# epoch_corrects:1447.0,epochsize:5083
# valid Loss: 1.929229 Acc: 0.284674
# Epoch 30/3000
# epoch_loss:1.9338114654516516
# epoch_corrects:1577.0,epochsize:5683
# train Loss: 1.933811 Acc: 0.277494
# epoch_loss:1.9287534466696001
# epoch_corrects:1460.0,epochsize:5083
# valid Loss: 1.928753 Acc: 0.287232
# Epoch 31/3000
# epoch_loss:1.9334121226593157
# epoch_corrects:1557.0,epochsize:5683
# train Loss: 1.933412 Acc: 0.273975
# epoch_loss:1.9282850820014918
# epoch_corrects:1482.0,epochsize:5083
# valid Loss: 1.928285 Acc: 0.291560
# Epoch 32/3000
# epoch_loss:1.93287906945853
# epoch_corrects:1590.0,epochsize:5683
# train Loss: 1.932879 Acc: 0.279782
# epoch_loss:1.9278206779992935
# epoch_corrects:1497.0,epochsize:5083
# valid Loss: 1.927821 Acc: 0.294511
# Epoch 33/3000
# epoch_loss:1.932841603591915
# epoch_corrects:1622.0,epochsize:5683
# train Loss: 1.932842 Acc: 0.285413
# epoch_loss:1.9273623736289784
# epoch_corrects:1509.0,epochsize:5083
# valid Loss: 1.927362 Acc: 0.296872
# Epoch 34/3000
# epoch_loss:1.9325541091514855
# epoch_corrects:1618.0,epochsize:5683
# train Loss: 1.932554 Acc: 0.284709
# epoch_loss:1.9269097260595798
# epoch_corrects:1525.0,epochsize:5083
# valid Loss: 1.926910 Acc: 0.300020
# Epoch 35/3000
# epoch_loss:1.9324152837981856
# epoch_corrects:1653.0,epochsize:5683
# train Loss: 1.932415 Acc: 0.290867
# epoch_loss:1.926471880869253
# epoch_corrects:1537.0,epochsize:5083
# valid Loss: 1.926472 Acc: 0.302380
# Epoch 36/3000
# epoch_loss:1.9319612472677827
# epoch_corrects:1613.0,epochsize:5683
# train Loss: 1.931961 Acc: 0.283829
# epoch_loss:1.9260310458076908
# epoch_corrects:1546.0,epochsize:5083
# valid Loss: 1.926031 Acc: 0.304151
# Epoch 37/3000
# epoch_loss:1.9316079644445339
# epoch_corrects:1651.0,epochsize:5683
# train Loss: 1.931608 Acc: 0.290516
# epoch_loss:1.9255959893126622
# epoch_corrects:1557.0,epochsize:5083
# valid Loss: 1.925596 Acc: 0.306315
# Epoch 38/3000
# epoch_loss:1.931337021384339
# epoch_corrects:1643.0,epochsize:5683
# train Loss: 1.931337 Acc: 0.289108
# epoch_loss:1.9251743138551758
# epoch_corrects:1569.0,epochsize:5083
# valid Loss: 1.925174 Acc: 0.308676
# Epoch 39/3000
# epoch_loss:1.9313687297128654
# epoch_corrects:1677.0,epochsize:5683
# train Loss: 1.931369 Acc: 0.295091
# epoch_loss:1.924757303718786
# epoch_corrects:1579.0,epochsize:5083
# valid Loss: 1.924757 Acc: 0.310643
# Epoch 40/3000
# epoch_loss:1.9309610001285291
# epoch_corrects:1687.0,epochsize:5683
# train Loss: 1.930961 Acc: 0.296850
# epoch_loss:1.9243458587307642
# epoch_corrects:1594.0,epochsize:5083
# valid Loss: 1.924346 Acc: 0.313594
# Epoch 41/3000
# epoch_loss:1.9308064591605627
# epoch_corrects:1675.0,epochsize:5683
# train Loss: 1.930806 Acc: 0.294739
# epoch_loss:1.9239424519620494
# epoch_corrects:1611.0,epochsize:5083
# valid Loss: 1.923942 Acc: 0.316939
# Epoch 42/3000
# epoch_loss:1.9303247602854776
# epoch_corrects:1707.0,epochsize:5683
# train Loss: 1.930325 Acc: 0.300370
# epoch_loss:1.9235372290751045
# epoch_corrects:1622.0,epochsize:5083
# valid Loss: 1.923537 Acc: 0.319103
# Epoch 43/3000
# epoch_loss:1.9301315731258013
# epoch_corrects:1694.0,epochsize:5683
# train Loss: 1.930132 Acc: 0.298082
# epoch_loss:1.9231428373476758
# epoch_corrects:1637.0,epochsize:5083
# valid Loss: 1.923143 Acc: 0.322054
# Epoch 44/3000
# epoch_loss:1.9300948246755
# epoch_corrects:1714.0,epochsize:5683
# train Loss: 1.930095 Acc: 0.301601
# epoch_loss:1.9227543436305954
# epoch_corrects:1655.0,epochsize:5083
# valid Loss: 1.922754 Acc: 0.325595
# Epoch 45/3000
# epoch_loss:1.9300066558236117
# epoch_corrects:1716.0,epochsize:5683
# train Loss: 1.930007 Acc: 0.301953
# epoch_loss:1.9223727368708086
# epoch_corrects:1668.0,epochsize:5083
# valid Loss: 1.922373 Acc: 0.328153
# Epoch 46/3000
# epoch_loss:1.929786540831392
# epoch_corrects:1687.0,epochsize:5683
# train Loss: 1.929787 Acc: 0.296850
# epoch_loss:1.9219982348017493
# epoch_corrects:1698.0,epochsize:5083
# valid Loss: 1.921998 Acc: 0.334055
# Epoch 47/3000
# epoch_loss:1.9296963528052993
# epoch_corrects:1723.0,epochsize:5683
# train Loss: 1.929696 Acc: 0.303185
# epoch_loss:1.9216285958994614
# epoch_corrects:1721.0,epochsize:5083
# valid Loss: 1.921629 Acc: 0.338580
# Epoch 48/3000
# epoch_loss:1.929176577060927
# epoch_corrects:1723.0,epochsize:5683
# train Loss: 1.929177 Acc: 0.303185
# epoch_loss:1.9212559675949896
# epoch_corrects:1735.0,epochsize:5083
# valid Loss: 1.921256 Acc: 0.341334
# Epoch 49/3000
# epoch_loss:1.9292793559415564
# epoch_corrects:1746.0,epochsize:5683
# train Loss: 1.929279 Acc: 0.307232
# epoch_loss:1.9209009772934313
# epoch_corrects:1750.0,epochsize:5083
# valid Loss: 1.920901 Acc: 0.344285
# Epoch 50/3000
# epoch_loss:1.9287889429576042
# epoch_corrects:1767.0,epochsize:5683
# train Loss: 1.928789 Acc: 0.310927
# epoch_loss:1.9205451131969273
# epoch_corrects:1773.0,epochsize:5083
# valid Loss: 1.920545 Acc: 0.348810
# Epoch 51/3000
# epoch_loss:1.9288285277835
# epoch_corrects:1759.0,epochsize:5683
# train Loss: 1.928829 Acc: 0.309520
# epoch_loss:1.92019411102421
# epoch_corrects:1791.0,epochsize:5083
# valid Loss: 1.920194 Acc: 0.352351
# Epoch 52/3000
# epoch_loss:1.9283429721533234
# epoch_corrects:1784.0,epochsize:5683
# train Loss: 1.928343 Acc: 0.313919
# epoch_loss:1.9198442068293224
# epoch_corrects:1810.0,epochsize:5083
# valid Loss: 1.919844 Acc: 0.356089
# Epoch 53/3000
# epoch_loss:1.928613668341421
# epoch_corrects:1763.0,epochsize:5683
# train Loss: 1.928614 Acc: 0.310223
# epoch_loss:1.919500655882147
# epoch_corrects:1822.0,epochsize:5083
# valid Loss: 1.919501 Acc: 0.358450
# Epoch 54/3000
# epoch_loss:1.9279660447558824
# epoch_corrects:1782.0,epochsize:5683
# train Loss: 1.927966 Acc: 0.313567
# epoch_loss:1.919154005399633
# epoch_corrects:1837.0,epochsize:5083
# valid Loss: 1.919154 Acc: 0.361401
# Epoch 55/3000
# epoch_loss:1.9278118775676678
# epoch_corrects:1804.0,epochsize:5683
# train Loss: 1.927812 Acc: 0.317438
# epoch_loss:1.9188124042736505
# epoch_corrects:1858.0,epochsize:5083
# valid Loss: 1.918812 Acc: 0.365532
# Epoch 56/3000
# epoch_loss:1.9280228197794869
# epoch_corrects:1792.0,epochsize:5683
# train Loss: 1.928023 Acc: 0.315326
# epoch_loss:1.9184865159076567
# epoch_corrects:1871.0,epochsize:5083
# valid Loss: 1.918487 Acc: 0.368090
# Epoch 57/3000
# epoch_loss:1.9275686178915563
# epoch_corrects:1822.0,epochsize:5683
# train Loss: 1.927569 Acc: 0.320605
# epoch_loss:1.9181632551179728
# epoch_corrects:1884.0,epochsize:5083
# valid Loss: 1.918163 Acc: 0.370647
# Epoch 58/3000
# epoch_loss:1.9273862658137695
# epoch_corrects:1842.0,epochsize:5683
# train Loss: 1.927386 Acc: 0.324125
# epoch_loss:1.917833381226371
# epoch_corrects:1897.0,epochsize:5083
# valid Loss: 1.917833 Acc: 0.373205
# Epoch 59/3000
# epoch_loss:1.9272714540317784
# epoch_corrects:1827.0,epochsize:5683
# train Loss: 1.927271 Acc: 0.321485
# epoch_loss:1.9175076611558448
# epoch_corrects:1912.0,epochsize:5083
# valid Loss: 1.917508 Acc: 0.376156
# Epoch 60/3000
# epoch_loss:1.9270282667035181
# epoch_corrects:1850.0,epochsize:5683
# train Loss: 1.927028 Acc: 0.325532
# epoch_loss:1.917187462705762
# epoch_corrects:1926.0,epochsize:5083
# valid Loss: 1.917187 Acc: 0.378910
# Epoch 61/3000
# epoch_loss:1.9268065591985315
# epoch_corrects:1842.0,epochsize:5683
# train Loss: 1.926807 Acc: 0.324125
# epoch_loss:1.9168690888637308
# epoch_corrects:1940.0,epochsize:5083
# valid Loss: 1.916869 Acc: 0.381664
# Epoch 62/3000
# epoch_loss:1.9266250545702077
# epoch_corrects:1880.0,epochsize:5683
# train Loss: 1.926625 Acc: 0.330811
# epoch_loss:1.9165546260385702
# epoch_corrects:1948.0,epochsize:5083
# valid Loss: 1.916555 Acc: 0.383238
# Epoch 63/3000
# epoch_loss:1.926464906486432
# epoch_corrects:1879.0,epochsize:5683
# train Loss: 1.926465 Acc: 0.330635
# epoch_loss:1.9162422069620482
# epoch_corrects:1968.0,epochsize:5083
# valid Loss: 1.916242 Acc: 0.387173
# Epoch 64/3000
# epoch_loss:1.9268431153365388
# epoch_corrects:1894.0,epochsize:5683
# train Loss: 1.926843 Acc: 0.333275
# epoch_loss:1.9159449015267833
# epoch_corrects:1981.0,epochsize:5083
# valid Loss: 1.915945 Acc: 0.389730
# Epoch 65/3000
# epoch_loss:1.9264234212551155
# epoch_corrects:1898.0,epochsize:5683
# train Loss: 1.926423 Acc: 0.333979
# epoch_loss:1.9156443613991596
# epoch_corrects:1996.0,epochsize:5083
# valid Loss: 1.915644 Acc: 0.392681
# Epoch 66/3000
# epoch_loss:1.926274590586223
# epoch_corrects:1917.0,epochsize:5683
# train Loss: 1.926275 Acc: 0.337322
# epoch_loss:1.9153474255291092
# epoch_corrects:2012.0,epochsize:5083
# valid Loss: 1.915347 Acc: 0.395829
# Epoch 67/3000
# epoch_loss:1.9258841371821536
# epoch_corrects:1930.0,epochsize:5683
# train Loss: 1.925884 Acc: 0.339609
# epoch_loss:1.9150494819266248
# epoch_corrects:2022.0,epochsize:5083
# valid Loss: 1.915049 Acc: 0.397797
# Epoch 68/3000
# epoch_loss:1.9256675987832672
# epoch_corrects:1910.0,epochsize:5683
# train Loss: 1.925668 Acc: 0.336090
# epoch_loss:1.914755110217201
# epoch_corrects:2043.0,epochsize:5083
# valid Loss: 1.914755 Acc: 0.401928
# Epoch 69/3000
# epoch_loss:1.925732667589196
# epoch_corrects:1907.0,epochsize:5683
# train Loss: 1.925733 Acc: 0.335562
# epoch_loss:1.9144664333956274
# epoch_corrects:2060.0,epochsize:5083
# valid Loss: 1.914466 Acc: 0.405272
# Epoch 70/3000
# epoch_loss:1.9255939447269377
# epoch_corrects:1932.0,epochsize:5683
# train Loss: 1.925594 Acc: 0.339961
# epoch_loss:1.9141777271411091
# epoch_corrects:2072.0,epochsize:5083
# valid Loss: 1.914178 Acc: 0.407633
# Epoch 71/3000
# epoch_loss:1.9256645639073193
# epoch_corrects:1937.0,epochsize:5683
# train Loss: 1.925665 Acc: 0.340841
# epoch_loss:1.9138961922060005
# epoch_corrects:2078.0,epochsize:5083
# valid Loss: 1.913896 Acc: 0.408814
# Epoch 72/3000
# epoch_loss:1.9253732077613508
# epoch_corrects:1974.0,epochsize:5683
# train Loss: 1.925373 Acc: 0.347352
# epoch_loss:1.91361079304185
# epoch_corrects:2089.0,epochsize:5083
# valid Loss: 1.913611 Acc: 0.410978
# Epoch 73/3000
# epoch_loss:1.9250672194145104
# epoch_corrects:1937.0,epochsize:5683
# train Loss: 1.925067 Acc: 0.340841
# epoch_loss:1.9133319700184053
# epoch_corrects:2101.0,epochsize:5083
# valid Loss: 1.913332 Acc: 0.413339
# Epoch 74/3000
# epoch_loss:1.9252040857960804
# epoch_corrects:1944.0,epochsize:5683
# train Loss: 1.925204 Acc: 0.342073
# epoch_loss:1.9130571164321224
# epoch_corrects:2111.0,epochsize:5083
# valid Loss: 1.913057 Acc: 0.415306
# Epoch 75/3000
# epoch_loss:1.9250148904589979
# epoch_corrects:1977.0,epochsize:5683
# train Loss: 1.925015 Acc: 0.347880
# epoch_loss:1.912783666574507
# epoch_corrects:2119.0,epochsize:5083
# valid Loss: 1.912784 Acc: 0.416880
# Epoch 76/3000
# epoch_loss:1.924785989807165
# epoch_corrects:2014.0,epochsize:5683
# train Loss: 1.924786 Acc: 0.354390
# epoch_loss:1.9125095401813073
# epoch_corrects:2130.0,epochsize:5083
# valid Loss: 1.912510 Acc: 0.419044
# Epoch 77/3000
# epoch_loss:1.9246406597967785
# epoch_corrects:2023.0,epochsize:5683
# train Loss: 1.924641 Acc: 0.355974
# epoch_loss:1.9122399622686215
# epoch_corrects:2140.0,epochsize:5083
# valid Loss: 1.912240 Acc: 0.421011
# Epoch 78/3000
# epoch_loss:1.924880848055928
# epoch_corrects:1987.0,epochsize:5683
# train Loss: 1.924881 Acc: 0.349639
# epoch_loss:1.911978408785146
# epoch_corrects:2150.0,epochsize:5083
# valid Loss: 1.911978 Acc: 0.422979
# Epoch 79/3000
# epoch_loss:1.9246284667610305
# epoch_corrects:1977.0,epochsize:5683
# train Loss: 1.924628 Acc: 0.347880
# epoch_loss:1.9117155170056053
# epoch_corrects:2170.0,epochsize:5083
# valid Loss: 1.911716 Acc: 0.426913
# Epoch 80/3000
# epoch_loss:1.9243554163415437
# epoch_corrects:2004.0,epochsize:5683
# train Loss: 1.924355 Acc: 0.352631
# epoch_loss:1.911453239870381
# epoch_corrects:2179.0,epochsize:5083
# valid Loss: 1.911453 Acc: 0.428684
# Epoch 81/3000
# epoch_loss:1.9244130329202225
# epoch_corrects:2012.0,epochsize:5683
# train Loss: 1.924413 Acc: 0.354038
# epoch_loss:1.9111950692055428
# epoch_corrects:2192.0,epochsize:5083
# valid Loss: 1.911195 Acc: 0.431241
# Epoch 82/3000
# epoch_loss:1.9238390193404225
# epoch_corrects:2058.0,epochsize:5683
# train Loss: 1.923839 Acc: 0.362133
# epoch_loss:1.910936942561133
# epoch_corrects:2197.0,epochsize:5083
# valid Loss: 1.910937 Acc: 0.432225
# Epoch 83/3000
# epoch_loss:1.9239206460292924
# epoch_corrects:2033.0,epochsize:5683
# train Loss: 1.923921 Acc: 0.357734
# epoch_loss:1.9106817804123035
# epoch_corrects:2211.0,epochsize:5083
# valid Loss: 1.910682 Acc: 0.434979
# Epoch 84/3000
# epoch_loss:1.923944178190572
# epoch_corrects:2042.0,epochsize:5683
# train Loss: 1.923944 Acc: 0.359317
# epoch_loss:1.9104254425639082
# epoch_corrects:2218.0,epochsize:5083
# valid Loss: 1.910425 Acc: 0.436356
# Epoch 85/3000
# epoch_loss:1.9239177373268226
# epoch_corrects:2015.0,epochsize:5683
# train Loss: 1.923918 Acc: 0.354566
# epoch_loss:1.910175557167493
# epoch_corrects:2220.0,epochsize:5083
# valid Loss: 1.910176 Acc: 0.436750
# Epoch 86/3000
# epoch_loss:1.9235163473147396
# epoch_corrects:2047.0,epochsize:5683
# train Loss: 1.923516 Acc: 0.360197
# epoch_loss:1.909926860322639
# epoch_corrects:2228.0,epochsize:5083
# valid Loss: 1.909927 Acc: 0.438324
# Epoch 87/3000
# epoch_loss:1.9238435802337215
# epoch_corrects:2022.0,epochsize:5683
# train Loss: 1.923844 Acc: 0.355798
# epoch_loss:1.9096843613289296
# epoch_corrects:2236.0,epochsize:5083
# valid Loss: 1.909684 Acc: 0.439898
# Epoch 88/3000
# epoch_loss:1.9237091583033463
# epoch_corrects:2052.0,epochsize:5683
# train Loss: 1.923709 Acc: 0.361077
# epoch_loss:1.9094414387822456
# epoch_corrects:2243.0,epochsize:5083
# valid Loss: 1.909441 Acc: 0.441275
# Epoch 89/3000
# epoch_loss:1.9227685007267847
# epoch_corrects:2131.0,epochsize:5683
# train Loss: 1.922769 Acc: 0.374978
# epoch_loss:1.9091876012097422
# epoch_corrects:2250.0,epochsize:5083
# valid Loss: 1.909188 Acc: 0.442652
# Epoch 90/3000
# epoch_loss:1.9230672171391505
# epoch_corrects:2095.0,epochsize:5683
# train Loss: 1.923067 Acc: 0.368643
# epoch_loss:1.908944545663672
# epoch_corrects:2259.0,epochsize:5083
# valid Loss: 1.908945 Acc: 0.444423
# Epoch 91/3000
# epoch_loss:1.9229347763106832
# epoch_corrects:2095.0,epochsize:5683
# train Loss: 1.922935 Acc: 0.368643
# epoch_loss:1.9087070640606743
# epoch_corrects:2268.0,epochsize:5083
# valid Loss: 1.908707 Acc: 0.446193
# Epoch 92/3000
# epoch_loss:1.9232184577109883
# epoch_corrects:2058.0,epochsize:5683
# train Loss: 1.923218 Acc: 0.362133
# epoch_loss:1.9084759277080707
# epoch_corrects:2280.0,epochsize:5083
# valid Loss: 1.908476 Acc: 0.448554
# Epoch 93/3000
# epoch_loss:1.9230878370109838
# epoch_corrects:2070.0,epochsize:5683
# train Loss: 1.923088 Acc: 0.364244
# epoch_loss:1.908246448137102
# epoch_corrects:2288.0,epochsize:5083
# valid Loss: 1.908246 Acc: 0.450128
# Epoch 94/3000
# epoch_loss:1.9226710827611144
# epoch_corrects:2118.0,epochsize:5683
# train Loss: 1.922671 Acc: 0.372690
# epoch_loss:1.9080147298799357
# epoch_corrects:2292.0,epochsize:5083
# valid Loss: 1.908015 Acc: 0.450915
# Epoch 95/3000
# epoch_loss:1.9225827516771927
# epoch_corrects:2119.0,epochsize:5683
# train Loss: 1.922583 Acc: 0.372866
# epoch_loss:1.907781674428974
# epoch_corrects:2295.0,epochsize:5083
# valid Loss: 1.907782 Acc: 0.451505
# Epoch 96/3000
# epoch_loss:1.9229395364594883
# epoch_corrects:2109.0,epochsize:5683
# train Loss: 1.922940 Acc: 0.371107
# epoch_loss:1.9075582318950446
# epoch_corrects:2303.0,epochsize:5083
# valid Loss: 1.907558 Acc: 0.453079
# Epoch 97/3000
# epoch_loss:1.9223585977282467
# epoch_corrects:2115.0,epochsize:5683
# train Loss: 1.922359 Acc: 0.372163
# epoch_loss:1.9073316379487455
# epoch_corrects:2306.0,epochsize:5083
# valid Loss: 1.907332 Acc: 0.453669
# Epoch 98/3000
# epoch_loss:1.9225144022139953
# epoch_corrects:2138.0,epochsize:5683
# train Loss: 1.922514 Acc: 0.376210
# epoch_loss:1.907107083154386
# epoch_corrects:2312.0,epochsize:5083
# valid Loss: 1.907107 Acc: 0.454849
# Epoch 99/3000
# epoch_loss:1.922352371638706
# epoch_corrects:2132.0,epochsize:5683
# train Loss: 1.922352 Acc: 0.375154
# epoch_loss:1.9068839216992162
# epoch_corrects:2315.0,epochsize:5083
# valid Loss: 1.906884 Acc: 0.455440
# Epoch 100/3000
# epoch_loss:1.922408512354778
# epoch_corrects:2178.0,epochsize:5683
# train Loss: 1.922409 Acc: 0.383248
# epoch_loss:1.906665089935762
# epoch_corrects:2323.0,epochsize:5083
# valid Loss: 1.906665 Acc: 0.457014
# Epoch 101/3000
# epoch_loss:1.9223638109268908
# epoch_corrects:2108.0,epochsize:5683
# train Loss: 1.922364 Acc: 0.370931
# epoch_loss:1.9064431710902712
# epoch_corrects:2329.0,epochsize:5083
# valid Loss: 1.906443 Acc: 0.458194
# Epoch 102/3000
# epoch_loss:1.9221035331859988
# epoch_corrects:2146.0,epochsize:5683
# train Loss: 1.922104 Acc: 0.377617
# epoch_loss:1.9062242357134702
# epoch_corrects:2335.0,epochsize:5083
# valid Loss: 1.906224 Acc: 0.459374
# Epoch 103/3000
# epoch_loss:1.9219572706246029
# epoch_corrects:2162.0,epochsize:5683
# train Loss: 1.921957 Acc: 0.380433
# epoch_loss:1.9060100842338366
# epoch_corrects:2339.0,epochsize:5083
# valid Loss: 1.906010 Acc: 0.460161
# Epoch 104/3000
# epoch_loss:1.921870342195401
# epoch_corrects:2148.0,epochsize:5683
# train Loss: 1.921870 Acc: 0.377969
# epoch_loss:1.9057970329600245
# epoch_corrects:2347.0,epochsize:5083
# valid Loss: 1.905797 Acc: 0.461735
# Epoch 105/3000
# epoch_loss:1.9218202402279996
# epoch_corrects:2187.0,epochsize:5683
# train Loss: 1.921820 Acc: 0.384832
# epoch_loss:1.9055820905198362
# epoch_corrects:2352.0,epochsize:5083
# valid Loss: 1.905582 Acc: 0.462719
# Epoch 106/3000
# epoch_loss:1.9220852590081308
# epoch_corrects:2159.0,epochsize:5683
# train Loss: 1.922085 Acc: 0.379905
# epoch_loss:1.9053707661742234
# epoch_corrects:2356.0,epochsize:5083
# valid Loss: 1.905371 Acc: 0.463506
# Epoch 107/3000
# epoch_loss:1.9217451399697945
# epoch_corrects:2163.0,epochsize:5683
# train Loss: 1.921745 Acc: 0.380609
# epoch_loss:1.9051618300013342
# epoch_corrects:2362.0,epochsize:5083
# valid Loss: 1.905162 Acc: 0.464686
# Epoch 108/3000
# epoch_loss:1.9217392056420008
# epoch_corrects:2180.0,epochsize:5683
# train Loss: 1.921739 Acc: 0.383600
# epoch_loss:1.9049523093675549
# epoch_corrects:2369.0,epochsize:5083
# valid Loss: 1.904952 Acc: 0.466063
# Epoch 109/3000
# epoch_loss:1.921763839340747
# epoch_corrects:2217.0,epochsize:5683
# train Loss: 1.921764 Acc: 0.390111
# epoch_loss:1.9047544507935317
# epoch_corrects:2377.0,epochsize:5083
# valid Loss: 1.904754 Acc: 0.467637
# Epoch 110/3000
# epoch_loss:1.9216379046796725
# epoch_corrects:2151.0,epochsize:5683
# train Loss: 1.921638 Acc: 0.378497
# epoch_loss:1.904550894189017
# epoch_corrects:2387.0,epochsize:5083
# valid Loss: 1.904551 Acc: 0.469605
# Epoch 111/3000
# epoch_loss:1.9216237711524662
# epoch_corrects:2168.0,epochsize:5683
# train Loss: 1.921624 Acc: 0.381489
# epoch_loss:1.904352542290696
# epoch_corrects:2400.0,epochsize:5083
# valid Loss: 1.904353 Acc: 0.472162
# Epoch 112/3000
# epoch_loss:1.921180412695061
# epoch_corrects:2217.0,epochsize:5683
# train Loss: 1.921180 Acc: 0.390111
# epoch_loss:1.9041485555664939
# epoch_corrects:2406.0,epochsize:5083
# valid Loss: 1.904149 Acc: 0.473343
# Epoch 113/3000
# epoch_loss:1.9212229485329704
# epoch_corrects:2247.0,epochsize:5683
# train Loss: 1.921223 Acc: 0.395390
# epoch_loss:1.9039442577208212
# epoch_corrects:2414.0,epochsize:5083
# valid Loss: 1.903944 Acc: 0.474916
# Epoch 114/3000
# epoch_loss:1.9212596339070207
# epoch_corrects:2174.0,epochsize:5683
# train Loss: 1.921260 Acc: 0.382544
# epoch_loss:1.9037524063756517
# epoch_corrects:2421.0,epochsize:5083
# valid Loss: 1.903752 Acc: 0.476294
# Epoch 115/3000
# epoch_loss:1.9210770194765003
# epoch_corrects:2194.0,epochsize:5683
# train Loss: 1.921077 Acc: 0.386064
# epoch_loss:1.9035567988473179
# epoch_corrects:2423.0,epochsize:5083
# valid Loss: 1.903557 Acc: 0.476687
# Epoch 116/3000
# epoch_loss:1.9211780426264355
# epoch_corrects:2198.0,epochsize:5683
# train Loss: 1.921178 Acc: 0.386768
# epoch_loss:1.9033633065509814
# epoch_corrects:2431.0,epochsize:5083
# valid Loss: 1.903363 Acc: 0.478261
# Epoch 117/3000
# epoch_loss:1.9211061903441558
# epoch_corrects:2222.0,epochsize:5683
# train Loss: 1.921106 Acc: 0.390991
# epoch_loss:1.90317017378217
# epoch_corrects:2436.0,epochsize:5083
# valid Loss: 1.903170 Acc: 0.479245
# Epoch 118/3000
# epoch_loss:1.9208439171114964
# epoch_corrects:2267.0,epochsize:5683
# train Loss: 1.920844 Acc: 0.398909
# epoch_loss:1.9029769291681684
# epoch_corrects:2438.0,epochsize:5083
# valid Loss: 1.902977 Acc: 0.479638
# Epoch 119/3000
# epoch_loss:1.9208698353884024
# epoch_corrects:2224.0,epochsize:5683
# train Loss: 1.920870 Acc: 0.391343
# epoch_loss:1.9027855769869804
# epoch_corrects:2441.0,epochsize:5083
# valid Loss: 1.902786 Acc: 0.480228
# Epoch 120/3000
# epoch_loss:1.9208072431905996
# epoch_corrects:2270.0,epochsize:5683
# train Loss: 1.920807 Acc: 0.399437
# epoch_loss:1.902598886468292
# epoch_corrects:2448.0,epochsize:5083
# valid Loss: 1.902599 Acc: 0.481605
# Epoch 121/3000
# epoch_loss:1.9207422667230998
# epoch_corrects:2272.0,epochsize:5683
# train Loss: 1.920742 Acc: 0.399789
# epoch_loss:1.9024076536840138
# epoch_corrects:2454.0,epochsize:5083
# valid Loss: 1.902408 Acc: 0.482786
# Epoch 122/3000
# epoch_loss:1.9208920455704728
# epoch_corrects:2239.0,epochsize:5683
# train Loss: 1.920892 Acc: 0.393982
# epoch_loss:1.902218860199009
# epoch_corrects:2454.0,epochsize:5083
# valid Loss: 1.902219 Acc: 0.482786
# Epoch 123/3000
# epoch_loss:1.9207294477494317
# epoch_corrects:2230.0,epochsize:5683
# train Loss: 1.920729 Acc: 0.392398
# epoch_loss:1.9020329556220303
# epoch_corrects:2458.0,epochsize:5083
# valid Loss: 1.902033 Acc: 0.483573
# Epoch 124/3000
# epoch_loss:1.9207186655072748
# epoch_corrects:2247.0,epochsize:5683
# train Loss: 1.920719 Acc: 0.395390
# epoch_loss:1.9018483045836168
# epoch_corrects:2465.0,epochsize:5083
# valid Loss: 1.901848 Acc: 0.484950
# Epoch 125/3000
# epoch_loss:1.9202689813850171
# epoch_corrects:2289.0,epochsize:5683
# train Loss: 1.920269 Acc: 0.402780
# epoch_loss:1.9016632382944298
# epoch_corrects:2471.0,epochsize:5083
# valid Loss: 1.901663 Acc: 0.486130
# Epoch 126/3000
# epoch_loss:1.9203322509550491
# epoch_corrects:2225.0,epochsize:5683
# train Loss: 1.920332 Acc: 0.391519
# epoch_loss:1.9014792569669101
# epoch_corrects:2475.0,epochsize:5083
# valid Loss: 1.901479 Acc: 0.486917
# Epoch 127/3000
# epoch_loss:1.9205302232045556
# epoch_corrects:2243.0,epochsize:5683
# train Loss: 1.920530 Acc: 0.394686
# epoch_loss:1.9012979810312463
# epoch_corrects:2479.0,epochsize:5083
# valid Loss: 1.901298 Acc: 0.487704
# Epoch 128/3000
# epoch_loss:1.9201239463038247
# epoch_corrects:2283.0,epochsize:5683
# train Loss: 1.920124 Acc: 0.401724
# epoch_loss:1.9011124641717523
# epoch_corrects:2485.0,epochsize:5083
# valid Loss: 1.901112 Acc: 0.488885
# Epoch 129/3000
# epoch_loss:1.9202274760162874
# epoch_corrects:2272.0,epochsize:5683
# train Loss: 1.920227 Acc: 0.399789
# epoch_loss:1.9009334789400327
# epoch_corrects:2494.0,epochsize:5083
# valid Loss: 1.900933 Acc: 0.490655
# Epoch 130/3000
# epoch_loss:1.9202514968454554
# epoch_corrects:2230.0,epochsize:5683
# train Loss: 1.920251 Acc: 0.392398
# epoch_loss:1.9007570837605499
# epoch_corrects:2497.0,epochsize:5083
# valid Loss: 1.900757 Acc: 0.491245
# Epoch 131/3000
# epoch_loss:1.920282143240094
# epoch_corrects:2289.0,epochsize:5683
# train Loss: 1.920282 Acc: 0.402780
# epoch_loss:1.9005791339587208
# epoch_corrects:2499.0,epochsize:5083
# valid Loss: 1.900579 Acc: 0.491639
# Epoch 132/3000
# epoch_loss:1.9198902781614215
# epoch_corrects:2313.0,epochsize:5683
# train Loss: 1.919890 Acc: 0.407003
# epoch_loss:1.900400443994551
# epoch_corrects:2501.0,epochsize:5083
# valid Loss: 1.900400 Acc: 0.492032
# Epoch 133/3000
# epoch_loss:1.9199563748983772
# epoch_corrects:2312.0,epochsize:5683
# train Loss: 1.919956 Acc: 0.406827
# epoch_loss:1.9002255695015808
# epoch_corrects:2506.0,epochsize:5083
# valid Loss: 1.900226 Acc: 0.493016
# Epoch 134/3000
# epoch_loss:1.9201224991999608
# epoch_corrects:2248.0,epochsize:5683
# train Loss: 1.920122 Acc: 0.395566
# epoch_loss:1.9000507357222298
# epoch_corrects:2510.0,epochsize:5083
# valid Loss: 1.900051 Acc: 0.493803
# Epoch 135/3000
# epoch_loss:1.919764862647049
# epoch_corrects:2306.0,epochsize:5683
# train Loss: 1.919765 Acc: 0.405772
# epoch_loss:1.8998805614242913
# epoch_corrects:2518.0,epochsize:5083
# valid Loss: 1.899881 Acc: 0.495377
# Epoch 136/3000
# epoch_loss:1.9199168859769105
# epoch_corrects:2307.0,epochsize:5683
# train Loss: 1.919917 Acc: 0.405948
# epoch_loss:1.8997082229723452
# epoch_corrects:2519.0,epochsize:5083
# valid Loss: 1.899708 Acc: 0.495573
# Epoch 137/3000
# epoch_loss:1.9198127923749313
# epoch_corrects:2305.0,epochsize:5683
# train Loss: 1.919813 Acc: 0.405596
# epoch_loss:1.8995396518904277
# epoch_corrects:2523.0,epochsize:5083
# valid Loss: 1.899540 Acc: 0.496360
# Epoch 138/3000
# epoch_loss:1.919638797176696
# epoch_corrects:2293.0,epochsize:5683
# train Loss: 1.919639 Acc: 0.403484
# epoch_loss:1.8993709776407617
# epoch_corrects:2526.0,epochsize:5083
# valid Loss: 1.899371 Acc: 0.496951
# Epoch 139/3000
# epoch_loss:1.919394490774639
# epoch_corrects:2318.0,epochsize:5683
# train Loss: 1.919394 Acc: 0.407883
# epoch_loss:1.8991970565406773
# epoch_corrects:2532.0,epochsize:5083
# valid Loss: 1.899197 Acc: 0.498131
# Epoch 140/3000
# epoch_loss:1.919897927525554
# epoch_corrects:2310.0,epochsize:5683
# train Loss: 1.919898 Acc: 0.406475
# epoch_loss:1.8990301266679046
# epoch_corrects:2540.0,epochsize:5083
# valid Loss: 1.899030 Acc: 0.499705
# Epoch 141/3000
# epoch_loss:1.9194453706754757
# epoch_corrects:2322.0,epochsize:5683
# train Loss: 1.919445 Acc: 0.408587
# epoch_loss:1.8988631106773841
# epoch_corrects:2545.0,epochsize:5083
# valid Loss: 1.898863 Acc: 0.500689
# Epoch 142/3000
# epoch_loss:1.919321981341449
# epoch_corrects:2317.0,epochsize:5683
# train Loss: 1.919322 Acc: 0.407707
# epoch_loss:1.8986966280212043
# epoch_corrects:2549.0,epochsize:5083
# valid Loss: 1.898697 Acc: 0.501476
# Epoch 143/3000
# epoch_loss:1.9192627306326833
# epoch_corrects:2333.0,epochsize:5683
# train Loss: 1.919263 Acc: 0.410523
# epoch_loss:1.8985299152017414
# epoch_corrects:2552.0,epochsize:5083
# valid Loss: 1.898530 Acc: 0.502066
# Epoch 144/3000
# epoch_loss:1.919580891898835
# epoch_corrects:2311.0,epochsize:5683
# train Loss: 1.919581 Acc: 0.406651
# epoch_loss:1.8983709477731006
# epoch_corrects:2554.0,epochsize:5083
# valid Loss: 1.898371 Acc: 0.502459
# Epoch 145/3000
# epoch_loss:1.9190846377436006
# epoch_corrects:2341.0,epochsize:5683
# train Loss: 1.919085 Acc: 0.411930
# epoch_loss:1.8982069331221099
# epoch_corrects:2555.0,epochsize:5083
# valid Loss: 1.898207 Acc: 0.502656
# Epoch 146/3000
# epoch_loss:1.9192961258471233
# epoch_corrects:2327.0,epochsize:5683
# train Loss: 1.919296 Acc: 0.409467
# epoch_loss:1.898044819018514
# epoch_corrects:2557.0,epochsize:5083
# valid Loss: 1.898045 Acc: 0.503049
# Epoch 147/3000
# epoch_loss:1.9190320392404248
# epoch_corrects:2339.0,epochsize:5683
# train Loss: 1.919032 Acc: 0.411578
# epoch_loss:1.8978869596522976
# epoch_corrects:2559.0,epochsize:5083
# valid Loss: 1.897887 Acc: 0.503443
# Epoch 148/3000
# epoch_loss:1.918850533374489
# epoch_corrects:2393.0,epochsize:5683
# train Loss: 1.918851 Acc: 0.421080
# epoch_loss:1.8977247047865224
# epoch_corrects:2559.0,epochsize:5083
# valid Loss: 1.897725 Acc: 0.503443
# Epoch 149/3000
# epoch_loss:1.9190971091371303
# epoch_corrects:2351.0,epochsize:5683
# train Loss: 1.919097 Acc: 0.413690
# epoch_loss:1.8975659287541067
# epoch_corrects:2562.0,epochsize:5083
# valid Loss: 1.897566 Acc: 0.504033
# Epoch 150/3000
# epoch_loss:1.91935271185174
# epoch_corrects:2339.0,epochsize:5683
# train Loss: 1.919353 Acc: 0.411578
# epoch_loss:1.8974094343260473
# epoch_corrects:2570.0,epochsize:5083
# valid Loss: 1.897409 Acc: 0.505607
# Epoch 151/3000
# epoch_loss:1.9192105630911216
# epoch_corrects:2332.0,epochsize:5683
# train Loss: 1.919211 Acc: 0.410347
# epoch_loss:1.8972521389701014
# epoch_corrects:2572.0,epochsize:5083
# valid Loss: 1.897252 Acc: 0.506000
# Epoch 152/3000
# epoch_loss:1.918735177106218
# epoch_corrects:2354.0,epochsize:5683
# train Loss: 1.918735 Acc: 0.414218
# epoch_loss:1.897092617545427
# epoch_corrects:2573.0,epochsize:5083
# valid Loss: 1.897093 Acc: 0.506197
# Epoch 153/3000
# epoch_loss:1.9188756787103602
# epoch_corrects:2352.0,epochsize:5683
# train Loss: 1.918876 Acc: 0.413866
# epoch_loss:1.8969392262409457
# epoch_corrects:2575.0,epochsize:5083
# valid Loss: 1.896939 Acc: 0.506591
# Epoch 154/3000
# epoch_loss:1.9185652986874195
# epoch_corrects:2383.0,epochsize:5683
# train Loss: 1.918565 Acc: 0.419321
# epoch_loss:1.8967788399098404
# epoch_corrects:2581.0,epochsize:5083
# valid Loss: 1.896779 Acc: 0.507771
# Epoch 155/3000
# epoch_loss:1.9186626023313182
# epoch_corrects:2384.0,epochsize:5683
# train Loss: 1.918663 Acc: 0.419497
# epoch_loss:1.896623724303845
# epoch_corrects:2584.0,epochsize:5083
# valid Loss: 1.896624 Acc: 0.508361
# Epoch 156/3000
# epoch_loss:1.9187837891567767
# epoch_corrects:2374.0,epochsize:5683
# train Loss: 1.918784 Acc: 0.417737
# epoch_loss:1.8964695958389486
# epoch_corrects:2585.0,epochsize:5083
# valid Loss: 1.896470 Acc: 0.508558
# Epoch 157/3000
# epoch_loss:1.9187018827886075
# epoch_corrects:2314.0,epochsize:5683
# train Loss: 1.918702 Acc: 0.407179
# epoch_loss:1.8963182418805606
# epoch_corrects:2586.0,epochsize:5083
# valid Loss: 1.896318 Acc: 0.508755
# Epoch 158/3000
# epoch_loss:1.9187516955743682
# epoch_corrects:2374.0,epochsize:5683
# train Loss: 1.918752 Acc: 0.417737
# epoch_loss:1.896166444809775
# epoch_corrects:2591.0,epochsize:5083
# valid Loss: 1.896166 Acc: 0.509738
# Epoch 159/3000
# epoch_loss:1.9188556969637773
# epoch_corrects:2356.0,epochsize:5683
# train Loss: 1.918856 Acc: 0.414570
# epoch_loss:1.89601421658739
# epoch_corrects:2596.0,epochsize:5083
# valid Loss: 1.896014 Acc: 0.510722
# Epoch 160/3000
# epoch_loss:1.9189360334318162
# epoch_corrects:2328.0,epochsize:5683
# train Loss: 1.918936 Acc: 0.409643
# epoch_loss:1.8958694472126245
# epoch_corrects:2598.0,epochsize:5083
# valid Loss: 1.895869 Acc: 0.511115
# Epoch 161/3000
# epoch_loss:1.9185379622332042
# epoch_corrects:2379.0,epochsize:5683
# train Loss: 1.918538 Acc: 0.418617
# epoch_loss:1.8957202330175966
# epoch_corrects:2600.0,epochsize:5083
# valid Loss: 1.895720 Acc: 0.511509
# Epoch 162/3000
# epoch_loss:1.9183856518613018
# epoch_corrects:2392.0,epochsize:5683
# train Loss: 1.918386 Acc: 0.420904
# epoch_loss:1.8955731730796024
# epoch_corrects:2606.0,epochsize:5083
# valid Loss: 1.895573 Acc: 0.512689
# Epoch 163/3000
# epoch_loss:1.9185738121982865
# epoch_corrects:2385.0,epochsize:5683
# train Loss: 1.918574 Acc: 0.419673
# epoch_loss:1.8954293951846566
# epoch_corrects:2609.0,epochsize:5083
# valid Loss: 1.895429 Acc: 0.513280
# Epoch 164/3000
# epoch_loss:1.9185696066464208
# epoch_corrects:2366.0,epochsize:5683
# train Loss: 1.918570 Acc: 0.416329
# epoch_loss:1.895283939400785
# epoch_corrects:2612.0,epochsize:5083
# valid Loss: 1.895284 Acc: 0.513870
# Epoch 165/3000
# epoch_loss:1.9186156633851312
# epoch_corrects:2354.0,epochsize:5683
# train Loss: 1.918616 Acc: 0.414218
# epoch_loss:1.8951406039615657
# epoch_corrects:2615.0,epochsize:5083
# valid Loss: 1.895141 Acc: 0.514460
# Epoch 166/3000
# epoch_loss:1.9183207547687717
# epoch_corrects:2369.0,epochsize:5683
# train Loss: 1.918321 Acc: 0.416857
# epoch_loss:1.894997371713547
# epoch_corrects:2619.0,epochsize:5083
# valid Loss: 1.894997 Acc: 0.515247
# Epoch 167/3000
# epoch_loss:1.9181807170593044
# epoch_corrects:2365.0,epochsize:5683
# train Loss: 1.918181 Acc: 0.416153
# epoch_loss:1.8948543141400886
# epoch_corrects:2618.0,epochsize:5083
# valid Loss: 1.894854 Acc: 0.515050
# Epoch 168/3000
# epoch_loss:1.9181801742301658
# epoch_corrects:2422.0,epochsize:5683
# train Loss: 1.918180 Acc: 0.426183
# epoch_loss:1.894710456553393
# epoch_corrects:2619.0,epochsize:5083
# valid Loss: 1.894710 Acc: 0.515247
# Epoch 169/3000
# epoch_loss:1.9181993227912866
# epoch_corrects:2397.0,epochsize:5683
# train Loss: 1.918199 Acc: 0.421784
# epoch_loss:1.894563887688252
# epoch_corrects:2620.0,epochsize:5083
# valid Loss: 1.894564 Acc: 0.515444
# Epoch 170/3000
# epoch_loss:1.9181986683043883
# epoch_corrects:2371.0,epochsize:5683
# train Loss: 1.918199 Acc: 0.417209
# epoch_loss:1.8944206520630669
# epoch_corrects:2621.0,epochsize:5083
# valid Loss: 1.894421 Acc: 0.515640
# Epoch 171/3000
# epoch_loss:1.9177337110661379
# epoch_corrects:2428.0,epochsize:5683
# train Loss: 1.917734 Acc: 0.427239
# epoch_loss:1.8942759810717302
# epoch_corrects:2627.0,epochsize:5083
# valid Loss: 1.894276 Acc: 0.516821
# Epoch 172/3000
# epoch_loss:1.9182823954303143
# epoch_corrects:2417.0,epochsize:5683
# train Loss: 1.918282 Acc: 0.425304
# epoch_loss:1.8941379845107185
# epoch_corrects:2633.0,epochsize:5083
# valid Loss: 1.894138 Acc: 0.518001
# Epoch 173/3000
# epoch_loss:1.9181756889570478
# epoch_corrects:2372.0,epochsize:5683
# train Loss: 1.918176 Acc: 0.417385
# epoch_loss:1.8940012303717653
# epoch_corrects:2638.0,epochsize:5083
# valid Loss: 1.894001 Acc: 0.518985
# Epoch 174/3000
# epoch_loss:1.9179650325916109
# epoch_corrects:2433.0,epochsize:5683
# train Loss: 1.917965 Acc: 0.428119
# epoch_loss:1.8938655794405594
# epoch_corrects:2640.0,epochsize:5083
# valid Loss: 1.893866 Acc: 0.519378
# Epoch 175/3000
# epoch_loss:1.917845786005893
# epoch_corrects:2397.0,epochsize:5683
# train Loss: 1.917846 Acc: 0.421784
# epoch_loss:1.8937269592294537
# epoch_corrects:2641.0,epochsize:5083
# valid Loss: 1.893727 Acc: 0.519575
# Epoch 176/3000
# epoch_loss:1.9180643330907479
# epoch_corrects:2414.0,epochsize:5683
# train Loss: 1.918064 Acc: 0.424776
# epoch_loss:1.8935918550005397
# epoch_corrects:2639.0,epochsize:5083
# valid Loss: 1.893592 Acc: 0.519182
# Epoch 177/3000
# epoch_loss:1.9177697229066533
# epoch_corrects:2402.0,epochsize:5683
# train Loss: 1.917770 Acc: 0.422664
# epoch_loss:1.8934555064733634
# epoch_corrects:2640.0,epochsize:5083
# valid Loss: 1.893456 Acc: 0.519378
# Epoch 178/3000
# epoch_loss:1.917974811571072
# epoch_corrects:2411.0,epochsize:5683
# train Loss: 1.917975 Acc: 0.424248
# epoch_loss:1.8933219523873592
# epoch_corrects:2643.0,epochsize:5083
# valid Loss: 1.893322 Acc: 0.519969
# Epoch 179/3000
# epoch_loss:1.9177348330766408
# epoch_corrects:2418.0,epochsize:5683
# train Loss: 1.917735 Acc: 0.425480
# epoch_loss:1.8931844094923906
# epoch_corrects:2648.0,epochsize:5083
# valid Loss: 1.893184 Acc: 0.520952
# Epoch 180/3000
# epoch_loss:1.9181105897771877
# epoch_corrects:2360.0,epochsize:5683
# train Loss: 1.918111 Acc: 0.415274
# epoch_loss:1.89304813444204
# epoch_corrects:2650.0,epochsize:5083
# valid Loss: 1.893048 Acc: 0.521346
# Epoch 181/3000
# epoch_loss:1.917718056744722
# epoch_corrects:2448.0,epochsize:5683
# train Loss: 1.917718 Acc: 0.430758
# epoch_loss:1.8929133773108016
# epoch_corrects:2651.0,epochsize:5083
# valid Loss: 1.892913 Acc: 0.521542
# Epoch 182/3000
# epoch_loss:1.917279644749145
# epoch_corrects:2463.0,epochsize:5683
# train Loss: 1.917280 Acc: 0.433398
# epoch_loss:1.8927768633962734
# epoch_corrects:2652.0,epochsize:5083
# valid Loss: 1.892777 Acc: 0.521739
# Epoch 183/3000
# epoch_loss:1.9174116049437127
# epoch_corrects:2432.0,epochsize:5683
# train Loss: 1.917412 Acc: 0.427943
# epoch_loss:1.8926452709749977
# epoch_corrects:2654.0,epochsize:5083
# valid Loss: 1.892645 Acc: 0.522133
# Epoch 184/3000
# epoch_loss:1.9174262903618935
# epoch_corrects:2409.0,epochsize:5683
# train Loss: 1.917426 Acc: 0.423896
# epoch_loss:1.892512004370298
# epoch_corrects:2657.0,epochsize:5083
# valid Loss: 1.892512 Acc: 0.522723
# Epoch 185/3000
# epoch_loss:1.9174360458686825
# epoch_corrects:2455.0,epochsize:5683
# train Loss: 1.917436 Acc: 0.431990
# epoch_loss:1.8923744674322762
# epoch_corrects:2659.0,epochsize:5083
# valid Loss: 1.892374 Acc: 0.523116
# Epoch 186/3000
# epoch_loss:1.917540761590864
# epoch_corrects:2439.0,epochsize:5683
# train Loss: 1.917541 Acc: 0.429175
# epoch_loss:1.8922374640162152
# epoch_corrects:2663.0,epochsize:5083
# valid Loss: 1.892237 Acc: 0.523903
# Epoch 187/3000
# epoch_loss:1.9173496477876186
# epoch_corrects:2467.0,epochsize:5683
# train Loss: 1.917350 Acc: 0.434102
# epoch_loss:1.892108513688375
# epoch_corrects:2665.0,epochsize:5083
# valid Loss: 1.892109 Acc: 0.524297
# Epoch 188/3000
# epoch_loss:1.91785425106111
# epoch_corrects:2419.0,epochsize:5683
# train Loss: 1.917854 Acc: 0.425655
# epoch_loss:1.8919822971534241
# epoch_corrects:2668.0,epochsize:5083
# valid Loss: 1.891982 Acc: 0.524887
# Epoch 189/3000
# epoch_loss:1.9172141307385773
# epoch_corrects:2460.0,epochsize:5683
# train Loss: 1.917214 Acc: 0.432870
# epoch_loss:1.89185165835956
# epoch_corrects:2672.0,epochsize:5083
# valid Loss: 1.891852 Acc: 0.525674
# Epoch 190/3000
# epoch_loss:1.9174724477457157
# epoch_corrects:2449.0,epochsize:5683
# train Loss: 1.917472 Acc: 0.430934
# epoch_loss:1.8917223162569448
# epoch_corrects:2672.0,epochsize:5083
# valid Loss: 1.891722 Acc: 0.525674
# Epoch 191/3000
# epoch_loss:1.917785015404906
# epoch_corrects:2441.0,epochsize:5683
# train Loss: 1.917785 Acc: 0.429527
# epoch_loss:1.8915945768543945
# epoch_corrects:2672.0,epochsize:5083
# valid Loss: 1.891595 Acc: 0.525674
# Epoch 192/3000
# epoch_loss:1.917184989657512
# epoch_corrects:2445.0,epochsize:5683
# train Loss: 1.917185 Acc: 0.430231
# epoch_loss:1.8914712411363412
# epoch_corrects:2674.0,epochsize:5083
# valid Loss: 1.891471 Acc: 0.526067
# Epoch 193/3000
# epoch_loss:1.9174783437075422
# epoch_corrects:2464.0,epochsize:5683
# train Loss: 1.917478 Acc: 0.433574
# epoch_loss:1.8913475594932396
# epoch_corrects:2674.0,epochsize:5083
# valid Loss: 1.891348 Acc: 0.526067
# Epoch 194/3000
# epoch_loss:1.91788795532191
# epoch_corrects:2416.0,epochsize:5683
# train Loss: 1.917888 Acc: 0.425128
# epoch_loss:1.8912243232843375
# epoch_corrects:2674.0,epochsize:5083
# valid Loss: 1.891224 Acc: 0.526067
# Epoch 195/3000
# epoch_loss:1.9171814714836524
# epoch_corrects:2462.0,epochsize:5683
# train Loss: 1.917181 Acc: 0.433222
# epoch_loss:1.8911009276450301
# epoch_corrects:2676.0,epochsize:5083
# valid Loss: 1.891101 Acc: 0.526461
# Epoch 196/3000
# epoch_loss:1.9173912483475777
# epoch_corrects:2429.0,epochsize:5683
# train Loss: 1.917391 Acc: 0.427415
# epoch_loss:1.8909795962284335
# epoch_corrects:2676.0,epochsize:5083
# valid Loss: 1.890980 Acc: 0.526461
# Epoch 197/3000
# epoch_loss:1.9172087054468263
# epoch_corrects:2444.0,epochsize:5683
# train Loss: 1.917209 Acc: 0.430055
# epoch_loss:1.8908516850125336
# epoch_corrects:2677.0,epochsize:5083
# valid Loss: 1.890852 Acc: 0.526657
# Epoch 198/3000
# epoch_loss:1.9173491368846702
# epoch_corrects:2465.0,epochsize:5683
# train Loss: 1.917349 Acc: 0.433750
# epoch_loss:1.890731280604709
# epoch_corrects:2681.0,epochsize:5083
# valid Loss: 1.890731 Acc: 0.527444
# Epoch 199/3000
# epoch_loss:1.9169997677886106
# epoch_corrects:2497.0,epochsize:5683
# train Loss: 1.917000 Acc: 0.439381
# epoch_loss:1.8906053061938393
# epoch_corrects:2682.0,epochsize:5083
# valid Loss: 1.890605 Acc: 0.527641
# Epoch 200/3000
# epoch_loss:1.9173740937049888
# epoch_corrects:2432.0,epochsize:5683
# train Loss: 1.917374 Acc: 0.427943
# epoch_loss:1.8904854488635472
# epoch_corrects:2686.0,epochsize:5083
# valid Loss: 1.890485 Acc: 0.528428
# Epoch 201/3000
# epoch_loss:1.9169359893923008
# epoch_corrects:2474.0,epochsize:5683
# train Loss: 1.916936 Acc: 0.435333
# epoch_loss:1.8903633377670703
# epoch_corrects:2686.0,epochsize:5083
# valid Loss: 1.890363 Acc: 0.528428
# Epoch 202/3000
# epoch_loss:1.916755761790607
# epoch_corrects:2504.0,epochsize:5683
# train Loss: 1.916756 Acc: 0.440612
# epoch_loss:1.8902389464968423
# epoch_corrects:2686.0,epochsize:5083
# valid Loss: 1.890239 Acc: 0.528428
# Epoch 203/3000
# epoch_loss:1.9170388054222618
# epoch_corrects:2467.0,epochsize:5683
# train Loss: 1.917039 Acc: 0.434102
# epoch_loss:1.8901225775450954
# epoch_corrects:2691.0,epochsize:5083
# valid Loss: 1.890123 Acc: 0.529412
# Epoch 204/3000
# epoch_loss:1.917077385118556
# epoch_corrects:2488.0,epochsize:5683
# train Loss: 1.917077 Acc: 0.437797
# epoch_loss:1.8899998362552644
# epoch_corrects:2693.0,epochsize:5083
# valid Loss: 1.890000 Acc: 0.529805
# Epoch 205/3000
# epoch_loss:1.9168031565345511
# epoch_corrects:2497.0,epochsize:5683
# train Loss: 1.916803 Acc: 0.439381
# epoch_loss:1.8898728172680113
# epoch_corrects:2694.0,epochsize:5083
# valid Loss: 1.889873 Acc: 0.530002
# Epoch 206/3000
# epoch_loss:1.916502237131158
# epoch_corrects:2527.0,epochsize:5683
# train Loss: 1.916502 Acc: 0.444660
# epoch_loss:1.889749851818749
# epoch_corrects:2692.0,epochsize:5083
# valid Loss: 1.889750 Acc: 0.529608
# Epoch 207/3000
# epoch_loss:1.9168201692503313
# epoch_corrects:2453.0,epochsize:5683
# train Loss: 1.916820 Acc: 0.431638
# epoch_loss:1.8896331613795063
# epoch_corrects:2695.0,epochsize:5083
# valid Loss: 1.889633 Acc: 0.530199
# Epoch 208/3000
# epoch_loss:1.9166159564165421
# epoch_corrects:2523.0,epochsize:5683
# train Loss: 1.916616 Acc: 0.443956
# epoch_loss:1.889510422317667
# epoch_corrects:2698.0,epochsize:5083
# valid Loss: 1.889510 Acc: 0.530789
# Epoch 209/3000
# epoch_loss:1.9165387629581634
# epoch_corrects:2468.0,epochsize:5683
# train Loss: 1.916539 Acc: 0.434278
# epoch_loss:1.8893929038159425
# epoch_corrects:2702.0,epochsize:5083
# valid Loss: 1.889393 Acc: 0.531576
# Epoch 210/3000
# epoch_loss:1.9163245195950627
# epoch_corrects:2487.0,epochsize:5683
# train Loss: 1.916325 Acc: 0.437621
# epoch_loss:1.8892718782908988
# epoch_corrects:2702.0,epochsize:5083
# valid Loss: 1.889272 Acc: 0.531576
# Epoch 211/3000
# epoch_loss:1.9163735410434226
# epoch_corrects:2511.0,epochsize:5683
# train Loss: 1.916374 Acc: 0.441844
# epoch_loss:1.8891514318326597
# epoch_corrects:2703.0,epochsize:5083
# valid Loss: 1.889151 Acc: 0.531773
# Epoch 212/3000
# epoch_loss:1.9166361396211606
# epoch_corrects:2524.0,epochsize:5683
# train Loss: 1.916636 Acc: 0.444132
# epoch_loss:1.8890345612778665
# epoch_corrects:2705.0,epochsize:5083
# valid Loss: 1.889035 Acc: 0.532166
# Epoch 213/3000
# epoch_loss:1.9170358705411552
# epoch_corrects:2471.0,epochsize:5683
# train Loss: 1.917036 Acc: 0.434806
# epoch_loss:1.8889183889053573
# epoch_corrects:2709.0,epochsize:5083
# valid Loss: 1.888918 Acc: 0.532953
# Epoch 214/3000
# epoch_loss:1.9167114930234281
# epoch_corrects:2517.0,epochsize:5683
# train Loss: 1.916711 Acc: 0.442900
# epoch_loss:1.8888027842720734
# epoch_corrects:2712.0,epochsize:5083
# valid Loss: 1.888803 Acc: 0.533543
# Epoch 215/3000
# epoch_loss:1.9164840006060568
# epoch_corrects:2464.0,epochsize:5683
# train Loss: 1.916484 Acc: 0.433574
# epoch_loss:1.8886873759600489
# epoch_corrects:2712.0,epochsize:5083
# valid Loss: 1.888687 Acc: 0.533543
# Epoch 216/3000
# epoch_loss:1.9162548569627742
# epoch_corrects:2492.0,epochsize:5683
# train Loss: 1.916255 Acc: 0.438501
# epoch_loss:1.8885706658441204
# epoch_corrects:2716.0,epochsize:5083
# valid Loss: 1.888571 Acc: 0.534330
# Epoch 217/3000
# epoch_loss:1.916519389382429
# epoch_corrects:2497.0,epochsize:5683
# train Loss: 1.916519 Acc: 0.439381
# epoch_loss:1.8884550568721155
# epoch_corrects:2717.0,epochsize:5083
# valid Loss: 1.888455 Acc: 0.534527
# Epoch 218/3000
# epoch_loss:1.9170586289433176
# epoch_corrects:2465.0,epochsize:5683
# train Loss: 1.917059 Acc: 0.433750
# epoch_loss:1.8883465235331338
# epoch_corrects:2721.0,epochsize:5083
# valid Loss: 1.888347 Acc: 0.535314
# Epoch 219/3000
# epoch_loss:1.9166339039697669
# epoch_corrects:2474.0,epochsize:5683
# train Loss: 1.916634 Acc: 0.435333
# epoch_loss:1.8882361197363737
# epoch_corrects:2723.0,epochsize:5083
# valid Loss: 1.888236 Acc: 0.535707
# Epoch 220/3000
# epoch_loss:1.9167531624281677
# epoch_corrects:2467.0,epochsize:5683
# train Loss: 1.916753 Acc: 0.434102
# epoch_loss:1.888124603913709
# epoch_corrects:2724.0,epochsize:5083
# valid Loss: 1.888125 Acc: 0.535904
# Epoch 221/3000
# epoch_loss:1.9162374748093718
# ...
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842863 Acc: 0.617942
# Epoch 1300/3000
# epoch_loss:1.9080416466513088
# epoch_corrects:3003.0,epochsize:5683
# train Loss: 1.908042 Acc: 0.528418
# epoch_loss:1.8428437086674212
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842844 Acc: 0.617942
# Epoch 1301/3000
# epoch_loss:1.907898897544066
# epoch_corrects:3043.0,epochsize:5683
# train Loss: 1.907899 Acc: 0.535457
# epoch_loss:1.842824443315817
# epoch_corrects:3140.0,epochsize:5083
# valid Loss: 1.842824 Acc: 0.617745
# Epoch 1302/3000
# epoch_loss:1.9083857109444715
# epoch_corrects:2977.0,epochsize:5683
# train Loss: 1.908386 Acc: 0.523843
# epoch_loss:1.842800853760393
# epoch_corrects:3140.0,epochsize:5083
# valid Loss: 1.842801 Acc: 0.617745
# Epoch 1303/3000
# epoch_loss:1.9088312398374196
# epoch_corrects:3008.0,epochsize:5683
# train Loss: 1.908831 Acc: 0.529298
# epoch_loss:1.8427829182619375
# epoch_corrects:3138.0,epochsize:5083
# valid Loss: 1.842783 Acc: 0.617352
# Epoch 1304/3000
# epoch_loss:1.9080867090633002
# epoch_corrects:3001.0,epochsize:5683
# train Loss: 1.908087 Acc: 0.528066
# epoch_loss:1.8427633684075022
# epoch_corrects:3140.0,epochsize:5083
# valid Loss: 1.842763 Acc: 0.617745
# Epoch 1305/3000
# epoch_loss:1.9080607678171575
# epoch_corrects:3021.0,epochsize:5683
# train Loss: 1.908061 Acc: 0.531585
# epoch_loss:1.8427454978960507
# epoch_corrects:3139.0,epochsize:5083
# valid Loss: 1.842745 Acc: 0.617549
# Epoch 1306/3000
# epoch_loss:1.9086172225167797
# epoch_corrects:2982.0,epochsize:5683
# train Loss: 1.908617 Acc: 0.524723
# epoch_loss:1.8427275930969775
# epoch_corrects:3139.0,epochsize:5083
# valid Loss: 1.842728 Acc: 0.617549
# Epoch 1307/3000
# epoch_loss:1.9082548717954892
# epoch_corrects:3005.0,epochsize:5683
# train Loss: 1.908255 Acc: 0.528770
# epoch_loss:1.8427093828754024
# epoch_corrects:3140.0,epochsize:5083
# valid Loss: 1.842709 Acc: 0.617745
# Epoch 1308/3000
# epoch_loss:1.908149396787956
# epoch_corrects:3012.0,epochsize:5683
# train Loss: 1.908149 Acc: 0.530002
# epoch_loss:1.8426888113811732
# epoch_corrects:3140.0,epochsize:5083
# valid Loss: 1.842689 Acc: 0.617745
# Epoch 1309/3000
# epoch_loss:1.9078714307420548
# epoch_corrects:3041.0,epochsize:5683
# train Loss: 1.907871 Acc: 0.535105
# epoch_loss:1.8426709019150436
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842671 Acc: 0.617942
# Epoch 1310/3000
# epoch_loss:1.9081496241099813
# epoch_corrects:3010.0,epochsize:5683
# train Loss: 1.908150 Acc: 0.529650
# epoch_loss:1.8426523664770178
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842652 Acc: 0.617942
# Epoch 1311/3000
# epoch_loss:1.9081029174362671
# epoch_corrects:3006.0,epochsize:5683
# train Loss: 1.908103 Acc: 0.528946
# epoch_loss:1.8426324737463649
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842632 Acc: 0.617942
# Epoch 1312/3000
# epoch_loss:1.9080653881787542
# epoch_corrects:3007.0,epochsize:5683
# train Loss: 1.908065 Acc: 0.529122
# epoch_loss:1.842611450321581
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842611 Acc: 0.617942
# Epoch 1313/3000
# epoch_loss:1.9084540554362452
# epoch_corrects:2999.0,epochsize:5683
# train Loss: 1.908454 Acc: 0.527714
# epoch_loss:1.8425931285831512
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842593 Acc: 0.617942
# Epoch 1314/3000
# epoch_loss:1.9081407660186112
# epoch_corrects:2995.0,epochsize:5683
# train Loss: 1.908141 Acc: 0.527010
# epoch_loss:1.842571420156414
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842571 Acc: 0.617942
# Epoch 1315/3000
# epoch_loss:1.9081293648446758
# epoch_corrects:3029.0,epochsize:5683
# train Loss: 1.908129 Acc: 0.532993
# epoch_loss:1.8425482936949564
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842548 Acc: 0.617942
# Epoch 1316/3000
# epoch_loss:1.9086071361481
# epoch_corrects:3017.0,epochsize:5683
# train Loss: 1.908607 Acc: 0.530882
# epoch_loss:1.8425267091445652
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842527 Acc: 0.617942
# Epoch 1317/3000
# epoch_loss:1.90832215634614
# epoch_corrects:2974.0,epochsize:5683
# train Loss: 1.908322 Acc: 0.523315
# epoch_loss:1.8425072978946746
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842507 Acc: 0.617942
# Epoch 1318/3000
# epoch_loss:1.908910912295242
# epoch_corrects:2991.0,epochsize:5683
# train Loss: 1.908911 Acc: 0.526307
# epoch_loss:1.8424874581198698
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842487 Acc: 0.617942
# Epoch 1319/3000
# epoch_loss:1.9080106624305908
# epoch_corrects:2985.0,epochsize:5683
# train Loss: 1.908011 Acc: 0.525251
# epoch_loss:1.8424652393657392
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842465 Acc: 0.617942
# Epoch 1320/3000
# epoch_loss:1.9080800134364135
# epoch_corrects:3029.0,epochsize:5683
# train Loss: 1.908080 Acc: 0.532993
# epoch_loss:1.8424444516859444
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842444 Acc: 0.617942
# Epoch 1321/3000
# epoch_loss:1.9079413417567466
# epoch_corrects:2993.0,epochsize:5683
# train Loss: 1.907941 Acc: 0.526658
# epoch_loss:1.8424243982584487
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842424 Acc: 0.617942
# Epoch 1322/3000
# epoch_loss:1.9083254715936109
# epoch_corrects:2977.0,epochsize:5683
# train Loss: 1.908325 Acc: 0.523843
# epoch_loss:1.8424037404588516
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842404 Acc: 0.617942
# Epoch 1323/3000
# epoch_loss:1.908027895546161
# epoch_corrects:3042.0,epochsize:5683
# train Loss: 1.908028 Acc: 0.535281
# epoch_loss:1.842387531794785
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842388 Acc: 0.617942
# Epoch 1324/3000
# epoch_loss:1.9079906191809926
# epoch_corrects:3026.0,epochsize:5683
# train Loss: 1.907991 Acc: 0.532465
# epoch_loss:1.8423698758506737
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842370 Acc: 0.617942
# Epoch 1325/3000
# epoch_loss:1.908150685645316
# epoch_corrects:3034.0,epochsize:5683
# train Loss: 1.908151 Acc: 0.533873
# epoch_loss:1.842352222720868
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.842352 Acc: 0.618139
# Epoch 1326/3000
# epoch_loss:1.908519159314835
# epoch_corrects:2974.0,epochsize:5683
# train Loss: 1.908519 Acc: 0.523315
# epoch_loss:1.8423329013880374
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842333 Acc: 0.617942
# Epoch 1327/3000
# epoch_loss:1.908548193814447
# epoch_corrects:2979.0,epochsize:5683
# train Loss: 1.908548 Acc: 0.524195
# epoch_loss:1.842314701180699
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842315 Acc: 0.617942
# Epoch 1328/3000
# epoch_loss:1.9085492924571603
# epoch_corrects:3000.0,epochsize:5683
# train Loss: 1.908549 Acc: 0.527890
# epoch_loss:1.8422965568373246
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842297 Acc: 0.617942
# Epoch 1329/3000
# epoch_loss:1.9080580949531607
# epoch_corrects:3011.0,epochsize:5683
# train Loss: 1.908058 Acc: 0.529826
# epoch_loss:1.842277696042133
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842278 Acc: 0.617942
# Epoch 1330/3000
# epoch_loss:1.9086455264688063
# epoch_corrects:2981.0,epochsize:5683
# train Loss: 1.908646 Acc: 0.524547
# epoch_loss:1.8422607768362909
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.842261 Acc: 0.618139
# Epoch 1331/3000
# epoch_loss:1.9082969440114177
# epoch_corrects:3020.0,epochsize:5683
# train Loss: 1.908297 Acc: 0.531409
# epoch_loss:1.8422394096440928
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.842239 Acc: 0.618139
# Epoch 1332/3000
# epoch_loss:1.908249713806919
# epoch_corrects:2997.0,epochsize:5683
# train Loss: 1.908250 Acc: 0.527362
# epoch_loss:1.8422187544946336
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.842219 Acc: 0.618139
# Epoch 1333/3000
# epoch_loss:1.9088388925577875
# epoch_corrects:3015.0,epochsize:5683
# train Loss: 1.908839 Acc: 0.530530
# epoch_loss:1.842200143938104
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.842200 Acc: 0.618139
# Epoch 1334/3000
# epoch_loss:1.908223461500675
# epoch_corrects:3035.0,epochsize:5683
# train Loss: 1.908223 Acc: 0.534049
# epoch_loss:1.842183513010953
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.842184 Acc: 0.618139
# Epoch 1335/3000
# epoch_loss:1.9081327084523365
# epoch_corrects:3003.0,epochsize:5683
# train Loss: 1.908133 Acc: 0.528418
# epoch_loss:1.8421609025524048
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842161 Acc: 0.617942
# Epoch 1336/3000
# epoch_loss:1.9087966666472498
# epoch_corrects:3015.0,epochsize:5683
# train Loss: 1.908797 Acc: 0.530530
# epoch_loss:1.8421442828121182
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842144 Acc: 0.617942
# Epoch 1337/3000
# epoch_loss:1.9076725766416716
# epoch_corrects:3050.0,epochsize:5683
# train Loss: 1.907673 Acc: 0.536688
# epoch_loss:1.8421274168435546
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.842127 Acc: 0.618139
# Epoch 1338/3000
# epoch_loss:1.9079003580099425
# epoch_corrects:3044.0,epochsize:5683
# train Loss: 1.907900 Acc: 0.535633
# epoch_loss:1.8421075786869756
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.842108 Acc: 0.617942
# Epoch 1339/3000
# epoch_loss:1.9082282043648673
# epoch_corrects:3038.0,epochsize:5683
# train Loss: 1.908228 Acc: 0.534577
# epoch_loss:1.8420891871303173
# epoch_corrects:3140.0,epochsize:5083
# valid Loss: 1.842089 Acc: 0.617745
# Epoch 1340/3000
# epoch_loss:1.9081789759416596
# epoch_corrects:3009.0,epochsize:5683
# train Loss: 1.908179 Acc: 0.529474
# epoch_loss:1.8420705353911178
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.842071 Acc: 0.618139
# Epoch 1341/3000
# epoch_loss:1.9080877895194126
# epoch_corrects:3025.0,epochsize:5683
# train Loss: 1.908088 Acc: 0.532289
# epoch_loss:1.8420521458044734
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.842052 Acc: 0.618139
# Epoch 1342/3000
# epoch_loss:1.9085006261194926
# epoch_corrects:2957.0,epochsize:5683
# train Loss: 1.908501 Acc: 0.520324
# epoch_loss:1.8420369641508334
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.842037 Acc: 0.618139
# Epoch 1343/3000
# epoch_loss:1.9084543723487821
# epoch_corrects:3043.0,epochsize:5683
# train Loss: 1.908454 Acc: 0.535457
# epoch_loss:1.8420186932575227
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.842019 Acc: 0.618139
# Epoch 1344/3000
# epoch_loss:1.9081259245145032
# epoch_corrects:3037.0,epochsize:5683
# train Loss: 1.908126 Acc: 0.534401
# epoch_loss:1.8419964513088243
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841996 Acc: 0.618139
# Epoch 1345/3000
# epoch_loss:1.9083085037255274
# epoch_corrects:3010.0,epochsize:5683
# train Loss: 1.908309 Acc: 0.529650
# epoch_loss:1.8419743341511214
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841974 Acc: 0.618139
# Epoch 1346/3000
# epoch_loss:1.907978117203767
# epoch_corrects:3018.0,epochsize:5683
# train Loss: 1.907978 Acc: 0.531058
# epoch_loss:1.8419571888158341
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.841957 Acc: 0.617942
# Epoch 1347/3000
# epoch_loss:1.9082483060968691
# epoch_corrects:3021.0,epochsize:5683
# train Loss: 1.908248 Acc: 0.531585
# epoch_loss:1.8419392417083686
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841939 Acc: 0.618139
# Epoch 1348/3000
# epoch_loss:1.9083608433370878
# epoch_corrects:2995.0,epochsize:5683
# train Loss: 1.908361 Acc: 0.527010
# epoch_loss:1.841920684740906
# epoch_corrects:3141.0,epochsize:5083
# valid Loss: 1.841921 Acc: 0.617942
# Epoch 1349/3000
# epoch_loss:1.9083442788046052
# epoch_corrects:2992.0,epochsize:5683
# train Loss: 1.908344 Acc: 0.526482
# epoch_loss:1.8418998119518228
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841900 Acc: 0.618139
# Epoch 1350/3000
# epoch_loss:1.9079520928698193
# epoch_corrects:3026.0,epochsize:5683
# train Loss: 1.907952 Acc: 0.532465
# epoch_loss:1.841880344603443
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841880 Acc: 0.618139
# Epoch 1351/3000
# epoch_loss:1.9081029594311638
# epoch_corrects:2992.0,epochsize:5683
# train Loss: 1.908103 Acc: 0.526482
# epoch_loss:1.8418646272233028
# epoch_corrects:3143.0,epochsize:5083
# valid Loss: 1.841865 Acc: 0.618336
# Epoch 1352/3000
# epoch_loss:1.9078021059358454
# epoch_corrects:3027.0,epochsize:5683
# train Loss: 1.907802 Acc: 0.532641
# epoch_loss:1.8418463336982855
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841846 Acc: 0.618139
# Epoch 1353/3000
# epoch_loss:1.9080990510739513
# epoch_corrects:3012.0,epochsize:5683
# train Loss: 1.908099 Acc: 0.530002
# epoch_loss:1.8418275535329458
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841828 Acc: 0.618139
# Epoch 1354/3000
# epoch_loss:1.908588888295704
# epoch_corrects:2992.0,epochsize:5683
# train Loss: 1.908589 Acc: 0.526482
# epoch_loss:1.8418103130506809
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841810 Acc: 0.618139
# Epoch 1355/3000
# epoch_loss:1.9083730332053885
# epoch_corrects:2987.0,epochsize:5683
# train Loss: 1.908373 Acc: 0.525603
# epoch_loss:1.8417960261116575
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841796 Acc: 0.618139
# Epoch 1356/3000
# epoch_loss:1.9080565052302647
# epoch_corrects:3034.0,epochsize:5683
# train Loss: 1.908057 Acc: 0.533873
# epoch_loss:1.8417800232202266
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841780 Acc: 0.618139
# Epoch 1357/3000
# epoch_loss:1.9084625200929093
# epoch_corrects:3030.0,epochsize:5683
# train Loss: 1.908463 Acc: 0.533169
# epoch_loss:1.8417592477123028
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841759 Acc: 0.618139
# Epoch 1358/3000
# epoch_loss:1.9081157029524627
# epoch_corrects:3021.0,epochsize:5683
# train Loss: 1.908116 Acc: 0.531585
# epoch_loss:1.8417402002113954
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841740 Acc: 0.618139
# Epoch 1359/3000
# epoch_loss:1.9079892466694626
# epoch_corrects:3020.0,epochsize:5683
# train Loss: 1.907989 Acc: 0.531409
# epoch_loss:1.8417212595133807
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841721 Acc: 0.618139
# Epoch 1360/3000
# epoch_loss:1.9081334856515952
# epoch_corrects:3013.0,epochsize:5683
# train Loss: 1.908133 Acc: 0.530178
# epoch_loss:1.8417049201248248
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841705 Acc: 0.618139
# Epoch 1361/3000
# epoch_loss:1.9077808516096444
# epoch_corrects:3010.0,epochsize:5683
# train Loss: 1.907781 Acc: 0.529650
# epoch_loss:1.8416855523559537
# epoch_corrects:3143.0,epochsize:5083
# valid Loss: 1.841686 Acc: 0.618336
# Epoch 1362/3000
# epoch_loss:1.9084057902526252
# epoch_corrects:3002.0,epochsize:5683
# train Loss: 1.908406 Acc: 0.528242
# epoch_loss:1.841664831656629
# epoch_corrects:3143.0,epochsize:5083
# valid Loss: 1.841665 Acc: 0.618336
# Epoch 1363/3000
# epoch_loss:1.9083323349483663
# epoch_corrects:2999.0,epochsize:5683
# train Loss: 1.908332 Acc: 0.527714
# epoch_loss:1.841647991837654
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841648 Acc: 0.618139
# Epoch 1364/3000
# epoch_loss:1.9084895946139204
# epoch_corrects:3016.0,epochsize:5683
# train Loss: 1.908490 Acc: 0.530706
# epoch_loss:1.8416295442059591
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841630 Acc: 0.618139
# Epoch 1365/3000
# epoch_loss:1.9083366074151773
# epoch_corrects:3006.0,epochsize:5683
# train Loss: 1.908337 Acc: 0.528946
# epoch_loss:1.8416122265413664
# epoch_corrects:3142.0,epochsize:5083
# valid Loss: 1.841612 Acc: 0.618139
# Epoch 1366/3000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1c63f381dfa4> in <module>
# ----> 1 mymodel.train(dataloader_dict,_print=True,_num_epochs=3000)
#       2 #mymodel.loadModel(addname="1_177datas")
#
# ~\git\MyVggishLearning\mylibs\trainer.py in train(self, dataloader_dict, _num_epochs, _print)
#     122                         if phase == "train":
#     123                             #逆伝搬
# --> 124                             loss.backward()
#     125
#     126                             #パラメータ更新
#
# ~\anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# ~\anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     143         retain_graph = create_graph
#     144
# --> 145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
mymodel.graph()

mymodel.eval(dataloader_dict)
mymodel.getKondou()
# Out:
# 正解数/入力数:3142/5083
# 正解率:0.618
#                      Car  Emergency vehicle  Tools  Water  Animal  \
# Car                823.0                3.0    6.0   24.0    64.0
# Emergency vehicle  119.0              268.0    5.0    3.0   100.0
# Tools              117.0                0.0  172.0   70.0    64.0
# Water              148.0                0.0   39.0  613.0   152.0
# Animal             167.0               10.0    2.0   91.0   704.0
# Rail transport     183.0                5.0    6.0   13.0    21.0
# Glass               48.0                0.0   10.0   67.0   104.0
#
#                    Rail transport  Glass
# Car                          80.0    0.0
# Emergency vehicle            80.0    0.0
# Tools                        42.0    0.0
# Water                        48.0    0.0
# Animal                       26.0    0.0
# Rail transport              562.0    0.0
# Glass                        24.0    0.0

# %%
mymodel.saveModel(addname="aaa")

# %%
from pathlib import Path
model=mymodel.model
model.eval()
DIR=Path().resolve()
count=0
os.makedirs(os.path.join(DIR,"acc"),exist_ok=True)
os.makedirs(os.path.join(DIR,"bat"),exist_ok=True)
for inputs,la in dataloader_dict["valid"]:
    outputs=model(inputs)
    print(la,outputs)
    for i in range(len(inputs)):
        fig=plt.figure()
        plt.imshow(inputs[i][0].to('cpu').detach().numpy().copy().T)
        plt.title(labels[int(la[i])])
        isans='acc' if labels[int(la[i])]==labels[int(outputs[i])] else 'bat'
        filepath=os.path.join(DIR,isans,str(count)+".png")
        count+=1
        fig.savefig(filepath)
# Out:
# tensor([1, 1, 3, 0, 1, 2, 3, 0, 1, 4]) tensor([[0.0919, 0.2580, 0.2334, 0.1538, 0.0932, 0.0605, 0.1090],
#         [0.2619, 0.2304, 0.1652, 0.1001, 0.0516, 0.0762, 0.1147],
#         [0.1217, 0.1003, 0.1359, 0.3603, 0.0960, 0.0818, 0.1040],
#         [0.3573, 0.1500, 0.1479, 0.1109, 0.0488, 0.0812, 0.1039],
#         [0.1106, 0.4515, 0.1462, 0.0915, 0.0352, 0.0548, 0.1101],
#         [0.1169, 0.0790, 0.5239, 0.0817, 0.0654, 0.0522, 0.0809],
#         [0.2103, 0.1199, 0.3552, 0.0888, 0.0667, 0.0645, 0.0946],
#         [0.3798, 0.1817, 0.1456, 0.0719, 0.0413, 0.0785, 0.1012],
#         [0.0980, 0.3569, 0.1818, 0.1362, 0.0483, 0.0606, 0.1181],
#         [0.1018, 0.1014, 0.3232, 0.1889, 0.1207, 0.0641, 0.0999]],
#        device='cuda:0', grad_fn=<SoftmaxBackward>)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-1f25877f6ba7> in <module>
#      13         plt.imshow(inputs[i][0].to('cpu').detach().numpy().copy().T)
#      14         plt.title(labels[int(la[i])])
# ---> 15         isans='acc' if labels[int(la[i])]==labels[int(outputs[i])] else 'bat'
#      16         filepath=os.path.join(DIR,isans,str(count)+".png")
#      17         count+=1
#
# ValueError: only one element tensors can be converted to Python scalars

# %%
torch.save(mymodel.model,"mylibs/models/CarSirenSpeechotherMusicAnimal.pth")

# %%
Sequential0Linearin_features=128out_features=64bias=True1Dropoutp=0.5inplace=False2Sigmoid3Linearin_features=64out_features=4bias=True4Softmaxdim=11201500datasotherMusicAnimal.pthCarCivildefensesirenPolicecarsirenFireenginefiretrucksirenMusicAnimalSpeechSequential0Linearin_features=128out_features=64bias=True1Dropoutp=0.5inplace=False2Sigmoid3Linearin_features=64out_features=7bias=True4Softmaxdim=1

# %%
mymodel.model=torch.load("mylibs/models/CarSirenSpeechotherMusicAnimal.pth")

# %%
mymodel.eval(dataloader_dict)
mymodel.getKondou()
# Out:
# 正解数/入力数:1234/2300
# 正解率:0.537
#                                    Car  Civil defense siren  \
# Car                              157.0                 53.0
# Civil defense siren                8.0                175.0
# Police car (siren)                 6.0                 21.0
# Fire engine, fire truck (siren)   14.0                 37.0
# Music                              3.0                 13.0
# Animal                             1.0                 13.0
# Speech                             9.0                  7.0
#
#                                  Police car (siren)  \
# Car                                             1.0
# Civil defense siren                             0.0
# Police car (siren)                              2.0
# Fire engine, fire truck (siren)                 1.0
# Music                                           0.0
# Animal                                          1.0
# Speech                                          0.0
#
#                                  Fire engine, fire truck (siren)  Music  \
# Car                                                         16.0   31.0
# Civil defense siren                                         20.0   33.0
# Police car (siren)                                         112.0   50.0
# Fire engine, fire truck (siren)                            131.0   16.0
# Music                                                        0.0  300.0
# Animal                                                       4.0   34.0
# Speech                                                       1.0   84.0
#
#                                  Animal  Speech
# Car                                83.0    59.0
# Civil defense siren                22.0     7.0
# Police car (siren)                 44.0     5.0
# Fire engine, fire truck (siren)    15.0    21.0
# Music                              37.0    47.0
# Animal                            313.0    34.0
# Speech                            103.0   156.0

# %%
t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2a9af0be2990> in <module>
# ----> 1 trainer.eval(dataloader_dict)
#
# TypeError: eval() missing 1 required positional argument: 'dataloader_dict'

# %%
mymodel.eval(dataloader_dict=dataloader_dict,mode="2")
