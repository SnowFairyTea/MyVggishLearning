# %%
from mylibs.dataloader_dict import *
from mylibs.trainer import *
import torch
import torch.nn as nn
import os
import torch.utils.data as data
from importlib import import_module
import matplotlib.pyplot as plt
import torch.optim as optim
import copy

vggish_input=import_module(".torchvggish.vggish_input","torchvggish-master_changed")
use_pretrained = True

#GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))
# Out:
# vggish/embedding:0
# vggish/embedding:0
# Using cuda device

# %%
mymodel=trainer()
dataloader_dict=get_dataloader_dict(["Speech","Music"])
# Out:
# vggish/embedding:0
# C:\Users\hase\git\MyVggishLearning\mylibs\dataloaders ['C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\MusicSpeech.jb']
# joblib.loadします

# %%
mymodel.train(dataloader_dict,_print=True)
# Out:
# Epoch 1/50
# train Loss: 1.3647 Acc: 0.5258
# valid Loss: 1.3382 Acc: 0.5011
# Epoch 2/50
# train Loss: 1.3191 Acc: 0.6238
# valid Loss: 1.3050 Acc: 0.6911
# Epoch 3/50
# train Loss: 1.2784 Acc: 0.7801
# valid Loss: 1.2510 Acc: 0.8014
# Epoch 4/50
# train Loss: 1.2179 Acc: 0.8107
# valid Loss: 1.1910 Acc: 0.8106
# Epoch 5/50
# train Loss: 1.1666 Acc: 0.8165
# valid Loss: 1.1516 Acc: 0.8150
# Epoch 6/50
# train Loss: 1.1362 Acc: 0.8186
# valid Loss: 1.1295 Acc: 0.8150
# Epoch 7/50
# train Loss: 1.1188 Acc: 0.8208
# valid Loss: 1.1164 Acc: 0.8174
# Epoch 8/50
# train Loss: 1.1085 Acc: 0.8215
# valid Loss: 1.1082 Acc: 0.8190
# Epoch 9/50
# train Loss: 1.1017 Acc: 0.8216
# valid Loss: 1.1026 Acc: 0.8184
# Epoch 10/50
# train Loss: 1.0970 Acc: 0.8214
# valid Loss: 1.0987 Acc: 0.8190
# Epoch 11/50
# train Loss: 1.0937 Acc: 0.8225
# valid Loss: 1.0957 Acc: 0.8199
# Epoch 12/50
# train Loss: 1.0911 Acc: 0.8232
# valid Loss: 1.0934 Acc: 0.8217
# Epoch 13/50
# train Loss: 1.0891 Acc: 0.8229
# ...

# %%
mymodel.graph("1000")

# %%
mymodel100=trainer()
dataloader_dict100=get_dataloader_dict(["Speech100","Music100"])
mymodel100.train(dataloader_dict100,_print=True)
# Out:
# C:\Users\hase\git\MyVggishLearning\mylibs\dataloaders ['C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\Music100Speech100.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\Music10Speech10.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\MusicSpeech.jb']
# joblib.loadします
# Epoch 1/50
# train Loss: 1.364456 Acc: 0.525345
# valid Loss: 1.338056 Acc: 0.499846
# Epoch 2/50
# train Loss: 1.327895 Acc: 0.658413
# valid Loss: 1.315326 Acc: 0.729905
# Epoch 3/50
# train Loss: 1.298069 Acc: 0.757533
# valid Loss: 1.275275 Acc: 0.789652
# Epoch 4/50
# train Loss: 1.248596 Acc: 0.801682
# valid Loss: 1.217598 Acc: 0.805359
# Epoch 5/50
# train Loss: 1.194851 Acc: 0.807522
# valid Loss: 1.169247 Acc: 0.811518
# Epoch 6/50
# train Loss: 1.157279 Acc: 0.808845
# valid Loss: 1.139896 Acc: 0.819526
# Epoch 7/50
# train Loss: 1.134840 Acc: 0.813050
# valid Loss: 1.122760 Acc: 0.816754
# Epoch 8/50
# train Loss: 1.121487 Acc: 0.812816
# ...

# %%
mymodel100.graph("100")

# %%
mymodel10=trainer(_print=False,_lr=1)
dataloader_dict10=get_dataloader_dict(["Speech10","Music10"])
mymodel10.train(dataloader_dict10,_print=True,_num_epochs=200)
# Out:
# C:\Users\hase\git\MyVggishLearning\mylibs\dataloaders ['C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\Music100Speech100.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\Music10Speech10.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\MusicSpeech.jb']
# joblib.loadします
# train用データの数：11
# valid用データの数：8
# Epoch 1/200
# train Loss: 1.344108 Acc: 0.559633
# valid Loss: 1.404839 Acc: 0.500000
# Epoch 2/200
# train Loss: 1.273247 Acc: 0.633028
# valid Loss: 1.404752 Acc: 0.500000
# Epoch 3/200
# train Loss: 1.272826 Acc: 0.633028
# valid Loss: 1.404715 Acc: 0.500000
# Epoch 4/200
# train Loss: 1.272577 Acc: 0.633028
# valid Loss: 1.404700 Acc: 0.500000
# Epoch 5/200
# train Loss: 1.272442 Acc: 0.633028
# valid Loss: 1.404695 Acc: 0.500000
# Epoch 6/200
# train Loss: 1.272333 Acc: 0.633028
# valid Loss: 1.404691 Acc: 0.500000
# Epoch 7/200
# train Loss: 1.272261 Acc: 0.633028
# valid Loss: 1.404690 Acc: 0.500000
# Epoch 8/200
# ...

# %%
mymodel10.graph("10,Dropoutなし")

# %%
mymodel10=trainer(_print=False,_lr=1,_classfilter=nn.Sequential(
                            nn.Linear(128,64),
                            nn.Dropout(p=0.5),
                            nn.Sigmoid(),
                            nn.Linear(64,5),
                            nn.Softmax(dim=1)
                            ), )
dataloader_dict10=get_dataloader_dict(["Speech10","Music10"])
mymodel10.train(dataloader_dict10,_print=True,_num_epochs=200)
# Out:
# C:\Users\hase\git\MyVggishLearning\mylibs\dataloaders ['C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\Music100Speech100.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\Music10Speech10.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\MusicSpeech.jb']
# joblib.loadします
# train用データの数：11
# valid用データの数：8
# Epoch 1/200
# train Loss: 1.610684 Acc: 0.000000
# valid Loss: 1.608851 Acc: 0.000000
# Epoch 2/200
# train Loss: 1.595105 Acc: 0.064220
# valid Loss: 1.597094 Acc: 0.000000
# Epoch 3/200
# train Loss: 1.580493 Acc: 0.321101
# valid Loss: 1.586392 Acc: 0.300000
# Epoch 4/200
# train Loss: 1.566414 Acc: 0.559633
# valid Loss: 1.576581 Acc: 0.500000
# Epoch 5/200
# train Loss: 1.552791 Acc: 0.614679
# valid Loss: 1.568064 Acc: 0.500000
# Epoch 6/200
# train Loss: 1.543590 Acc: 0.623853
# valid Loss: 1.560868 Acc: 0.500000
# Epoch 7/200
# train Loss: 1.538845 Acc: 0.623853
# valid Loss: 1.554638 Acc: 0.500000
# Epoch 8/200
# ...

# %%
mymodel10.graph("10,nn.Dropout(p=0.5)")

# %%
mymodel10=trainer(_print=False,_lr=1,_classfilter=nn.Sequential(
                            nn.Linear(128,64),
                            nn.Dropout(p=0.75),
                            nn.Sigmoid(),
                            nn.Linear(64,5),
                            nn.Softmax(dim=1)
                            ), 
                 _update_param_names=
                     ['embeddings.4.weight','embeddings.4.bias',
                         'classfilter.0.weight', 'classfilter.0.bias', 
                          'classfilter.2.weight','classfilter.2.bias'],)
dataloader_dict10=get_dataloader_dict(["Speech10","Music10"])
mymodel10.train(dataloader_dict10,_print=True,_num_epochs=200)
# Out:
# C:\Users\hase\git\MyVggishLearning\mylibs\dataloaders ['C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\Music100Speech100.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\Music10Speech10.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\MusicSpeech.jb']
# joblib.loadします
# train用データの数：11
# valid用データの数：8
# Epoch 1/200
# train Loss: 1.636845 Acc: 0.000000
# valid Loss: 1.628220 Acc: 0.000000
# Epoch 2/200
# train Loss: 1.619151 Acc: 0.018349
# valid Loss: 1.611530 Acc: 0.000000
# Epoch 3/200
# train Loss: 1.604321 Acc: 0.100917
# valid Loss: 1.594447 Acc: 0.200000
# Epoch 4/200
# train Loss: 1.589986 Acc: 0.275229
# valid Loss: 1.579741 Acc: 0.500000
# Epoch 5/200
# train Loss: 1.588890 Acc: 0.256881
# valid Loss: 1.568687 Acc: 0.500000
# Epoch 6/200
# train Loss: 1.585281 Acc: 0.275229
# valid Loss: 1.560009 Acc: 0.500000
# Epoch 7/200
# train Loss: 1.576517 Acc: 0.321101
# valid Loss: 1.551938 Acc: 0.500000
# Epoch 8/200
# ...

# %%
mymodel10.graph("lr:1,nn.Dropout(p=0.75),embeddings.4.")

# %%
mymodel10=trainer(_print=False,_lr=1,_classfilter=nn.Sequential(
                            nn.Linear(128,64),
                            nn.Dropout(p=0.9),
                            nn.Sigmoid(),
                            nn.Linear(64,5),
                            nn.Softmax(dim=1)
                            ), )
dataloader_dict10=get_dataloader_dict(["Speech10","Music10"])
mymodel10.train(dataloader_dict10,_print=True,_num_epochs=200)
# Out:
# C:\Users\hase\git\MyVggishLearning\mylibs\dataloaders ['C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\Music100Speech100.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\Music10Speech10.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\MusicSpeech.jb']
# joblib.loadします
# train用データの数：11
# valid用データの数：8
# Epoch 1/200
# train Loss: 1.560090 Acc: 0.633028
# valid Loss: 1.563362 Acc: 0.500000
# Epoch 2/200
# train Loss: 1.551987 Acc: 0.633028
# valid Loss: 1.555443 Acc: 0.500000
# Epoch 3/200
# train Loss: 1.546425 Acc: 0.633028
# valid Loss: 1.549695 Acc: 0.500000
# Epoch 4/200
# train Loss: 1.544223 Acc: 0.633028
# valid Loss: 1.546185 Acc: 0.500000
# Epoch 5/200
# train Loss: 1.542362 Acc: 0.633028
# valid Loss: 1.543635 Acc: 0.500000
# Epoch 6/200
# train Loss: 1.541398 Acc: 0.633028
# valid Loss: 1.541318 Acc: 0.500000
# Epoch 7/200
# train Loss: 1.540047 Acc: 0.633028
# valid Loss: 1.539190 Acc: 0.500000
# Epoch 8/200
# ...

# %%
mymodel10.graph("10,nn.Dropout(p=0.90)")
