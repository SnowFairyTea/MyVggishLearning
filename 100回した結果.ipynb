# %%
import torch
import torch.nn as nn
import os
import torch.utils.data as data
from importlib import import_module
import matplotlib.pyplot as plt

vggish_input=import_module(".torchvggish.vggish_input","torchvggish-master")


#GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))
#損失関数
criterion = nn.CrossEntropyLoss()
# Out:
# vggish/embedding:0
# Using cuda device

# %%
model = torch.hub.load('torchvggish-master', 'vggish', source='local', preprocess=False).to(device)
model.eval()
# Out:
# vggish/embedding:0
# VGGish(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace=True)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace=True)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (embeddings): Sequential(
#     (0): Linear(in_features=12288, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=4096, out_features=4096, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=4096, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#   )
#   (pproc): Postprocessor()
# )

# %%
class MyClassfilter(nn.Module):
    def __init__(self):
        super(MyClassfilter, self).__init__()
        self.classfilter=nn.Sequential(
            nn.Linear(128,64),
            nn.Sigmoid(),
            nn.Linear(64,5),
            nn.Softmax()
        )
    def forward(self, x):
        return self.classfilter(x)
mymodel = MyClassfilter().to(device)
mymodel.eval()
# Out:
# MyClassfilter(
#   (classfilter): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=64, out_features=5, bias=True)
#     (3): Softmax(dim=None)
#   )
# )

# %%
# 学習済みの重みを使用
use_pretrained = True

# モデルをロード
print(model)
print(mymodel)
# Out:
# VGGish(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace=True)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace=True)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (embeddings): Sequential(
#     (0): Linear(in_features=12288, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=4096, out_features=4096, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=4096, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#   )
#   (pproc): Postprocessor()
# )
# MyClassfilter(
#   (classfilter): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=64, out_features=5, bias=True)
#     (3): Softmax(dim=None)
#   )
# )

# %%
#試しに実行
#model.eval()# 評価しない
#import urllib
#url, filename = ("http://soundbible.com/grab.php?id=1698&type=wav", "bus_chatter.wav")
#try: urllib.URLopener().retrieve(url, filename)
#except: urllib.request.urlretrieve(url, filename)
#a =model.forward(filename)
#rint(a.size(),a.dim())
#print(mymodel.forward(a))

# %%
#データセットの定義？
classes=["Speech","Wind","Animal","Music","Speech"]
dataset_dir="C:/Users/hase/git/youtubedl/result"


def make_path_list():
    train_file_list=[]
    valid_file_list=[]
    for i in range(len(classes)):
        dir_name=os.path.join(dataset_dir,classes[i]).replace("\\","/")
        file_list=os.listdir(dir_name)
        
        #8割を学習用、残りを検証用にする
        num_data = len(file_list)
        num_split = int(num_data*0.8)
        
        train_file_list += [[os.path.join(dir_name, file).replace('\\', '/'), i] for file in file_list[:num_split] ]
        valid_file_list += [[os.path.join(dir_name, file).replace('\\', '/'), i] for file in file_list[num_split:]]
    return {"train":train_file_list,"valid":valid_file_list}
# 画像データへのファイルパスとラベルを格納したリストを取得する
path_dict = make_path_list()
## リストが変かもなのでみてみる


print('学習データファイル数 : ', len(path_dict["train"]))
##### 先頭3件だけ表示
print(path_dict["train"][:3])

print('検証データファイル数 : ', len(path_dict["valid"]))
##### 先頭3件だけ表示
print(path_dict["valid"][:3])
# Out:
# 学習データファイル数 :  162
# [['C:/Users/hase/git/youtubedl/result/Speech/--aE2O5G5WE.wav', 0], ['C:/Users/hase/git/youtubedl/result/Speech/--PJHxphWEs.wav', 0], ['C:/Users/hase/git/youtubedl/result/Speech/-30H9V1IKps.wav', 0]]
# 検証データファイル数 :  44
# [['C:/Users/hase/git/youtubedl/result/Speech/-L44JqysUy8.wav', 0], ['C:/Users/hase/git/youtubedl/result/Speech/-L68XDzhn2g.wav', 0], ['C:/Users/hase/git/youtubedl/result/Speech/-LBl0UeKNyU.wav', 0]]

# %%
#0830
#DataSet型を作る必要がある気がする
class MyDataset(data.Dataset):
    '''
    data_dictは[パス,番号]
    '''
    def __init__(self, path_dict,  phase='train'):
        #self.data_dict = data_dict
        self.data_dict = []
        for path, label in path_dict:
            for data in vggish_input.wavfile_to_examples(path):
                self.data_dict.append([data, label])
                
        
        self.phase = phase
        
    def __len__(self):
        return len(self.data_dict)
    
    def __getitem__(self,index):
        
        wav_data,label = self.data_dict[index]
        
        return wav_data, label

#DataSetを実際に作ってみる 

train_dataset = MyDataset(
    path_dict=path_dict["train"],
    phase="train"
)

valid_dataset = MyDataset(
    path_dict=path_dict["valid"],
    phase="valid"
)

# %%
print("学習用データ数 : ", len(train_dataset))
print("検証用データ数 : ", len(valid_dataset))
# Out:
# 学習用データ数 :  1608
# 検証用データ数 :  439

# %%
#dataloaderを用いてミニバッチを作成
batch_size=10

train_dataloader=data.DataLoader(
    train_dataset, batch_size = batch_size, shuffle=True
)
valid_dataloader=data.DataLoader(
    valid_dataset, batch_size = batch_size//2, shuffle=True
)

dataloader_dict={
    'train': train_dataloader, 
    'valid': valid_dataloader
}
print(dataloader_dict)
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader object at 0x0000025C86AF3E20>, 'valid': <torch.utils.data.dataloader.DataLoader object at 0x0000025C86AF30A0>}

# %%
# パラメータ名の確認
for name, param in model.named_parameters():
    print('name : ', name)
print("-------")
for name, param in mymodel.named_parameters():
    print("name : ",name)
#print(mymodel.parameters())
# Out:
# name :  features.0.weight
# name :  features.0.bias
# name :  features.3.weight
# name :  features.3.bias
# name :  features.6.weight
# name :  features.6.bias
# name :  features.8.weight
# name :  features.8.bias
# name :  features.11.weight
# name :  features.11.bias
# name :  features.13.weight
# name :  features.13.bias
# name :  embeddings.0.weight
# name :  embeddings.0.bias
# name :  embeddings.2.weight
# name :  embeddings.2.bias
# name :  embeddings.4.weight
# name :  embeddings.4.bias
# name :  pproc.pca_eigen_vectors
# name :  pproc.pca_means
# -------
# name :  classfilter.0.weight
# name :  classfilter.0.bias
# name :  classfilter.2.weight
# name :  classfilter.2.bias

# %%
#学習させるパラメータを格納
params_to_update=[]
#学習させるパラメータ名
update_param_names=['classfilter.0.weight', 'classfilter.0.bias', 'classfilter.2.weight']

#対象以外は購買計算をせず、変化しないようにもする
for name,param in mymodel.named_parameters():
    if name in update_param_names:
        param.requires_grad = True
        params_to_update.append(param)
        print("name : ",name)
    else:
        param.requires_grad = False
# Out:
# name :  classfilter.0.weight
# name :  classfilter.0.bias
# name :  classfilter.2.weight

# %%
import torch.optim as optim
#勾配計算手法?
#optimizer = optim.SGD(params_to_update, lr=0.01)
optimizer = optim.SGD(params_to_update, lr=0.01)

# %%
#エポック数
num_epochs=100
x=[]
y=[]
for epoch in range(num_epochs):
    print('Epoch {}/{}'.format(epoch+1,num_epochs))
    
    for phase in ['train','valid']:
        if phase == 'train':
            mymodel.train()#学習モード
        else:
            mymodel.eval()#検証モード
    
        #epoch全体の損失の輪と正解数
        epoch_loss=0.0
        epoch_corrects=0
        
        count=0.0
        #print(phase)
        for inputs, labels in dataloader_dict[phase]:
            #入力の確認
            #print(len(inputs),len(labels))
            #optimizer?を初期化?する?
            optimizer.zero_grad()


            with torch.set_grad_enabled(phase=='train'):

                out1=model(inputs)
                outputs=mymodel(out1)

                #labelsをcudaに
                labels=labels.to(device)

                #損失関数を計算
                loss=criterion(outputs, labels)
                #ラベルを予測
                _,preds = torch.max(outputs,1)
                
                #訓練時は逆伝搬の計算
                if phase == "train":
                    #逆伝搬
                    loss.backward()
                    
                    #パラメータ更新
                    optimizer.step()
                
                #イテレーション結果の計算
                #lossの合計を更新
                #pytorchの使用上バッチ内の平均lossが計算されているのでデータ数をかけて合計にする
                #損失和を「全データの損失/データ数」で求めるせいらしい?
                #print(len(inputs))
                epoch_loss += loss.item() * inputs.size(0)
                
                #正解数の合計を更新
                epoch_corrects += torch.sum(preds == labels.data)

        #epochのlossと正解数の表示
        epoch_loss=epoch_loss/len(dataloader_dict[phase])
        epoch_acc=epoch_corrects.double()/len(dataloader_dict[phase].dataset)

        print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))
        x.append(epoch_acc)
        y.append(epoch)
# Out:
# Epoch 1/100
# C:\Users\hase\anaconda3\lib\site-packages\torch\nn\modules\container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# train Loss: 15.9353 Acc: 0.2842
# valid Loss: 7.9429 Acc: 0.2984
# Epoch 2/100
# train Loss: 15.7135 Acc: 0.3228
# valid Loss: 7.8613 Acc: 0.2642
# Epoch 3/100
# train Loss: 15.4813 Acc: 0.3545
# valid Loss: 7.7724 Acc: 0.3417
# Epoch 4/100
# train Loss: 15.2897 Acc: 0.3943
# valid Loss: 7.6856 Acc: 0.3599
# Epoch 5/100
# train Loss: 15.0665 Acc: 0.4067
# valid Loss: 7.6339 Acc: 0.3576
# Epoch 6/100
# train Loss: 14.9274 Acc: 0.4036
# valid Loss: 7.5917 Acc: 0.3781
# Epoch 7/100
# train Loss: 14.7649 Acc: 0.4198
# valid Loss: 7.5287 Acc: 0.4191
# Epoch 8/100
# train Loss: 14.6251 Acc: 0.4415
# valid Loss: 7.4674 Acc: 0.4009
# Epoch 9/100
# train Loss: 14.4899 Acc: 0.4639
# valid Loss: 7.4241 Acc: 0.4465
# Epoch 10/100
# train Loss: 14.3983 Acc: 0.4863
# valid Loss: 7.3849 Acc: 0.4647
# Epoch 11/100
# train Loss: 14.2883 Acc: 0.5037
# valid Loss: 7.4070 Acc: 0.4305
# Epoch 12/100
# train Loss: 14.2620 Acc: 0.4938
# valid Loss: 7.3020 Acc: 0.4647
# Epoch 13/100
# train Loss: 14.0405 Acc: 0.5193
# valid Loss: 7.2851 Acc: 0.4738
# Epoch 14/100
# train Loss: 13.9373 Acc: 0.5280
# valid Loss: 7.2811 Acc: 0.4556
# Epoch 15/100
# train Loss: 13.9335 Acc: 0.5218
# valid Loss: 7.3209 Acc: 0.4533
# Epoch 16/100
# train Loss: 13.8039 Acc: 0.5522
# valid Loss: 7.2240 Acc: 0.4784
# Epoch 17/100
# train Loss: 13.7374 Acc: 0.5510
# valid Loss: 7.2115 Acc: 0.4487
# Epoch 18/100
# train Loss: 13.7630 Acc: 0.5572
# valid Loss: 7.2741 Acc: 0.4738
# Epoch 19/100
# train Loss: 13.6072 Acc: 0.5864
# valid Loss: 7.1993 Acc: 0.4989
# Epoch 20/100
# train Loss: 13.6399 Acc: 0.5578
# valid Loss: 7.2009 Acc: 0.4556
# Epoch 21/100
# train Loss: 13.5308 Acc: 0.5709
# valid Loss: 7.1422 Acc: 0.4897
# Epoch 22/100
# train Loss: 13.4985 Acc: 0.5665
# valid Loss: 7.2491 Acc: 0.4556
# Epoch 23/100
# train Loss: 13.4085 Acc: 0.5951
# valid Loss: 7.1973 Acc: 0.4784
# Epoch 24/100
# train Loss: 13.3329 Acc: 0.5976
# valid Loss: 7.1975 Acc: 0.4806
# Epoch 25/100
# train Loss: 13.3905 Acc: 0.5908
# valid Loss: 7.2482 Acc: 0.4510
# Epoch 26/100
# train Loss: 13.2679 Acc: 0.6026
# valid Loss: 7.1917 Acc: 0.4715
# Epoch 27/100
# train Loss: 13.2267 Acc: 0.6194
# valid Loss: 7.2118 Acc: 0.4510
# Epoch 28/100
# train Loss: 13.1727 Acc: 0.5983
# valid Loss: 7.2254 Acc: 0.4647
# Epoch 29/100
# train Loss: 13.2115 Acc: 0.6014
# valid Loss: 7.1581 Acc: 0.4556
# Epoch 30/100
# train Loss: 13.1399 Acc: 0.5951
# valid Loss: 7.1940 Acc: 0.4579
# Epoch 31/100
# train Loss: 13.1713 Acc: 0.6107
# valid Loss: 7.1486 Acc: 0.4715
# Epoch 32/100
# train Loss: 13.0530 Acc: 0.6194
# valid Loss: 7.1319 Acc: 0.4761
# Epoch 33/100
# train Loss: 13.1405 Acc: 0.6063
# valid Loss: 7.2978 Acc: 0.4374
# Epoch 34/100
# train Loss: 13.1278 Acc: 0.6088
# valid Loss: 7.1729 Acc: 0.4852
# Epoch 35/100
# train Loss: 13.0906 Acc: 0.6163
# valid Loss: 7.1765 Acc: 0.4692
# Epoch 36/100
# train Loss: 13.0551 Acc: 0.6182
# valid Loss: 7.1816 Acc: 0.4692
# Epoch 37/100
# train Loss: 13.0255 Acc: 0.6169
# valid Loss: 7.1356 Acc: 0.4715
# Epoch 38/100
# train Loss: 12.9367 Acc: 0.6213
# valid Loss: 7.1950 Acc: 0.4556
# Epoch 39/100
# train Loss: 12.9719 Acc: 0.6269
# valid Loss: 7.1572 Acc: 0.4624
# Epoch 40/100
# train Loss: 12.9379 Acc: 0.6238
# valid Loss: 7.2882 Acc: 0.4328
# Epoch 41/100
# train Loss: 12.9441 Acc: 0.6219
# valid Loss: 7.1836 Acc: 0.4715
# Epoch 42/100
# train Loss: 12.9983 Acc: 0.6231
# valid Loss: 7.2229 Acc: 0.4601
# Epoch 43/100
# train Loss: 12.9641 Acc: 0.6225
# valid Loss: 7.1107 Acc: 0.5103
# Epoch 44/100
# train Loss: 13.0056 Acc: 0.6219
# valid Loss: 7.1989 Acc: 0.4442
# Epoch 45/100
# train Loss: 12.9289 Acc: 0.6175
# valid Loss: 7.1086 Acc: 0.4715
# Epoch 46/100
# train Loss: 12.8711 Acc: 0.6200
# valid Loss: 7.1320 Acc: 0.4556
# Epoch 47/100
# train Loss: 12.8211 Acc: 0.6362
# valid Loss: 7.1083 Acc: 0.4875
# Epoch 48/100
# train Loss: 12.9450 Acc: 0.6219
# valid Loss: 7.1104 Acc: 0.4784
# Epoch 49/100
# train Loss: 12.9030 Acc: 0.6350
# valid Loss: 7.0852 Acc: 0.4920
# Epoch 50/100
# train Loss: 13.0043 Acc: 0.6343
# valid Loss: 7.1915 Acc: 0.4487
# Epoch 51/100
# train Loss: 12.8850 Acc: 0.6269
# valid Loss: 7.1304 Acc: 0.4829
# Epoch 52/100
# train Loss: 12.8025 Acc: 0.6343
# valid Loss: 7.0785 Acc: 0.4943
# Epoch 53/100
# train Loss: 12.8473 Acc: 0.6449
# valid Loss: 7.1347 Acc: 0.4784
# Epoch 54/100
# train Loss: 12.8124 Acc: 0.6350
# valid Loss: 7.1161 Acc: 0.4761
# Epoch 55/100
# train Loss: 12.9073 Acc: 0.6206
# valid Loss: 7.1376 Acc: 0.4784
# Epoch 56/100
# train Loss: 12.9283 Acc: 0.6231
# valid Loss: 7.0442 Acc: 0.4852
# Epoch 57/100
# train Loss: 12.8333 Acc: 0.6387
# valid Loss: 7.2409 Acc: 0.4396
# Epoch 58/100
# train Loss: 12.8804 Acc: 0.6331
# valid Loss: 7.1052 Acc: 0.4989
# Epoch 59/100
# train Loss: 12.8659 Acc: 0.6169
# valid Loss: 7.0875 Acc: 0.4897
# Epoch 60/100
# train Loss: 12.8581 Acc: 0.6281
# valid Loss: 7.2159 Acc: 0.4374
# Epoch 61/100
# train Loss: 12.7853 Acc: 0.6343
# valid Loss: 7.1674 Acc: 0.4510
# Epoch 62/100
# train Loss: 12.8864 Acc: 0.6169
# valid Loss: 7.2138 Acc: 0.4533
# Epoch 63/100
# train Loss: 12.9371 Acc: 0.6318
# valid Loss: 7.2155 Acc: 0.4419
# Epoch 64/100
# train Loss: 12.8438 Acc: 0.6287
# valid Loss: 7.0784 Acc: 0.4670
# Epoch 65/100
# train Loss: 12.7782 Acc: 0.6331
# valid Loss: 7.0373 Acc: 0.4784
# Epoch 66/100
# train Loss: 12.8358 Acc: 0.6325
# valid Loss: 7.1033 Acc: 0.4670
# Epoch 67/100
# train Loss: 12.8655 Acc: 0.6269
# valid Loss: 7.1512 Acc: 0.4761
# Epoch 68/100
# train Loss: 12.8409 Acc: 0.6256
# valid Loss: 7.0797 Acc: 0.4784
# Epoch 69/100
# train Loss: 12.8012 Acc: 0.6412
# valid Loss: 7.1641 Acc: 0.4601
# Epoch 70/100
# train Loss: 12.7185 Acc: 0.6374
# valid Loss: 7.0547 Acc: 0.4761
# Epoch 71/100
# train Loss: 12.7651 Acc: 0.6306
# valid Loss: 7.0280 Acc: 0.4875
# Epoch 72/100
# train Loss: 12.7375 Acc: 0.6424
# valid Loss: 7.1846 Acc: 0.4487
# Epoch 73/100
# train Loss: 12.7341 Acc: 0.6350
# valid Loss: 7.1525 Acc: 0.4579
# Epoch 74/100
# train Loss: 12.7473 Acc: 0.6306
# valid Loss: 7.0902 Acc: 0.4806
# Epoch 75/100
# train Loss: 12.7811 Acc: 0.6262
# valid Loss: 7.1190 Acc: 0.4647
# Epoch 76/100
# train Loss: 12.8570 Acc: 0.6238
# valid Loss: 7.2220 Acc: 0.4761
# Epoch 77/100
# train Loss: 12.8505 Acc: 0.6262
# valid Loss: 7.2380 Acc: 0.4396
# Epoch 78/100
# train Loss: 12.8467 Acc: 0.6238
# valid Loss: 7.1362 Acc: 0.4624
# Epoch 79/100
# train Loss: 12.5851 Acc: 0.6480
# valid Loss: 7.1013 Acc: 0.4692
# Epoch 80/100
# train Loss: 12.6674 Acc: 0.6374
# valid Loss: 7.1014 Acc: 0.4806
# Epoch 81/100
# train Loss: 12.7860 Acc: 0.6275
# valid Loss: 7.1290 Acc: 0.4692
# Epoch 82/100
# train Loss: 12.8037 Acc: 0.6405
# valid Loss: 7.1278 Acc: 0.4715
# Epoch 83/100
# train Loss: 12.6435 Acc: 0.6424
# valid Loss: 7.1279 Acc: 0.4692
# Epoch 84/100
# train Loss: 12.6591 Acc: 0.6337
# valid Loss: 7.1698 Acc: 0.4533
# Epoch 85/100
# train Loss: 12.7171 Acc: 0.6424
# valid Loss: 7.1746 Acc: 0.4487
# Epoch 86/100
# train Loss: 12.7911 Acc: 0.6437
# valid Loss: 7.2746 Acc: 0.4305
# Epoch 87/100
# train Loss: 12.7224 Acc: 0.6356
# valid Loss: 7.1330 Acc: 0.4579
# Epoch 88/100
# train Loss: 12.6709 Acc: 0.6505
# valid Loss: 7.0873 Acc: 0.4806
# Epoch 89/100
# train Loss: 12.7113 Acc: 0.6399
# valid Loss: 7.1756 Acc: 0.4510
# Epoch 90/100
# train Loss: 12.7036 Acc: 0.6399
# valid Loss: 7.0970 Acc: 0.4670
# Epoch 91/100
# train Loss: 12.7785 Acc: 0.6294
# valid Loss: 7.1133 Acc: 0.4806
# Epoch 92/100
# train Loss: 12.7381 Acc: 0.6368
# valid Loss: 7.1270 Acc: 0.4852
# Epoch 93/100
# train Loss: 12.8805 Acc: 0.6213
# valid Loss: 7.1424 Acc: 0.4579
# Epoch 94/100
# train Loss: 12.7773 Acc: 0.6318
# valid Loss: 7.2100 Acc: 0.4510
# Epoch 95/100
# train Loss: 12.7915 Acc: 0.6350
# valid Loss: 7.1263 Acc: 0.4647
# Epoch 96/100
# train Loss: 12.7405 Acc: 0.6337
# valid Loss: 7.2051 Acc: 0.4328
# Epoch 97/100
# train Loss: 12.6563 Acc: 0.6331
# valid Loss: 7.1641 Acc: 0.4533
# Epoch 98/100
# train Loss: 12.6302 Acc: 0.6474
# valid Loss: 7.1623 Acc: 0.4487
# Epoch 99/100
# train Loss: 12.5337 Acc: 0.6443
# valid Loss: 7.1422 Acc: 0.4624
# Epoch 100/100
# train Loss: 12.5819 Acc: 0.6437
# valid Loss: 7.1126 Acc: 0.4692

# %%
plt.plot(y[::2],[i.tolist() for i in x][::2], label="train", color ="Green")
plt.plot(y[::2],[i.tolist() for i in x][1::2], label="valid", color ="Blue")
plt.legend(loc='upper left')
