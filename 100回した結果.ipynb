# %%
import torch
import torch.nn as nn
import os
import torch.utils.data as data
from importlib import import_module
import matplotlib.pyplot as plt

vggish_input=import_module(".torchvggish.vggish_input","torchvggish-master")


#GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))
#損失関数
criterion = nn.CrossEntropyLoss()
# Out:
# vggish/embedding:0
# Using cuda device

# %%
model = torch.hub.load('torchvggish-master', 'vggish', source='local', preprocess=False).to(device)
model.eval()
# Out:
# vggish/embedding:0
# VGGish(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace=True)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace=True)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (embeddings): Sequential(
#     (0): Linear(in_features=12288, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=4096, out_features=4096, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=4096, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#   )
#   (pproc): Postprocessor()
# )

# %%
class MyClassfilter(nn.Module):
    def __init__(self):
        super(MyClassfilter, self).__init__()
        self.classfilter=nn.Sequential(
            nn.Linear(128,64),
            nn.Sigmoid(),
            nn.Linear(64,5),
            nn.Softmax()
        )
    def forward(self, x):
        return self.classfilter(x)
mymodel = MyClassfilter().to(device)
mymodel.eval()
# Out:
# MyClassfilter(
#   (classfilter): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=64, out_features=5, bias=True)
#     (3): Softmax(dim=None)
#   )
# )

# %%
# 学習済みの重みを使用
use_pretrained = True

# モデルをロード
print(model)
print(mymodel)
# Out:
# VGGish(
#   (features): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace=True)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace=True)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (embeddings): Sequential(
#     (0): Linear(in_features=12288, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=4096, out_features=4096, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=4096, out_features=128, bias=True)
#     (5): ReLU(inplace=True)
#   )
#   (pproc): Postprocessor()
# )
# MyClassfilter(
#   (classfilter): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=64, out_features=5, bias=True)
#     (3): Softmax(dim=None)
#   )
# )

# %%
#試しに実行
#model.eval()# 評価しない
#import urllib
#url, filename = ("http://soundbible.com/grab.php?id=1698&type=wav", "bus_chatter.wav")
#try: urllib.URLopener().retrieve(url, filename)
#except: urllib.request.urlretrieve(url, filename)
#a =model.forward(filename)
#rint(a.size(),a.dim())
#print(mymodel.forward(a))

# %%
#データセットの定義？
classes=["Speech","Wind","Animal","Music","Speech"]
dataset_dir="C:/Users/hase/git/youtubedl/result"


def make_path_list():
    train_file_list=[]
    valid_file_list=[]
    for i in range(len(classes)):
        dir_name=os.path.join(dataset_dir,classes[i]).replace("\\","/")
        file_list=os.listdir(dir_name)
        
        #8割を学習用、残りを検証用にする
        num_data = len(file_list)
        num_split = int(num_data*0.8)
        
        train_file_list += [[os.path.join(dir_name, file).replace('\\', '/'), i] for file in file_list[:num_split] ]
        valid_file_list += [[os.path.join(dir_name, file).replace('\\', '/'), i] for file in file_list[num_split:]]
    return {"train":train_file_list,"valid":valid_file_list}
# 画像データへのファイルパスとラベルを格納したリストを取得する
path_dict = make_path_list()
## リストが変かもなのでみてみる


print('学習データファイル数 : ', len(path_dict["train"]))
##### 先頭3件だけ表示
print(path_dict["train"][:3])

print('検証データファイル数 : ', len(path_dict["valid"]))
##### 先頭3件だけ表示
print(path_dict["valid"][:3])
# Out:
# 学習データファイル数 :  162
# [['C:/Users/hase/git/youtubedl/result/Speech/--aE2O5G5WE.wav', 0], ['C:/Users/hase/git/youtubedl/result/Speech/--PJHxphWEs.wav', 0], ['C:/Users/hase/git/youtubedl/result/Speech/-30H9V1IKps.wav', 0]]
# 検証データファイル数 :  44
# [['C:/Users/hase/git/youtubedl/result/Speech/-L44JqysUy8.wav', 0], ['C:/Users/hase/git/youtubedl/result/Speech/-L68XDzhn2g.wav', 0], ['C:/Users/hase/git/youtubedl/result/Speech/-LBl0UeKNyU.wav', 0]]

# %%
#0830
#DataSet型を作る必要がある気がする
class MyDataset(data.Dataset):
    '''
    data_dictは[パス,番号]
    '''
    def __init__(self, path_dict,  phase='train'):
        #self.data_dict = data_dict
        self.data_dict = []
        for path, label in path_dict:
            for data in vggish_input.wavfile_to_examples(path):
                self.data_dict.append([data, label])
                
        
        self.phase = phase
        
    def __len__(self):
        return len(self.data_dict)
    
    def __getitem__(self,index):
        
        wav_data,label = self.data_dict[index]
        
        return wav_data, label

#DataSetを実際に作ってみる 

train_dataset = MyDataset(
    path_dict=path_dict["train"],
    phase="train"
)

valid_dataset = MyDataset(
    path_dict=path_dict["valid"],
    phase="valid"
)

# %%
print("学習用データ数 : ", len(train_dataset))
print("検証用データ数 : ", len(valid_dataset))
# Out:
# 学習用データ数 :  1608
# 検証用データ数 :  439

# %%
#dataloaderを用いてミニバッチを作成
batch_size=10

train_dataloader=data.DataLoader(
    train_dataset, batch_size = batch_size, shuffle=True
)
valid_dataloader=data.DataLoader(
    valid_dataset, batch_size = batch_size//2, shuffle=True
)

dataloader_dict={
    'train': train_dataloader, 
    'valid': valid_dataloader
}
print(dataloader_dict)
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader object at 0x00000207FCC03610>, 'valid': <torch.utils.data.dataloader.DataLoader object at 0x00000207FCC035E0>}

# %%
# パラメータ名の確認
for name, param in model.named_parameters():
    print('name : ', name)
print("-------")
for name, param in mymodel.named_parameters():
    print("name : ",name)
#print(mymodel.parameters())
# Out:
# name :  features.0.weight
# name :  features.0.bias
# name :  features.3.weight
# name :  features.3.bias
# name :  features.6.weight
# name :  features.6.bias
# name :  features.8.weight
# name :  features.8.bias
# name :  features.11.weight
# name :  features.11.bias
# name :  features.13.weight
# name :  features.13.bias
# name :  embeddings.0.weight
# name :  embeddings.0.bias
# name :  embeddings.2.weight
# name :  embeddings.2.bias
# name :  embeddings.4.weight
# name :  embeddings.4.bias
# name :  pproc.pca_eigen_vectors
# name :  pproc.pca_means
# -------
# name :  classfilter.0.weight
# name :  classfilter.0.bias
# name :  classfilter.2.weight
# name :  classfilter.2.bias

# %%
#学習させるパラメータを格納
params_to_update=[]
#学習させるパラメータ名
update_param_names=['classfilter.0.weight', 'classfilter.0.bias', 'classfilter.2.weight','classfilter.2.bias']

#対象以外は購買計算をせず、変化しないようにもする
for name,param in mymodel.named_parameters():
    if name in update_param_names:
        param.requires_grad = True
        params_to_update.append(param)
        print("name : ",name)
    else:
        param.requires_grad = False
# Out:
# name :  classfilter.0.weight
# name :  classfilter.0.bias
# name :  classfilter.2.weight
# name :  classfilter.2.bias

# %%
import torch.optim as optim
#勾配計算手法?
#optimizer = optim.SGD(params_to_update, lr=0.01)
optimizer = optim.SGD(params_to_update, lr=0.01)

# %%
#エポック数
num_epochs=100
x=[]
y=[]
for epoch in range(num_epochs):
    print('Epoch {}/{}'.format(epoch+1,num_epochs))
    
    for phase in ['train','valid']:
        if phase == 'train':
            mymodel.train()#学習モード
        else:
            mymodel.eval()#検証モード
    
        #epoch全体の損失の輪と正解数
        epoch_loss=0.0
        epoch_corrects=0
        
        count=0.0
        #print(phase)
        for inputs, labels in dataloader_dict[phase]:
            #入力の確認
            #print(len(inputs),len(labels))
            #optimizer?を初期化?する?
            optimizer.zero_grad()


            with torch.set_grad_enabled(phase=='train'):

                out1=model(inputs)
                outputs=mymodel(out1)

                #labelsをcudaに
                labels=labels.to(device)

                #損失関数を計算
                loss=criterion(outputs, labels)
                #ラベルを予測
                _,preds = torch.max(outputs,1)
                
                #訓練時は逆伝搬の計算
                if phase == "train":
                    #逆伝搬
                    loss.backward()
                    
                    #パラメータ更新
                    optimizer.step()
                
                #イテレーション結果の計算
                #lossの合計を更新
                #pytorchの使用上バッチ内の平均lossが計算されているのでデータ数をかけて合計にする
                #損失和を「全データの損失/データ数」で求めるせいらしい?
                #print(len(inputs))
                epoch_loss += loss.item() * inputs.size(0)
                
                #正解数の合計を更新
                epoch_corrects += torch.sum(preds == labels.data)

        #epochのlossと正解数の表示
        epoch_loss=epoch_loss/len(dataloader_dict[phase])
        epoch_acc=epoch_corrects.double()/len(dataloader_dict[phase].dataset)

        print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))
        x.append(epoch_acc)
        y.append(epoch)
# Out:
# Epoch 1/100
# C:\Users\hase\anaconda3\lib\site-packages\torch\nn\modules\container.py:119: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# train Loss: 16.0740 Acc: 0.2257
# valid Loss: 7.9851 Acc: 0.2916
# Epoch 2/100
# train Loss: 15.9126 Acc: 0.3097
# valid Loss: 7.9474 Acc: 0.2369
# Epoch 3/100
# train Loss: 15.7471 Acc: 0.3060
# valid Loss: 7.8920 Acc: 0.3144
# Epoch 4/100
# train Loss: 15.5826 Acc: 0.3619
# valid Loss: 7.8078 Acc: 0.3394
# Epoch 5/100
# train Loss: 15.4011 Acc: 0.3738
# valid Loss: 7.7251 Acc: 0.3326
# Epoch 6/100
# train Loss: 15.1542 Acc: 0.3937
# valid Loss: 7.6590 Acc: 0.3599
# Epoch 7/100
# train Loss: 15.0169 Acc: 0.3881
# valid Loss: 7.5756 Acc: 0.3645
# Epoch 8/100
# train Loss: 14.8500 Acc: 0.3999
# valid Loss: 7.5590 Acc: 0.3736
# Epoch 9/100
# train Loss: 14.7140 Acc: 0.4465
# valid Loss: 7.5224 Acc: 0.4191
# Epoch 10/100
# train Loss: 14.6119 Acc: 0.4652
# valid Loss: 7.4841 Acc: 0.4123
# Epoch 11/100
# train Loss: 14.5165 Acc: 0.4876
# valid Loss: 7.4816 Acc: 0.4100
# Epoch 12/100
# train Loss: 14.3843 Acc: 0.5012
# valid Loss: 7.4132 Acc: 0.4260
# Epoch 13/100
# train Loss: 14.2562 Acc: 0.5081
# valid Loss: 7.3645 Acc: 0.4579
# Epoch 14/100
# train Loss: 14.1379 Acc: 0.5093
# valid Loss: 7.3422 Acc: 0.4419
# Epoch 15/100
# train Loss: 14.0236 Acc: 0.5199
# valid Loss: 7.3268 Acc: 0.4374
# Epoch 16/100
# train Loss: 14.0016 Acc: 0.5236
# valid Loss: 7.3438 Acc: 0.4647
# Epoch 17/100
# train Loss: 13.9656 Acc: 0.5255
# valid Loss: 7.3568 Acc: 0.4374
# Epoch 18/100
# train Loss: 13.8818 Acc: 0.5299
# valid Loss: 7.3081 Acc: 0.4533
# Epoch 19/100
# train Loss: 13.7577 Acc: 0.5417
# valid Loss: 7.3070 Acc: 0.4601
# Epoch 20/100
# train Loss: 13.7495 Acc: 0.5510
# valid Loss: 7.3087 Acc: 0.4510
# Epoch 21/100
# train Loss: 13.7154 Acc: 0.5616
# valid Loss: 7.2284 Acc: 0.4738
# Epoch 22/100
# train Loss: 13.6879 Acc: 0.5641
# valid Loss: 7.3134 Acc: 0.4374
# Epoch 23/100
# train Loss: 13.7715 Acc: 0.5491
# valid Loss: 7.3127 Acc: 0.4396
# Epoch 24/100
# train Loss: 13.7232 Acc: 0.5616
# valid Loss: 7.2387 Acc: 0.4510
# Epoch 25/100
# train Loss: 13.5993 Acc: 0.5672
# valid Loss: 7.2578 Acc: 0.4784
# Epoch 26/100
# train Loss: 13.6400 Acc: 0.5746
# valid Loss: 7.2090 Acc: 0.4852
# Epoch 27/100
# train Loss: 13.5530 Acc: 0.5802
# valid Loss: 7.2392 Acc: 0.4829
# Epoch 28/100
# train Loss: 13.4666 Acc: 0.5914
# valid Loss: 7.1784 Acc: 0.4715
# Epoch 29/100
# train Loss: 13.3755 Acc: 0.5908
# valid Loss: 7.1980 Acc: 0.4761
# Epoch 30/100
# train Loss: 13.3426 Acc: 0.6070
# valid Loss: 7.2592 Acc: 0.4556
# Epoch 31/100
# train Loss: 13.2934 Acc: 0.6045
# valid Loss: 7.2303 Acc: 0.4442
# Epoch 32/100
# train Loss: 13.2547 Acc: 0.5945
# valid Loss: 7.1727 Acc: 0.4396
# Epoch 33/100
# train Loss: 13.2743 Acc: 0.6051
# valid Loss: 7.1829 Acc: 0.4852
# Epoch 34/100
# train Loss: 13.2506 Acc: 0.6014
# valid Loss: 7.2158 Acc: 0.4670
# Epoch 35/100
# train Loss: 13.2981 Acc: 0.5889
# valid Loss: 7.1785 Acc: 0.4806
# Epoch 36/100
# train Loss: 13.2066 Acc: 0.6020
# valid Loss: 7.1467 Acc: 0.4875
# Epoch 37/100
# train Loss: 13.2098 Acc: 0.6113
# valid Loss: 7.1327 Acc: 0.4852
# Epoch 38/100
# train Loss: 13.1604 Acc: 0.6045
# valid Loss: 7.1184 Acc: 0.4806
# Epoch 39/100
# train Loss: 13.1198 Acc: 0.6076
# valid Loss: 7.1069 Acc: 0.4852
# Epoch 40/100
# train Loss: 13.0622 Acc: 0.6188
# valid Loss: 7.0911 Acc: 0.4897
# Epoch 41/100
# train Loss: 13.0484 Acc: 0.6119
# valid Loss: 7.1087 Acc: 0.4738
# Epoch 42/100
# train Loss: 13.1092 Acc: 0.6095
# valid Loss: 7.2324 Acc: 0.4487
# Epoch 43/100
# train Loss: 13.1685 Acc: 0.6107
# valid Loss: 7.1181 Acc: 0.4875
# Epoch 44/100
# train Loss: 12.9731 Acc: 0.6200
# valid Loss: 7.1035 Acc: 0.4806
# Epoch 45/100
# train Loss: 13.0516 Acc: 0.6182
# valid Loss: 7.1587 Acc: 0.4556
# Epoch 46/100
# train Loss: 12.9672 Acc: 0.6281
# valid Loss: 7.1267 Acc: 0.4692
# Epoch 47/100
# train Loss: 13.0614 Acc: 0.6119
# valid Loss: 7.1106 Acc: 0.4784
# Epoch 48/100
# train Loss: 13.0844 Acc: 0.6150
# valid Loss: 7.1835 Acc: 0.4510
# Epoch 49/100
# train Loss: 13.0426 Acc: 0.6113
# valid Loss: 7.1630 Acc: 0.4784
# Epoch 50/100
# train Loss: 12.9684 Acc: 0.6144
# valid Loss: 7.0952 Acc: 0.4806
# Epoch 51/100
# train Loss: 13.0151 Acc: 0.6287
# valid Loss: 7.1982 Acc: 0.4738
# Epoch 52/100
# train Loss: 13.1076 Acc: 0.6287
# valid Loss: 7.2494 Acc: 0.4396
# Epoch 53/100
# train Loss: 13.1133 Acc: 0.6175
# valid Loss: 7.1354 Acc: 0.4670
# Epoch 54/100
# train Loss: 12.9201 Acc: 0.6294
# valid Loss: 7.1431 Acc: 0.4670
# Epoch 55/100
# train Loss: 12.9588 Acc: 0.6101
# valid Loss: 7.1324 Acc: 0.4738
# Epoch 56/100
# train Loss: 13.0471 Acc: 0.6107
# valid Loss: 7.1877 Acc: 0.4829
# Epoch 57/100
# train Loss: 13.0630 Acc: 0.6188
# valid Loss: 7.1347 Acc: 0.4670
# Epoch 58/100
# train Loss: 12.9607 Acc: 0.6281
# valid Loss: 7.1801 Acc: 0.4784
# Epoch 59/100
# train Loss: 12.9690 Acc: 0.6300
# valid Loss: 7.1546 Acc: 0.4761
# Epoch 60/100
# train Loss: 12.9466 Acc: 0.6250
# valid Loss: 7.2039 Acc: 0.4601
# Epoch 61/100
# train Loss: 13.0482 Acc: 0.6169
# valid Loss: 7.1552 Acc: 0.4784
# Epoch 62/100
# train Loss: 13.0027 Acc: 0.6262
# valid Loss: 7.1969 Acc: 0.4875
# Epoch 63/100
# train Loss: 12.9777 Acc: 0.6175
# valid Loss: 7.3067 Acc: 0.4237
# Epoch 64/100
# train Loss: 12.9552 Acc: 0.6144
# valid Loss: 7.1018 Acc: 0.4852
# Epoch 65/100
# train Loss: 13.0234 Acc: 0.6150
# valid Loss: 7.1612 Acc: 0.4715
# Epoch 66/100
# train Loss: 13.0029 Acc: 0.6026
# valid Loss: 7.1841 Acc: 0.4806
# Epoch 67/100
# train Loss: 13.0018 Acc: 0.6188
# valid Loss: 7.1228 Acc: 0.5057
# Epoch 68/100
# train Loss: 12.9885 Acc: 0.6200
# valid Loss: 7.2147 Acc: 0.4784
# Epoch 69/100
# train Loss: 13.0073 Acc: 0.6262
# valid Loss: 7.2542 Acc: 0.4374
# Epoch 70/100
# train Loss: 12.9876 Acc: 0.6219
# valid Loss: 7.1163 Acc: 0.4579
# Epoch 71/100
# train Loss: 12.8477 Acc: 0.6238
# valid Loss: 7.1312 Acc: 0.4624
# Epoch 72/100
# train Loss: 12.9554 Acc: 0.6144
# valid Loss: 7.1406 Acc: 0.4784
# Epoch 73/100
# train Loss: 12.8885 Acc: 0.6213
# valid Loss: 7.1575 Acc: 0.4897
# Epoch 74/100
# train Loss: 12.9271 Acc: 0.6200
# valid Loss: 7.1101 Acc: 0.4647
# Epoch 75/100
# train Loss: 12.9318 Acc: 0.6188
# valid Loss: 7.2357 Acc: 0.4419
# Epoch 76/100
# train Loss: 12.9548 Acc: 0.6238
# valid Loss: 7.1630 Acc: 0.4670
# Epoch 77/100
# train Loss: 12.8809 Acc: 0.6337
# valid Loss: 7.2350 Acc: 0.4282
# Epoch 78/100
# train Loss: 12.8339 Acc: 0.6424
# valid Loss: 7.1576 Acc: 0.4556
# Epoch 79/100
# train Loss: 12.9244 Acc: 0.6238
# valid Loss: 7.1713 Acc: 0.4533
# Epoch 80/100
# train Loss: 12.8358 Acc: 0.6362
# valid Loss: 7.0997 Acc: 0.4989
# Epoch 81/100
# train Loss: 12.8651 Acc: 0.6200
# valid Loss: 7.1723 Acc: 0.4533
# Epoch 82/100
# train Loss: 12.8081 Acc: 0.6275
# valid Loss: 7.2068 Acc: 0.4556
# Epoch 83/100
# train Loss: 12.9919 Acc: 0.6132
# valid Loss: 7.1666 Acc: 0.4715
# Epoch 84/100
# train Loss: 12.8976 Acc: 0.6262
# valid Loss: 7.2186 Acc: 0.4465
# Epoch 85/100
# train Loss: 12.9674 Acc: 0.6150
# valid Loss: 7.2119 Acc: 0.4692
# Epoch 86/100
# train Loss: 12.8504 Acc: 0.6362
# valid Loss: 7.2225 Acc: 0.4510
# Epoch 87/100
# train Loss: 12.8704 Acc: 0.6107
# valid Loss: 7.1597 Acc: 0.4943
# Epoch 88/100
# train Loss: 12.7352 Acc: 0.6381
# valid Loss: 7.1320 Acc: 0.4692
# Epoch 89/100
# train Loss: 12.7462 Acc: 0.6362
# valid Loss: 7.2296 Acc: 0.4579
# Epoch 90/100
# train Loss: 12.8475 Acc: 0.6281
# valid Loss: 7.1863 Acc: 0.4556
# Epoch 91/100
# train Loss: 12.8510 Acc: 0.6244
# valid Loss: 7.2355 Acc: 0.4419
# Epoch 92/100
# train Loss: 12.7481 Acc: 0.6238
# valid Loss: 7.1577 Acc: 0.4579
# Epoch 93/100
# train Loss: 12.8086 Acc: 0.6225
# valid Loss: 7.1392 Acc: 0.4784
# Epoch 94/100
# train Loss: 12.7418 Acc: 0.6387
# valid Loss: 7.1956 Acc: 0.4829
# Epoch 95/100
# train Loss: 13.0388 Acc: 0.6287
# valid Loss: 7.2674 Acc: 0.4556
# Epoch 96/100
# train Loss: 12.7930 Acc: 0.6437
# valid Loss: 7.2056 Acc: 0.4374
# Epoch 97/100
# train Loss: 12.8457 Acc: 0.6250
# valid Loss: 7.2807 Acc: 0.4328
# Epoch 98/100
# train Loss: 12.8700 Acc: 0.6269
# valid Loss: 7.2889 Acc: 0.4282
# Epoch 99/100
# train Loss: 12.8443 Acc: 0.6343
# valid Loss: 7.2776 Acc: 0.4510
# Epoch 100/100
# train Loss: 12.7571 Acc: 0.6350
# valid Loss: 7.1604 Acc: 0.4624

# %%
plt.plot(y[::2],[i.tolist() for i in x][::2], label="train", color ="Green")
plt.plot(y[::2],[i.tolist() for i in x][1::2], label="valid", color ="Blue")
plt.legend(loc='upper left')
