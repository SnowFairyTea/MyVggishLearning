# %%
from mylibs.dataloader_dict import *
from mylibs.trainer import *
import torch
import torch.nn as nn
import os
import torch.utils.data as data
from importlib import import_module
import matplotlib.pyplot as plt
import torch.optim as optim
import copy

vggish_input=import_module(".torchvggish.vggish_input","torchvggish-master_changed")
use_pretrained = True

#GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))
# Out:
# vggish/embedding:0
# vggish/embedding:0
# Using cuda device

# %%
labels=["Car","Emergency vehicle","Motor vehicle (road)","Water","Animal","Rail transport","Buzzer"]
mymodel=trainer(_print=False,_lr=0.01,_labels=labels,
                _classfilter=nn.Sequential(
                            nn.Linear(128,64),
                            nn.Dropout(p=0.75),
                            nn.Sigmoid(),
                            nn.Linear(64,7),
                            nn.Softmax(dim=1)),
                     _update_param_names=["embeddings.2.weight",
"embeddings.2.bias",
"embeddings.4.weight","embeddings.4.bias",'classfilter.0.weight', 'classfilter.0.bias', 
                          'classfilter.2.weight','classfilter.2.bias']
                            )
# Out:
# vggish/embedding:0

# %%
dataloader_dict=get_dataloader_dict(labels,datatype="1215_emergency",num_data=250)
# Out:
# C:\Users\hase\git\MyVggishLearning\mylibs\dataloaders ['C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\100_trainSirens100AnimalCarCivil defense sirenFire engine, fire truck (siren)MusicPolice car (siren)Speech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\100_trainSirens100CarCivil defense sirenFire engine, fire truck (siren)Police car (siren)other_MusicAnimalSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\100_trainSirens100CarCivil defense sirenFire engine, fire truck (siren)Police car (siren)Speechother_MusicAnimal.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1210_emergency100AnimalCarEmergency vehicleMusicSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1214_emergency100AnimalCarEmergency vehicleMusic.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1215_emergency250AnimalBuzzerCarEmergency vehicleMotor vehicle (road)Rail transportWater.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1215_emergency250AnimalCarEmergency vehicleGlassRail transportToolsWater.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1215_emergency250AnimalCarEmergency vehicleMusic.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1215_emergency250CarEmergency vehicleother_MusicAnimal.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1215_emergency250CarEmergency vehicleSpeechother_MusicAnimal.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1221!250AnimalCarEmergency vehicleMusic.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\1222!250AnimalCarEmergency vehicleMusic.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\177_train177AnimalCarMusicSirenSpeechVehicle.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\177_trainMusicAnimalSpeech177CarSirenother_MusicAnimalSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\267_trainMusicAnimalSpeech267CarSirenother_MusicAnimalSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\267_trainMusicAnimalSpeech5AnimalCarMusicSirenSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\267_trainMusicAnimalSpeech5CarSirenother_MusicAnimalSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\evalMusicSilenceSirenSpeechVehicleWind.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\oikomi_train500CarSirenSpeechother_MusicAnimal.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\oikomi_trainMusicAnimalSpeech500CarSirenother_MusicAnimalSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\train177AnimalCarMusicSirenSpeechVehicle.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\train300AnimalCarDogMusicSirenSpeechVehicleWind.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\trainMusic100Speech100.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\trainMusic10Speech10.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\trainMusicSilenceSirenSpeechVehicle.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\trainMusicSilenceSirenSpeechVehicleWind.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\trainMusicSirenSpeechVehicle.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\trainMusicSpeech.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\train_print_test177AnimalCarMusicSirenSpeechVehicle.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\train_print_test500AnimalCarMusicSirenSpeechVehicle.jb', 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\dataloaders\\train_test177AnimalCarMusicSirenSpeechVehicle.jb']
# joblib.loadします
# train用データの数：548
# valid用データの数：499

# %%
mymodel.train(dataloader_dict,_print=True,_num_epochs=3000)
#mymodel.loadModel(addname="1_177datas")
# Out:
# Epoch 1/3000
# epoch_loss:1.9380298923069275
# epoch_corrects:1249.0,epochsize:5472
# train Loss: 1.938030 Acc: 0.228253
# epoch_loss:1.9418451357289324
# epoch_corrects:1000.0,epochsize:4988
# valid Loss: 1.941845 Acc: 0.200481
# Epoch 2/3000
# epoch_loss:1.9370549112035518
# epoch_corrects:1249.0,epochsize:5472
# train Loss: 1.937055 Acc: 0.228253
# epoch_loss:1.94074811563553
# epoch_corrects:1000.0,epochsize:4988
# valid Loss: 1.940748 Acc: 0.200481
# Epoch 3/3000
# epoch_loss:1.9357286638945166
# epoch_corrects:1251.0,epochsize:5472
# train Loss: 1.935729 Acc: 0.228618
# epoch_loss:1.939582414692081
# epoch_corrects:1000.0,epochsize:4988
# valid Loss: 1.939582 Acc: 0.200481
# Epoch 4/3000
# epoch_loss:1.934551128474941
# epoch_corrects:1252.0,epochsize:5472
# train Loss: 1.934551 Acc: 0.228801
# epoch_loss:1.9383891546544594
# epoch_corrects:1000.0,epochsize:4988
# valid Loss: 1.938389 Acc: 0.200481
# Epoch 5/3000
# epoch_loss:1.9334847318847277
# epoch_corrects:1257.0,epochsize:5472
# train Loss: 1.933485 Acc: 0.229715
# epoch_loss:1.9371197424894728
# epoch_corrects:1000.0,epochsize:4988
# valid Loss: 1.937120 Acc: 0.200481
# Epoch 6/3000
# epoch_loss:1.9318620875826356
# epoch_corrects:1271.0,epochsize:5472
# train Loss: 1.931862 Acc: 0.232273
# epoch_loss:1.935740885250838
# epoch_corrects:1000.0,epochsize:4988
# valid Loss: 1.935741 Acc: 0.200481
# Epoch 7/3000
# epoch_loss:1.9306777647277067
# epoch_corrects:1288.0,epochsize:5472
# train Loss: 1.930678 Acc: 0.235380
# epoch_loss:1.9343023885701691
# epoch_corrects:1017.0,epochsize:4988
# valid Loss: 1.934302 Acc: 0.203889
# Epoch 8/3000
# epoch_loss:1.9295166254217861
# epoch_corrects:1307.0,epochsize:5472
# train Loss: 1.929517 Acc: 0.238852
# epoch_loss:1.9328082603459944
# epoch_corrects:1088.0,epochsize:4988
# valid Loss: 1.932808 Acc: 0.218123
# Epoch 9/3000
# epoch_loss:1.9281548284299193
# epoch_corrects:1357.0,epochsize:5472
# train Loss: 1.928155 Acc: 0.247990
# epoch_loss:1.931257165424711
# epoch_corrects:1177.0,epochsize:4988
# valid Loss: 1.931257 Acc: 0.235966
# Epoch 10/3000
# epoch_loss:1.9269984857729303
# epoch_corrects:1384.0,epochsize:5472
# train Loss: 1.926998 Acc: 0.252924
# epoch_loss:1.9296420932580876
# epoch_corrects:1259.0,epochsize:4988
# valid Loss: 1.929642 Acc: 0.252406
# Epoch 11/3000
# epoch_loss:1.9255696179573996
# epoch_corrects:1449.0,epochsize:5472
# train Loss: 1.925570 Acc: 0.264803
# epoch_loss:1.9279900873386104
# epoch_corrects:1330.0,epochsize:4988
# valid Loss: 1.927990 Acc: 0.266640
# Epoch 12/3000
# epoch_loss:1.9243309635952202
# epoch_corrects:1492.0,epochsize:5472
# train Loss: 1.924331 Acc: 0.272661
# epoch_loss:1.9263084196241358
# epoch_corrects:1397.0,epochsize:4988
# valid Loss: 1.926308 Acc: 0.280072
# Epoch 13/3000
# epoch_loss:1.9231635443212693
# epoch_corrects:1506.0,epochsize:5472
# train Loss: 1.923164 Acc: 0.275219
# epoch_loss:1.9246224792078197
# epoch_corrects:1446.0,epochsize:4988
# valid Loss: 1.924622 Acc: 0.289896
# Epoch 14/3000
# epoch_loss:1.9222463236479035
# epoch_corrects:1538.0,epochsize:5472
# train Loss: 1.922246 Acc: 0.281067
# epoch_loss:1.9229438276222064
# epoch_corrects:1491.0,epochsize:4988
# valid Loss: 1.922944 Acc: 0.298917
# Epoch 15/3000
# epoch_loss:1.9215497899125193
# epoch_corrects:1570.0,epochsize:5472
# train Loss: 1.921550 Acc: 0.286915
# epoch_loss:1.921290899479781
# epoch_corrects:1529.0,epochsize:4988
# valid Loss: 1.921291 Acc: 0.306536
# Epoch 16/3000
# epoch_loss:1.9203075102546758
# epoch_corrects:1593.0,epochsize:5472
# train Loss: 1.920308 Acc: 0.291118
# epoch_loss:1.9196343114114132
# epoch_corrects:1559.0,epochsize:4988
# valid Loss: 1.919634 Acc: 0.312550
# Epoch 17/3000
# epoch_loss:1.9192627689294648
# epoch_corrects:1640.0,epochsize:5472
# train Loss: 1.919263 Acc: 0.299708
# epoch_loss:1.917963023461049
# epoch_corrects:1601.0,epochsize:4988
# valid Loss: 1.917963 Acc: 0.320970
# Epoch 18/3000
# epoch_loss:1.9184715354390312
# epoch_corrects:1665.0,epochsize:5472
# train Loss: 1.918472 Acc: 0.304276
# epoch_loss:1.9163057180816112
# epoch_corrects:1631.0,epochsize:4988
# valid Loss: 1.916306 Acc: 0.326985
# Epoch 19/3000
# epoch_loss:1.9174027569722711
# epoch_corrects:1679.0,epochsize:5472
# train Loss: 1.917403 Acc: 0.306835
# epoch_loss:1.9146402720078144
# epoch_corrects:1666.0,epochsize:4988
# valid Loss: 1.914640 Acc: 0.334002
# Epoch 20/3000
# epoch_loss:1.9166168645895711
# epoch_corrects:1698.0,epochsize:5472
# train Loss: 1.916617 Acc: 0.310307
# epoch_loss:1.9130158470263936
# epoch_corrects:1707.0,epochsize:4988
# valid Loss: 1.913016 Acc: 0.342221
# Epoch 21/3000
# epoch_loss:1.9158937452219382
# epoch_corrects:1737.0,epochsize:5472
# train Loss: 1.915894 Acc: 0.317434
# epoch_loss:1.911417505171362
# epoch_corrects:1736.0,epochsize:4988
# valid Loss: 1.911418 Acc: 0.348035
# Epoch 22/3000
# epoch_loss:1.915323785871093
# epoch_corrects:1763.0,epochsize:5472
# train Loss: 1.915324 Acc: 0.322186
# epoch_loss:1.9098463459500525
# epoch_corrects:1769.0,epochsize:4988
# valid Loss: 1.909846 Acc: 0.354651
# Epoch 23/3000
# epoch_loss:1.9145425320194478
# epoch_corrects:1805.0,epochsize:5472
# train Loss: 1.914543 Acc: 0.329861
# epoch_loss:1.9082728267289584
# epoch_corrects:1805.0,epochsize:4988
# valid Loss: 1.908273 Acc: 0.361868
# Epoch 24/3000
# epoch_loss:1.9140014199659838
# epoch_corrects:1819.0,epochsize:5472
# train Loss: 1.914001 Acc: 0.332420
# epoch_loss:1.9067565023468893
# epoch_corrects:1841.0,epochsize:4988
# valid Loss: 1.906757 Acc: 0.369086
# Epoch 25/3000
# epoch_loss:1.9136775009203375
# epoch_corrects:1810.0,epochsize:5472
# train Loss: 1.913678 Acc: 0.330775
# epoch_loss:1.9052872863309136
# epoch_corrects:1863.0,epochsize:4988
# valid Loss: 1.905287 Acc: 0.373496
# Epoch 26/3000
# epoch_loss:1.9127759528264665
# epoch_corrects:1887.0,epochsize:5472
# train Loss: 1.912776 Acc: 0.344846
# epoch_loss:1.9038162538311247
# epoch_corrects:1879.0,epochsize:4988
# valid Loss: 1.903816 Acc: 0.376704
# Epoch 27/3000
# epoch_loss:1.9121686112113863
# epoch_corrects:1886.0,epochsize:5472
# train Loss: 1.912169 Acc: 0.344664
# epoch_loss:1.9023858024391445
# epoch_corrects:1898.0,epochsize:4988
# valid Loss: 1.902386 Acc: 0.380513
# Epoch 28/3000
# epoch_loss:1.911676713205569
# epoch_corrects:1914.0,epochsize:5472
# train Loss: 1.911677 Acc: 0.349781
# epoch_loss:1.9009833297159735
# epoch_corrects:1911.0,epochsize:4988
# valid Loss: 1.900983 Acc: 0.383119
# Epoch 29/3000
# epoch_loss:1.9111278332900583
# epoch_corrects:1903.0,epochsize:5472
# train Loss: 1.911128 Acc: 0.347770
# epoch_loss:1.8996109858262797
# epoch_corrects:1927.0,epochsize:4988
# valid Loss: 1.899611 Acc: 0.386327
# Epoch 30/3000
# epoch_loss:1.910578669598925
# epoch_corrects:1939.0,epochsize:5472
# train Loss: 1.910579 Acc: 0.354349
# epoch_loss:1.898283143471792
# epoch_corrects:1949.0,epochsize:4988
# valid Loss: 1.898283 Acc: 0.390738
# Epoch 31/3000
# epoch_loss:1.9103729771504625
# epoch_corrects:1969.0,epochsize:5472
# train Loss: 1.910373 Acc: 0.359832
# epoch_loss:1.8970096576376352
# epoch_corrects:1962.0,epochsize:4988
# valid Loss: 1.897010 Acc: 0.393344
# Epoch 32/3000
# epoch_loss:1.9096440851078396
# epoch_corrects:2000.0,epochsize:5472
# train Loss: 1.909644 Acc: 0.365497
# epoch_loss:1.8957159909708747
# epoch_corrects:1969.0,epochsize:4988
# valid Loss: 1.895716 Acc: 0.394747
# Epoch 33/3000
# epoch_loss:1.9100034544516724
# epoch_corrects:1983.0,epochsize:5472
# train Loss: 1.910003 Acc: 0.362390
# epoch_loss:1.894515959185988
# epoch_corrects:1980.0,epochsize:4988
# valid Loss: 1.894516 Acc: 0.396953
# Epoch 34/3000
# epoch_loss:1.9089801800355577
# epoch_corrects:2020.0,epochsize:5472
# train Loss: 1.908980 Acc: 0.369152
# epoch_loss:1.8933112657634181
# epoch_corrects:1990.0,epochsize:4988
# valid Loss: 1.893311 Acc: 0.398957
# Epoch 35/3000
# epoch_loss:1.9087638960421434
# epoch_corrects:2039.0,epochsize:5472
# train Loss: 1.908764 Acc: 0.372624
# epoch_loss:1.8921547018726443
# epoch_corrects:1994.0,epochsize:4988
# valid Loss: 1.892155 Acc: 0.399759
# Epoch 36/3000
# epoch_loss:1.908815673263798
# epoch_corrects:2077.0,epochsize:5472
# train Loss: 1.908816 Acc: 0.379569
# epoch_loss:1.8910248388073974
# epoch_corrects:2000.0,epochsize:4988
# valid Loss: 1.891025 Acc: 0.400962
# Epoch 37/3000
# epoch_loss:1.9080418702541737
# epoch_corrects:2087.0,epochsize:5472
# train Loss: 1.908042 Acc: 0.381396
# epoch_loss:1.8899213631533582
# epoch_corrects:2015.0,epochsize:4988
# valid Loss: 1.889921 Acc: 0.403970
# Epoch 38/3000
# epoch_loss:1.9083676685889561
# epoch_corrects:2066.0,epochsize:5472
# train Loss: 1.908368 Acc: 0.377558
# epoch_loss:1.8888597813910644
# epoch_corrects:2030.0,epochsize:4988
# valid Loss: 1.888860 Acc: 0.406977
# Epoch 39/3000
# epoch_loss:1.9079336816368744
# epoch_corrects:2097.0,epochsize:5472
# train Loss: 1.907934 Acc: 0.383224
# epoch_loss:1.8878166205231055
# epoch_corrects:2038.0,epochsize:4988
# valid Loss: 1.887817 Acc: 0.408581
# Epoch 40/3000
# epoch_loss:1.9077531790785622
# epoch_corrects:2127.0,epochsize:5472
# train Loss: 1.907753 Acc: 0.388706
# epoch_loss:1.886801323034138
# epoch_corrects:2046.0,epochsize:4988
# valid Loss: 1.886801 Acc: 0.410184
# Epoch 41/3000
# epoch_loss:1.907084658611239
# epoch_corrects:2140.0,epochsize:5472
# train Loss: 1.907085 Acc: 0.391082
# epoch_loss:1.8857856480331543
# epoch_corrects:2059.0,epochsize:4988
# valid Loss: 1.885786 Acc: 0.412791
# Epoch 42/3000
# epoch_loss:1.9067335130091299
# epoch_corrects:2137.0,epochsize:5472
# train Loss: 1.906734 Acc: 0.390534
# epoch_loss:1.8847650637986093
# epoch_corrects:2067.0,epochsize:4988
# valid Loss: 1.884765 Acc: 0.414395
# Epoch 43/3000
# epoch_loss:1.9067559610856206
# epoch_corrects:2151.0,epochsize:5472
# train Loss: 1.906756 Acc: 0.393092
# epoch_loss:1.8838144938469699
# epoch_corrects:2067.0,epochsize:4988
# valid Loss: 1.883814 Acc: 0.414395
# Epoch 44/3000
# epoch_loss:1.906467578913036
# epoch_corrects:2169.0,epochsize:5472
# train Loss: 1.906468 Acc: 0.396382
# epoch_loss:1.882873226282782
# epoch_corrects:2073.0,epochsize:4988
# valid Loss: 1.882873 Acc: 0.415597
# Epoch 45/3000
# epoch_loss:1.9066767950939854
# epoch_corrects:2189.0,epochsize:5472
# train Loss: 1.906677 Acc: 0.400037
# epoch_loss:1.881941471849333
# epoch_corrects:2081.0,epochsize:4988
# valid Loss: 1.881941 Acc: 0.417201
# Epoch 46/3000
# epoch_loss:1.9064851476435076
# epoch_corrects:2182.0,epochsize:5472
# train Loss: 1.906485 Acc: 0.398757
# epoch_loss:1.8810689987042664
# epoch_corrects:2086.0,epochsize:4988
# valid Loss: 1.881069 Acc: 0.418204
# Epoch 47/3000
# epoch_loss:1.9060145714129622
# epoch_corrects:2212.0,epochsize:5472
# train Loss: 1.906015 Acc: 0.404240
# epoch_loss:1.880193727534584
# epoch_corrects:2090.0,epochsize:4988
# valid Loss: 1.880194 Acc: 0.419006
# Epoch 48/3000
# epoch_loss:1.905812840712698
# epoch_corrects:2237.0,epochsize:5472
# train Loss: 1.905813 Acc: 0.408808
# epoch_loss:1.8793178063062257
# epoch_corrects:2096.0,epochsize:4988
# valid Loss: 1.879318 Acc: 0.420209
# Epoch 49/3000
# epoch_loss:1.9054419321187757
# epoch_corrects:2232.0,epochsize:5472
# train Loss: 1.905442 Acc: 0.407895
# epoch_loss:1.878466057557532
# epoch_corrects:2101.0,epochsize:4988
# valid Loss: 1.878466 Acc: 0.421211
# Epoch 50/3000
# epoch_loss:1.905289141755355
# epoch_corrects:2255.0,epochsize:5472
# train Loss: 1.905289 Acc: 0.412098
# epoch_loss:1.87761811265586
# epoch_corrects:2105.0,epochsize:4988
# valid Loss: 1.877618 Acc: 0.422013
# Epoch 51/3000
# epoch_loss:1.9055531686770986
# epoch_corrects:2252.0,epochsize:5472
# train Loss: 1.905553 Acc: 0.411550
# epoch_loss:1.8768047374443904
# epoch_corrects:2110.0,epochsize:4988
# valid Loss: 1.876805 Acc: 0.423015
# Epoch 52/3000
# epoch_loss:1.9050247457902334
# epoch_corrects:2245.0,epochsize:5472
# train Loss: 1.905025 Acc: 0.410270
# epoch_loss:1.87599101870559
# epoch_corrects:2110.0,epochsize:4988
# valid Loss: 1.875991 Acc: 0.423015
# Epoch 53/3000
# epoch_loss:1.904718470895848
# epoch_corrects:2267.0,epochsize:5472
# train Loss: 1.904718 Acc: 0.414291
# epoch_loss:1.8751875882924989
# epoch_corrects:2115.0,epochsize:4988
# valid Loss: 1.875188 Acc: 0.424018
# Epoch 54/3000
# epoch_loss:1.905125919707686
# epoch_corrects:2253.0,epochsize:5472
# train Loss: 1.905126 Acc: 0.411732
# epoch_loss:1.874402788178674
# epoch_corrects:2117.0,epochsize:4988
# valid Loss: 1.874403 Acc: 0.424419
# Epoch 55/3000
# epoch_loss:1.9042250969779422
# epoch_corrects:2279.0,epochsize:5472
# train Loss: 1.904225 Acc: 0.416484
# epoch_loss:1.873616939271653
# epoch_corrects:2119.0,epochsize:4988
# valid Loss: 1.873617 Acc: 0.424820
# Epoch 56/3000
# epoch_loss:1.9044684392579816
# epoch_corrects:2268.0,epochsize:5472
# train Loss: 1.904468 Acc: 0.414474
# epoch_loss:1.8728749156476214
# epoch_corrects:2122.0,epochsize:4988
# valid Loss: 1.872875 Acc: 0.425421
# Epoch 57/3000
# epoch_loss:1.903927798682486
# epoch_corrects:2306.0,epochsize:5472
# train Loss: 1.903928 Acc: 0.421418
# epoch_loss:1.8720903750792828
# epoch_corrects:2124.0,epochsize:4988
# valid Loss: 1.872090 Acc: 0.425822
# Epoch 58/3000
# epoch_loss:1.9036016160110285
# epoch_corrects:2308.0,epochsize:5472
# train Loss: 1.903602 Acc: 0.421784
# epoch_loss:1.8713362007592331
# epoch_corrects:2128.0,epochsize:4988
# valid Loss: 1.871336 Acc: 0.426624
# Epoch 59/3000
# epoch_loss:1.9036521133449342
# epoch_corrects:2316.0,epochsize:5472
# train Loss: 1.903652 Acc: 0.423246
# epoch_loss:1.870603812725523
# epoch_corrects:2130.0,epochsize:4988
# valid Loss: 1.870604 Acc: 0.427025
# Epoch 60/3000
# epoch_loss:1.9041688061422772
# epoch_corrects:2319.0,epochsize:5472
# train Loss: 1.904169 Acc: 0.423794
# epoch_loss:1.8698818810290112
# epoch_corrects:2134.0,epochsize:4988
# valid Loss: 1.869882 Acc: 0.427827
# Epoch 61/3000
# epoch_loss:1.9034379634417986
# epoch_corrects:2325.0,epochsize:5472
# train Loss: 1.903438 Acc: 0.424890
# epoch_loss:1.869168028223486
# epoch_corrects:2137.0,epochsize:4988
# valid Loss: 1.869168 Acc: 0.428428
# Epoch 62/3000
# epoch_loss:1.903048738488677
# epoch_corrects:2356.0,epochsize:5472
# train Loss: 1.903049 Acc: 0.430556
# epoch_loss:1.8684671135931465
# epoch_corrects:2136.0,epochsize:4988
# valid Loss: 1.868467 Acc: 0.428228
# Epoch 63/3000
# epoch_loss:1.9033153613931255
# epoch_corrects:2329.0,epochsize:5472
# train Loss: 1.903315 Acc: 0.425621
# epoch_loss:1.8677596511511967
# epoch_corrects:2138.0,epochsize:4988
# valid Loss: 1.867760 Acc: 0.428629
# Epoch 64/3000
# epoch_loss:1.9032536145103605
# epoch_corrects:2356.0,epochsize:5472
# train Loss: 1.903254 Acc: 0.430556
# epoch_loss:1.8670912120183565
# epoch_corrects:2137.0,epochsize:4988
# valid Loss: 1.867091 Acc: 0.428428
# Epoch 65/3000
# epoch_loss:1.902898433656372
# epoch_corrects:2357.0,epochsize:5472
# train Loss: 1.902898 Acc: 0.430738
# epoch_loss:1.8664124891006573
# epoch_corrects:2140.0,epochsize:4988
# valid Loss: 1.866412 Acc: 0.429030
# Epoch 66/3000
# epoch_loss:1.9024734730608979
# epoch_corrects:2380.0,epochsize:5472
# train Loss: 1.902473 Acc: 0.434942
# epoch_loss:1.8657597982128238
# epoch_corrects:2140.0,epochsize:4988
# valid Loss: 1.865760 Acc: 0.429030
# Epoch 67/3000
# epoch_loss:1.9023068907142382
# epoch_corrects:2379.0,epochsize:5472
# train Loss: 1.902307 Acc: 0.434759
# epoch_loss:1.86510892849305
# epoch_corrects:2144.0,epochsize:4988
# valid Loss: 1.865109 Acc: 0.429832
# Epoch 68/3000
# epoch_loss:1.9023698950894394
# epoch_corrects:2361.0,epochsize:5472
# train Loss: 1.902370 Acc: 0.431469
# epoch_loss:1.8644642076113747
# epoch_corrects:2146.0,epochsize:4988
# valid Loss: 1.864464 Acc: 0.430233
# Epoch 69/3000
# epoch_loss:1.9022362575544949
# epoch_corrects:2371.0,epochsize:5472
# train Loss: 1.902236 Acc: 0.433297
# epoch_loss:1.8638262318532373
# epoch_corrects:2148.0,epochsize:4988
# valid Loss: 1.863826 Acc: 0.430634
# Epoch 70/3000
# epoch_loss:1.9020973285823537
# epoch_corrects:2379.0,epochsize:5472
# train Loss: 1.902097 Acc: 0.434759
# epoch_loss:1.863192315090152
# epoch_corrects:2149.0,epochsize:4988
# valid Loss: 1.863192 Acc: 0.430834
# Epoch 71/3000
# epoch_loss:1.9020756338423455
# epoch_corrects:2381.0,epochsize:5472
# train Loss: 1.902076 Acc: 0.435124
# epoch_loss:1.8625807760712043
# epoch_corrects:2151.0,epochsize:4988
# valid Loss: 1.862581 Acc: 0.431235
# Epoch 72/3000
# epoch_loss:1.9018968553309552
# epoch_corrects:2418.0,epochsize:5472
# train Loss: 1.901897 Acc: 0.441886
# epoch_loss:1.861985399566274
# epoch_corrects:2153.0,epochsize:4988
# valid Loss: 1.861985 Acc: 0.431636
# Epoch 73/3000
# epoch_loss:1.9021827377248228
# epoch_corrects:2369.0,epochsize:5472
# train Loss: 1.902183 Acc: 0.432931
# epoch_loss:1.861402431629903
# epoch_corrects:2156.0,epochsize:4988
# valid Loss: 1.861402 Acc: 0.432237
# Epoch 74/3000
# epoch_loss:1.9015420874395565
# epoch_corrects:2393.0,epochsize:5472
# train Loss: 1.901542 Acc: 0.437317
# epoch_loss:1.8608117917105973
# epoch_corrects:2161.0,epochsize:4988
# valid Loss: 1.860812 Acc: 0.433240
# Epoch 75/3000
# epoch_loss:1.9013954489900355
# epoch_corrects:2403.0,epochsize:5472
# train Loss: 1.901395 Acc: 0.439145
# epoch_loss:1.8602178869671886
# epoch_corrects:2163.0,epochsize:4988
# valid Loss: 1.860218 Acc: 0.433641
# Epoch 76/3000
# epoch_loss:1.901435881809533
# epoch_corrects:2393.0,epochsize:5472
# train Loss: 1.901436 Acc: 0.437317
# epoch_loss:1.8596515487267098
# epoch_corrects:2163.0,epochsize:4988
# valid Loss: 1.859652 Acc: 0.433641
# Epoch 77/3000
# epoch_loss:1.901165386476712
# epoch_corrects:2421.0,epochsize:5472
# train Loss: 1.901165 Acc: 0.442434
# epoch_loss:1.8590983376564172
# epoch_corrects:2169.0,epochsize:4988
# valid Loss: 1.859098 Acc: 0.434844
# Epoch 78/3000
# epoch_loss:1.9009338341958342
# epoch_corrects:2441.0,epochsize:5472
# train Loss: 1.900934 Acc: 0.446089
# epoch_loss:1.8585504297265647
# epoch_corrects:2171.0,epochsize:4988
# valid Loss: 1.858550 Acc: 0.435245
# Epoch 79/3000
# epoch_loss:1.900902728893255
# epoch_corrects:2407.0,epochsize:5472
# train Loss: 1.900903 Acc: 0.439876
# epoch_loss:1.8579449454306027
# epoch_corrects:2174.0,epochsize:4988
# valid Loss: 1.857945 Acc: 0.435846
# Epoch 80/3000
# epoch_loss:1.9011979826361116
# epoch_corrects:2411.0,epochsize:5472
# train Loss: 1.901198 Acc: 0.440607
# epoch_loss:1.8573997032671044
# epoch_corrects:2180.0,epochsize:4988
# valid Loss: 1.857400 Acc: 0.437049
# Epoch 81/3000
# epoch_loss:1.9010498473170208
# epoch_corrects:2428.0,epochsize:5472
# train Loss: 1.901050 Acc: 0.443713
# epoch_loss:1.8568472391429096
# epoch_corrects:2190.0,epochsize:4988
# valid Loss: 1.856847 Acc: 0.439054
# Epoch 82/3000
# epoch_loss:1.9010596016084242
# epoch_corrects:2441.0,epochsize:5472
# train Loss: 1.901060 Acc: 0.446089
# epoch_loss:1.8563158705221143
# epoch_corrects:2205.0,epochsize:4988
# valid Loss: 1.856316 Acc: 0.442061
# Epoch 83/3000
# epoch_loss:1.9008443305889766
# epoch_corrects:2435.0,epochsize:5472
# train Loss: 1.900844 Acc: 0.444993
# epoch_loss:1.8557919280091189
# epoch_corrects:2217.0,epochsize:4988
# valid Loss: 1.855792 Acc: 0.444467
# Epoch 84/3000
# epoch_loss:1.9005995449005513
# epoch_corrects:2421.0,epochsize:5472
# train Loss: 1.900600 Acc: 0.442434
# epoch_loss:1.8552389833672867
# epoch_corrects:2225.0,epochsize:4988
# valid Loss: 1.855239 Acc: 0.446071
# Epoch 85/3000
# epoch_loss:1.9006519640485446
# epoch_corrects:2429.0,epochsize:5472
# train Loss: 1.900652 Acc: 0.443896
# epoch_loss:1.8547278339134374
# epoch_corrects:2228.0,epochsize:4988
# valid Loss: 1.854728 Acc: 0.446672
# Epoch 86/3000
# epoch_loss:1.9007206017598075
# epoch_corrects:2435.0,epochsize:5472
# train Loss: 1.900721 Acc: 0.444993
# epoch_loss:1.8541914911010118
# epoch_corrects:2231.0,epochsize:4988
# valid Loss: 1.854191 Acc: 0.447273
# Epoch 87/3000
# epoch_loss:1.8996680748828672
# epoch_corrects:2447.0,epochsize:5472
# train Loss: 1.899668 Acc: 0.447186
# epoch_loss:1.8536806083624136
# epoch_corrects:2243.0,epochsize:4988
# valid Loss: 1.853681 Acc: 0.449679
# Epoch 88/3000
# epoch_loss:1.9003193508289014
# epoch_corrects:2452.0,epochsize:5472
# train Loss: 1.900319 Acc: 0.448099
# epoch_loss:1.8531595113378767
# epoch_corrects:2254.0,epochsize:4988
# valid Loss: 1.853160 Acc: 0.451885
# Epoch 89/3000
# epoch_loss:1.8998933248875434
# epoch_corrects:2431.0,epochsize:5472
# train Loss: 1.899893 Acc: 0.444262
# epoch_loss:1.8526319431704144
# epoch_corrects:2256.0,epochsize:4988
# valid Loss: 1.852632 Acc: 0.452285
# Epoch 90/3000
# epoch_loss:1.9000917359402305
# epoch_corrects:2450.0,epochsize:5472
# train Loss: 1.900092 Acc: 0.447734
# epoch_loss:1.852132646915142
# epoch_corrects:2263.0,epochsize:4988
# valid Loss: 1.852133 Acc: 0.453689
# Epoch 91/3000
# epoch_loss:1.899849161026422
# epoch_corrects:2447.0,epochsize:5472
# train Loss: 1.899849 Acc: 0.447186
# epoch_loss:1.8516330161186438
# epoch_corrects:2267.0,epochsize:4988
# valid Loss: 1.851633 Acc: 0.454491
# Epoch 92/3000
# epoch_loss:1.9000428522452277
# epoch_corrects:2447.0,epochsize:5472
# train Loss: 1.900043 Acc: 0.447186
# epoch_loss:1.8511433381028624
# epoch_corrects:2271.0,epochsize:4988
# valid Loss: 1.851143 Acc: 0.455293
# Epoch 93/3000
# epoch_loss:1.8997373631474568
# epoch_corrects:2448.0,epochsize:5472
# train Loss: 1.899737 Acc: 0.447368
# epoch_loss:1.8506648578735572
# epoch_corrects:2277.0,epochsize:4988
# valid Loss: 1.850665 Acc: 0.456496
# Epoch 94/3000
# epoch_loss:1.8993205186306386
# epoch_corrects:2461.0,epochsize:5472
# train Loss: 1.899321 Acc: 0.449744
# epoch_loss:1.8501624554371776
# epoch_corrects:2285.0,epochsize:4988
# valid Loss: 1.850162 Acc: 0.458099
# Epoch 95/3000
# epoch_loss:1.8997758235237752
# epoch_corrects:2456.0,epochsize:5472
# train Loss: 1.899776 Acc: 0.448830
# epoch_loss:1.8496880797070316
# epoch_corrects:2288.0,epochsize:4988
# valid Loss: 1.849688 Acc: 0.458701
# Epoch 96/3000
# epoch_loss:1.8996387168067939
# epoch_corrects:2488.0,epochsize:5472
# train Loss: 1.899639 Acc: 0.454678
# epoch_loss:1.8492225253687158
# epoch_corrects:2295.0,epochsize:4988
# valid Loss: 1.849223 Acc: 0.460104
# Epoch 97/3000
# epoch_loss:1.899267907553946
# epoch_corrects:2451.0,epochsize:5472
# train Loss: 1.899268 Acc: 0.447917
# epoch_loss:1.8487686640086323
# epoch_corrects:2299.0,epochsize:4988
# valid Loss: 1.848769 Acc: 0.460906
# Epoch 98/3000
# epoch_loss:1.8992687739998277
# epoch_corrects:2470.0,epochsize:5472
# train Loss: 1.899269 Acc: 0.451389
# epoch_loss:1.8483151819291073
# epoch_corrects:2307.0,epochsize:4988
# valid Loss: 1.848315 Acc: 0.462510
# Epoch 99/3000
# epoch_loss:1.8997137334785963
# epoch_corrects:2468.0,epochsize:5472
# train Loss: 1.899714 Acc: 0.451023
# epoch_loss:1.8478430517692994
# epoch_corrects:2307.0,epochsize:4988
# valid Loss: 1.847843 Acc: 0.462510
# Epoch 100/3000
# epoch_loss:1.8990541149736846
# epoch_corrects:2495.0,epochsize:5472
# train Loss: 1.899054 Acc: 0.455958
# epoch_loss:1.8473711855524333
# epoch_corrects:2315.0,epochsize:4988
# valid Loss: 1.847371 Acc: 0.464114
# Epoch 101/3000
# epoch_loss:1.8989191210409353
# epoch_corrects:2483.0,epochsize:5472
# train Loss: 1.898919 Acc: 0.453765
# epoch_loss:1.8469152827213169
# epoch_corrects:2320.0,epochsize:4988
# valid Loss: 1.846915 Acc: 0.465116
# Epoch 102/3000
# epoch_loss:1.8990075965112412
# epoch_corrects:2501.0,epochsize:5472
# train Loss: 1.899008 Acc: 0.457054
# epoch_loss:1.8464752181396547
# epoch_corrects:2326.0,epochsize:4988
# valid Loss: 1.846475 Acc: 0.466319
# Epoch 103/3000
# epoch_loss:1.8990108799951815
# epoch_corrects:2488.0,epochsize:5472
# train Loss: 1.899011 Acc: 0.454678
# epoch_loss:1.8460181537588405
# epoch_corrects:2332.0,epochsize:4988
# valid Loss: 1.846018 Acc: 0.467522
# Epoch 104/3000
# epoch_loss:1.8987983713983094
# epoch_corrects:2503.0,epochsize:5472
# train Loss: 1.898798 Acc: 0.457420
# epoch_loss:1.8455763336363658
# epoch_corrects:2336.0,epochsize:4988
# valid Loss: 1.845576 Acc: 0.468324
# Epoch 105/3000
# epoch_loss:1.898842377620831
# epoch_corrects:2507.0,epochsize:5472
# train Loss: 1.898842 Acc: 0.458151
# epoch_loss:1.8451479108408153
# epoch_corrects:2338.0,epochsize:4988
# valid Loss: 1.845148 Acc: 0.468725
# Epoch 106/3000
# epoch_loss:1.8987373446076237
# epoch_corrects:2499.0,epochsize:5472
# train Loss: 1.898737 Acc: 0.456689
# epoch_loss:1.844737784807072
# epoch_corrects:2337.0,epochsize:4988
# valid Loss: 1.844738 Acc: 0.468524
# Epoch 107/3000
# epoch_loss:1.8984655335284115
# epoch_corrects:2484.0,epochsize:5472
# train Loss: 1.898466 Acc: 0.453947
# epoch_loss:1.8442825803588463
# epoch_corrects:2340.0,epochsize:4988
# valid Loss: 1.844283 Acc: 0.469126
# Epoch 108/3000
# epoch_loss:1.897930614824532
# epoch_corrects:2497.0,epochsize:5472
# train Loss: 1.897931 Acc: 0.456323
# epoch_loss:1.8438172957948809
# epoch_corrects:2345.0,epochsize:4988
# valid Loss: 1.843817 Acc: 0.470128
# Epoch 109/3000
# epoch_loss:1.898131203973851
# epoch_corrects:2509.0,epochsize:5472
# train Loss: 1.898131 Acc: 0.458516
# epoch_loss:1.8433801190032897
# epoch_corrects:2346.0,epochsize:4988
# valid Loss: 1.843380 Acc: 0.470329
# Epoch 110/3000
# epoch_loss:1.8980795023472685
# epoch_corrects:2524.0,epochsize:5472
# train Loss: 1.898080 Acc: 0.461257
# epoch_loss:1.842938115239239
# epoch_corrects:2351.0,epochsize:4988
# valid Loss: 1.842938 Acc: 0.471331
# Epoch 111/3000
# epoch_loss:1.897878789326601
# epoch_corrects:2531.0,epochsize:5472
# train Loss: 1.897879 Acc: 0.462537
# epoch_loss:1.842487756357063
# epoch_corrects:2352.0,epochsize:4988
# valid Loss: 1.842488 Acc: 0.471532
# Epoch 112/3000
# epoch_loss:1.8983082775658333
# epoch_corrects:2508.0,epochsize:5472
# train Loss: 1.898308 Acc: 0.458333
# epoch_loss:1.8420495577783897
# epoch_corrects:2350.0,epochsize:4988
# valid Loss: 1.842050 Acc: 0.471131
# Epoch 113/3000
# epoch_loss:1.8983370624700484
# epoch_corrects:2517.0,epochsize:5472
# train Loss: 1.898337 Acc: 0.459978
# epoch_loss:1.8416050655323692
# epoch_corrects:2351.0,epochsize:4988
# valid Loss: 1.841605 Acc: 0.471331
# Epoch 114/3000
# epoch_loss:1.8976135038231547
# epoch_corrects:2516.0,epochsize:5472
# train Loss: 1.897614 Acc: 0.459795
# epoch_loss:1.8411762367369369
# epoch_corrects:2355.0,epochsize:4988
# valid Loss: 1.841176 Acc: 0.472133
# Epoch 115/3000
# epoch_loss:1.897623225088008
# epoch_corrects:2550.0,epochsize:5472
# train Loss: 1.897623 Acc: 0.466009
# epoch_loss:1.8407315470355936
# epoch_corrects:2358.0,epochsize:4988
# valid Loss: 1.840732 Acc: 0.472735
# Epoch 116/3000
# epoch_loss:1.8978283071988507
# epoch_corrects:2551.0,epochsize:5472
# train Loss: 1.897828 Acc: 0.466192
# epoch_loss:1.8403082025366586
# epoch_corrects:2361.0,epochsize:4988
# valid Loss: 1.840308 Acc: 0.473336
# Epoch 117/3000
# epoch_loss:1.8977463144743651
# epoch_corrects:2539.0,epochsize:5472
# train Loss: 1.897746 Acc: 0.463999
# epoch_loss:1.839863460018048
# epoch_corrects:2363.0,epochsize:4988
# valid Loss: 1.839863 Acc: 0.473737
# Epoch 118/3000
# epoch_loss:1.897839494659538
# epoch_corrects:2506.0,epochsize:5472
# train Loss: 1.897839 Acc: 0.457968
# epoch_loss:1.8394383769467437
# epoch_corrects:2366.0,epochsize:4988
# valid Loss: 1.839438 Acc: 0.474338
# Epoch 119/3000
# epoch_loss:1.8978089710686639
# epoch_corrects:2526.0,epochsize:5472
# train Loss: 1.897809 Acc: 0.461623
# epoch_loss:1.839009947029227
# epoch_corrects:2373.0,epochsize:4988
# valid Loss: 1.839010 Acc: 0.475742
# Epoch 120/3000
# epoch_loss:1.897809320374539
# epoch_corrects:2513.0,epochsize:5472
# train Loss: 1.897809 Acc: 0.459247
# epoch_loss:1.8385825589263354
# epoch_corrects:2376.0,epochsize:4988
# valid Loss: 1.838583 Acc: 0.476343
# Epoch 121/3000
# epoch_loss:1.8972731442217938
# epoch_corrects:2555.0,epochsize:5472
# train Loss: 1.897273 Acc: 0.466923
# epoch_loss:1.8381550300092628
# epoch_corrects:2379.0,epochsize:4988
# valid Loss: 1.838155 Acc: 0.476945
# Epoch 122/3000
# epoch_loss:1.8972660743615084
# epoch_corrects:2538.0,epochsize:5472
# train Loss: 1.897266 Acc: 0.463816
# epoch_loss:1.8377287605330765
# epoch_corrects:2379.0,epochsize:4988
# valid Loss: 1.837729 Acc: 0.476945
# Epoch 123/3000
# epoch_loss:1.8975287611372986
# epoch_corrects:2549.0,epochsize:5472
# train Loss: 1.897529 Acc: 0.465826
# epoch_loss:1.8373034543386917
# epoch_corrects:2381.0,epochsize:4988
# valid Loss: 1.837303 Acc: 0.477346
# Epoch 124/3000
# epoch_loss:1.8972468373981135
# epoch_corrects:2522.0,epochsize:5472
# train Loss: 1.897247 Acc: 0.460892
# epoch_loss:1.8368777499355693
# epoch_corrects:2382.0,epochsize:4988
# valid Loss: 1.836878 Acc: 0.477546
# Epoch 125/3000
# epoch_loss:1.8970837723354848
# epoch_corrects:2551.0,epochsize:5472
# train Loss: 1.897084 Acc: 0.466192
# epoch_loss:1.8364754690106813
# epoch_corrects:2382.0,epochsize:4988
# valid Loss: 1.836475 Acc: 0.477546
# Epoch 126/3000
# epoch_loss:1.8970339947015222
# epoch_corrects:2543.0,epochsize:5472
# train Loss: 1.897034 Acc: 0.464730
# epoch_loss:1.8360538174366128
# epoch_corrects:2387.0,epochsize:4988
# valid Loss: 1.836054 Acc: 0.478549
# Epoch 127/3000
# epoch_loss:1.8971630536150514
# epoch_corrects:2554.0,epochsize:5472
# train Loss: 1.897163 Acc: 0.466740
# epoch_loss:1.8356476213899535
# epoch_corrects:2392.0,epochsize:4988
# valid Loss: 1.835648 Acc: 0.479551
# Epoch 128/3000
# epoch_loss:1.8966670256783391
# epoch_corrects:2563.0,epochsize:5472
# train Loss: 1.896667 Acc: 0.468385
# epoch_loss:1.8352457189808489
# epoch_corrects:2394.0,epochsize:4988
# valid Loss: 1.835246 Acc: 0.479952
# Epoch 129/3000
# epoch_loss:1.897372571217735
# epoch_corrects:2547.0,epochsize:5472
# train Loss: 1.897373 Acc: 0.465461
# epoch_loss:1.8348527890066195
# epoch_corrects:2396.0,epochsize:4988
# valid Loss: 1.834853 Acc: 0.480353
# Epoch 130/3000
# epoch_loss:1.8971539709215972
# epoch_corrects:2549.0,epochsize:5472
# train Loss: 1.897154 Acc: 0.465826
# epoch_loss:1.8344363204077327
# epoch_corrects:2400.0,epochsize:4988
# valid Loss: 1.834436 Acc: 0.481155
# Epoch 131/3000
# epoch_loss:1.8967048563280997
# epoch_corrects:2549.0,epochsize:5472
# train Loss: 1.896705 Acc: 0.465826
# epoch_loss:1.834054993024901
# epoch_corrects:2409.0,epochsize:4988
# valid Loss: 1.834055 Acc: 0.482959
# Epoch 132/3000
# epoch_loss:1.8964685283122007
# epoch_corrects:2537.0,epochsize:5472
# train Loss: 1.896469 Acc: 0.463633
# epoch_loss:1.8336618514948113
# epoch_corrects:2411.0,epochsize:4988
# valid Loss: 1.833662 Acc: 0.483360
# Epoch 133/3000
# epoch_loss:1.896392248963055
# epoch_corrects:2561.0,epochsize:5472
# train Loss: 1.896392 Acc: 0.468019
# epoch_loss:1.8332347344090294
# epoch_corrects:2415.0,epochsize:4988
# valid Loss: 1.833235 Acc: 0.484162
# Epoch 134/3000
# epoch_loss:1.896680096610945
# epoch_corrects:2552.0,epochsize:5472
# train Loss: 1.896680 Acc: 0.466374
# epoch_loss:1.8328352580093439
# epoch_corrects:2416.0,epochsize:4988
# valid Loss: 1.832835 Acc: 0.484362
# Epoch 135/3000
# epoch_loss:1.896422769111848
# epoch_corrects:2554.0,epochsize:5472
# train Loss: 1.896423 Acc: 0.466740
# epoch_loss:1.8324667283699048
# epoch_corrects:2420.0,epochsize:4988
# valid Loss: 1.832467 Acc: 0.485164
# Epoch 136/3000
# epoch_loss:1.896184285089635
# epoch_corrects:2590.0,epochsize:5472
# train Loss: 1.896184 Acc: 0.473319
# epoch_loss:1.8320710301016843
# epoch_corrects:2422.0,epochsize:4988
# valid Loss: 1.832071 Acc: 0.485565
# Epoch 137/3000
# epoch_loss:1.896528020109001
# epoch_corrects:2561.0,epochsize:5472
# train Loss: 1.896528 Acc: 0.468019
# epoch_loss:1.8316732714342516
# epoch_corrects:2425.0,epochsize:4988
# valid Loss: 1.831673 Acc: 0.486167
# Epoch 138/3000
# epoch_loss:1.8962423990954433
# epoch_corrects:2574.0,epochsize:5472
# train Loss: 1.896242 Acc: 0.470395
# epoch_loss:1.831303408983333
# epoch_corrects:2426.0,epochsize:4988
# valid Loss: 1.831303 Acc: 0.486367
# Epoch 139/3000
# epoch_loss:1.896401637304596
# epoch_corrects:2543.0,epochsize:5472
# train Loss: 1.896402 Acc: 0.464730
# epoch_loss:1.8309336864384251
# epoch_corrects:2429.0,epochsize:4988
# valid Loss: 1.830934 Acc: 0.486969
# Epoch 140/3000
# epoch_loss:1.8963124321130982
# epoch_corrects:2572.0,epochsize:5472
# train Loss: 1.896312 Acc: 0.470029
# epoch_loss:1.8305628451712148
# epoch_corrects:2433.0,epochsize:4988
# valid Loss: 1.830563 Acc: 0.487771
# Epoch 141/3000
# epoch_loss:1.896224914107755
# epoch_corrects:2574.0,epochsize:5472
# train Loss: 1.896225 Acc: 0.470395
# epoch_loss:1.8302007713792032
# epoch_corrects:2440.0,epochsize:4988
# valid Loss: 1.830201 Acc: 0.489174
# Epoch 142/3000
# epoch_loss:1.895982408558416
# epoch_corrects:2565.0,epochsize:5472
# train Loss: 1.895982 Acc: 0.468750
# epoch_loss:1.829840478891359
# epoch_corrects:2441.0,epochsize:4988
# valid Loss: 1.829840 Acc: 0.489374
# Epoch 143/3000
# epoch_loss:1.8965514166749011
# epoch_corrects:2563.0,epochsize:5472
# train Loss: 1.896551 Acc: 0.468385
# epoch_loss:1.8294977093565052
# epoch_corrects:2443.0,epochsize:4988
# valid Loss: 1.829498 Acc: 0.489775
# Epoch 144/3000
# epoch_loss:1.896071226537576
# epoch_corrects:2578.0,epochsize:5472
# train Loss: 1.896071 Acc: 0.471126
# epoch_loss:1.82914704796593
# epoch_corrects:2444.0,epochsize:4988
# valid Loss: 1.829147 Acc: 0.489976
# Epoch 145/3000
# epoch_loss:1.8961569274726666
# epoch_corrects:2591.0,epochsize:5472
# train Loss: 1.896157 Acc: 0.473501
# epoch_loss:1.8287962886841658
# epoch_corrects:2444.0,epochsize:4988
# valid Loss: 1.828796 Acc: 0.489976
# Epoch 146/3000
# epoch_loss:1.895789324409432
# epoch_corrects:2575.0,epochsize:5472
# train Loss: 1.895789 Acc: 0.470577
# epoch_loss:1.8284379360956866
# epoch_corrects:2448.0,epochsize:4988
# valid Loss: 1.828438 Acc: 0.490778
# Epoch 147/3000
# epoch_loss:1.8962581961998466
# epoch_corrects:2582.0,epochsize:5472
# train Loss: 1.896258 Acc: 0.471857
# epoch_loss:1.8281264817991922
# epoch_corrects:2454.0,epochsize:4988
# valid Loss: 1.828126 Acc: 0.491981
# Epoch 148/3000
# epoch_loss:1.8962254548194812
# epoch_corrects:2575.0,epochsize:5472
# train Loss: 1.896225 Acc: 0.470577
# epoch_loss:1.8278255147654816
# epoch_corrects:2455.0,epochsize:4988
# valid Loss: 1.827826 Acc: 0.492181
# Epoch 149/3000
# epoch_loss:1.8958900710731221
# epoch_corrects:2572.0,epochsize:5472
# train Loss: 1.895890 Acc: 0.470029
# epoch_loss:1.8274745007180746
# epoch_corrects:2456.0,epochsize:4988
# valid Loss: 1.827475 Acc: 0.492382
# Epoch 150/3000
# epoch_loss:1.895732684747169
# epoch_corrects:2586.0,epochsize:5472
# train Loss: 1.895733 Acc: 0.472588
# epoch_loss:1.827124394076102
# epoch_corrects:2462.0,epochsize:4988
# valid Loss: 1.827124 Acc: 0.493585
# Epoch 151/3000
# epoch_loss:1.8955855215327782
# epoch_corrects:2566.0,epochsize:5472
# train Loss: 1.895586 Acc: 0.468933
# epoch_loss:1.8267608349956124
# epoch_corrects:2472.0,epochsize:4988
# valid Loss: 1.826761 Acc: 0.495589
# Epoch 152/3000
# epoch_loss:1.8959261263497391
# epoch_corrects:2575.0,epochsize:5472
# train Loss: 1.895926 Acc: 0.470577
# epoch_loss:1.826459522905021
# epoch_corrects:2485.0,epochsize:4988
# valid Loss: 1.826460 Acc: 0.498196
# Epoch 153/3000
# epoch_loss:1.895664004249531
# epoch_corrects:2584.0,epochsize:5472
# train Loss: 1.895664 Acc: 0.472222
# epoch_loss:1.8261128662104786
# epoch_corrects:2488.0,epochsize:4988
# valid Loss: 1.826113 Acc: 0.498797
# Epoch 154/3000
# epoch_loss:1.895294802230701
# epoch_corrects:2582.0,epochsize:5472
# train Loss: 1.895295 Acc: 0.471857
# epoch_loss:1.8258012652205962
# epoch_corrects:2487.0,epochsize:4988
# valid Loss: 1.825801 Acc: 0.498597
# Epoch 155/3000
# epoch_loss:1.8951869139894408
# epoch_corrects:2580.0,epochsize:5472
# train Loss: 1.895187 Acc: 0.471491
# epoch_loss:1.8254605384473335
# epoch_corrects:2491.0,epochsize:4988
# valid Loss: 1.825461 Acc: 0.499399
# Epoch 156/3000
# epoch_loss:1.8956987608594504
# epoch_corrects:2589.0,epochsize:5472
# train Loss: 1.895699 Acc: 0.473136
# epoch_loss:1.825139903219203
# epoch_corrects:2495.0,epochsize:4988
# valid Loss: 1.825140 Acc: 0.500200
# Epoch 157/3000
# epoch_loss:1.8956785662132396
# epoch_corrects:2546.0,epochsize:5472
# train Loss: 1.895679 Acc: 0.465278
# epoch_loss:1.8248162616130919
# epoch_corrects:2497.0,epochsize:4988
# valid Loss: 1.824816 Acc: 0.500601
# Epoch 158/3000
# epoch_loss:1.8955427448739086
# epoch_corrects:2563.0,epochsize:5472
# train Loss: 1.895543 Acc: 0.468385
# epoch_loss:1.8244970475279434
# epoch_corrects:2505.0,epochsize:4988
# valid Loss: 1.824497 Acc: 0.502205
# Epoch 159/3000
# epoch_loss:1.8955482293290702
# epoch_corrects:2592.0,epochsize:5472
# train Loss: 1.895548 Acc: 0.473684
# epoch_loss:1.824167625848637
# epoch_corrects:2508.0,epochsize:4988
# valid Loss: 1.824168 Acc: 0.502807
# Epoch 160/3000
# epoch_loss:1.8951582085145147
# epoch_corrects:2588.0,epochsize:5472
# train Loss: 1.895158 Acc: 0.472953
# epoch_loss:1.8238410881355274
# epoch_corrects:2518.0,epochsize:4988
# valid Loss: 1.823841 Acc: 0.504812
# Epoch 161/3000
# epoch_loss:1.895197083857673
# epoch_corrects:2558.0,epochsize:5472
# train Loss: 1.895197 Acc: 0.467471
# epoch_loss:1.8234884558244047
# epoch_corrects:2527.0,epochsize:4988
# valid Loss: 1.823488 Acc: 0.506616
# Epoch 162/3000
# epoch_loss:1.8953647982568769
# epoch_corrects:2576.0,epochsize:5472
# train Loss: 1.895365 Acc: 0.470760
# epoch_loss:1.823188406568388
# epoch_corrects:2532.0,epochsize:4988
# valid Loss: 1.823188 Acc: 0.507618
# Epoch 163/3000
# epoch_loss:1.8951895013451576
# epoch_corrects:2580.0,epochsize:5472
# train Loss: 1.895190 Acc: 0.471491
# epoch_loss:1.8228251853750148
# epoch_corrects:2544.0,epochsize:4988
# valid Loss: 1.822825 Acc: 0.510024
# Epoch 164/3000
# epoch_loss:1.8953952899540376
# epoch_corrects:2575.0,epochsize:5472
# train Loss: 1.895395 Acc: 0.470577
# epoch_loss:1.822536386913936
# epoch_corrects:2550.0,epochsize:4988
# valid Loss: 1.822536 Acc: 0.511227
# Epoch 165/3000
# epoch_loss:1.8951628252166755
# epoch_corrects:2593.0,epochsize:5472
# train Loss: 1.895163 Acc: 0.473867
# epoch_loss:1.822228432562032
# epoch_corrects:2553.0,epochsize:4988
# valid Loss: 1.822228 Acc: 0.511828
# Epoch 166/3000
# epoch_loss:1.8950846442266513
# epoch_corrects:2591.0,epochsize:5472
# train Loss: 1.895085 Acc: 0.473501
# epoch_loss:1.8219325689669121
# epoch_corrects:2561.0,epochsize:4988
# valid Loss: 1.821933 Acc: 0.513432
# Epoch 167/3000
# epoch_loss:1.8948425737302206
# epoch_corrects:2613.0,epochsize:5472
# train Loss: 1.894843 Acc: 0.477522
# epoch_loss:1.8216308648813793
# epoch_corrects:2565.0,epochsize:4988
# valid Loss: 1.821631 Acc: 0.514234
# Epoch 168/3000
# epoch_loss:1.895031196114264
# epoch_corrects:2600.0,epochsize:5472
# train Loss: 1.895031 Acc: 0.475146
# epoch_loss:1.8213243105933488
# epoch_corrects:2564.0,epochsize:4988
# valid Loss: 1.821324 Acc: 0.514034
# Epoch 169/3000
# epoch_loss:1.8946955177431914
# epoch_corrects:2583.0,epochsize:5472
# train Loss: 1.894696 Acc: 0.472039
# epoch_loss:1.821031376229541
# epoch_corrects:2572.0,epochsize:4988
# valid Loss: 1.821031 Acc: 0.515638
# Epoch 170/3000
# epoch_loss:1.8947077542543411
# epoch_corrects:2620.0,epochsize:5472
# train Loss: 1.894708 Acc: 0.478801
# epoch_loss:1.8207181009561804
# epoch_corrects:2579.0,epochsize:4988
# valid Loss: 1.820718 Acc: 0.517041
# Epoch 171/3000
# epoch_loss:1.8946692504380878
# epoch_corrects:2589.0,epochsize:5472
# train Loss: 1.894669 Acc: 0.473136
# epoch_loss:1.8204297163339263
# epoch_corrects:2581.0,epochsize:4988
# valid Loss: 1.820430 Acc: 0.517442
# Epoch 172/3000
# epoch_loss:1.8944889732271608
# epoch_corrects:2649.0,epochsize:5472
# train Loss: 1.894489 Acc: 0.484101
# epoch_loss:1.8201335100240486
# epoch_corrects:2587.0,epochsize:4988
# valid Loss: 1.820134 Acc: 0.518645
# Epoch 173/3000
# epoch_loss:1.895034702157068
# epoch_corrects:2592.0,epochsize:5472
# train Loss: 1.895035 Acc: 0.473684
# epoch_loss:1.8198360327538625
# epoch_corrects:2593.0,epochsize:4988
# valid Loss: 1.819836 Acc: 0.519848
# Epoch 174/3000
# epoch_loss:1.8946603132270232
# epoch_corrects:2607.0,epochsize:5472
# train Loss: 1.894660 Acc: 0.476425
# epoch_loss:1.8195530565241957
# epoch_corrects:2597.0,epochsize:4988
# valid Loss: 1.819553 Acc: 0.520650
# Epoch 175/3000
# epoch_loss:1.894752056452266
# epoch_corrects:2582.0,epochsize:5472
# train Loss: 1.894752 Acc: 0.471857
# epoch_loss:1.8192650735043676
# epoch_corrects:2599.0,epochsize:4988
# valid Loss: 1.819265 Acc: 0.521051
# Epoch 176/3000
# epoch_loss:1.894503080705453
# epoch_corrects:2589.0,epochsize:5472
# train Loss: 1.894503 Acc: 0.473136
# epoch_loss:1.8189905411067158
# epoch_corrects:2600.0,epochsize:4988
# valid Loss: 1.818991 Acc: 0.521251
# Epoch 177/3000
# epoch_loss:1.8945476907299974
# epoch_corrects:2605.0,epochsize:5472
# train Loss: 1.894548 Acc: 0.476060
# epoch_loss:1.8187065034172682
# epoch_corrects:2605.0,epochsize:4988
# valid Loss: 1.818707 Acc: 0.522253
# Epoch 178/3000
# epoch_loss:1.8947296733396095
# epoch_corrects:2599.0,epochsize:5472
# train Loss: 1.894730 Acc: 0.474963
# epoch_loss:1.8184223008710285
# epoch_corrects:2608.0,epochsize:4988
# valid Loss: 1.818422 Acc: 0.522855
# Epoch 179/3000
# epoch_loss:1.8942751612143907
# epoch_corrects:2629.0,epochsize:5472
# train Loss: 1.894275 Acc: 0.480446
# epoch_loss:1.8181325919454157
# epoch_corrects:2613.0,epochsize:4988
# valid Loss: 1.818133 Acc: 0.523857
# Epoch 180/3000
# epoch_loss:1.8944286327613027
# epoch_corrects:2592.0,epochsize:5472
# train Loss: 1.894429 Acc: 0.473684
# epoch_loss:1.8178485523918293
# epoch_corrects:2614.0,epochsize:4988
# valid Loss: 1.817849 Acc: 0.524058
# Epoch 181/3000
# epoch_loss:1.895120190510973
# epoch_corrects:2591.0,epochsize:5472
# train Loss: 1.895120 Acc: 0.473501
# epoch_loss:1.817575559342682
# epoch_corrects:2620.0,epochsize:4988
# valid Loss: 1.817576 Acc: 0.525261
# Epoch 182/3000
# epoch_loss:1.8941702213552263
# epoch_corrects:2646.0,epochsize:5472
# train Loss: 1.894170 Acc: 0.483553
# epoch_loss:1.8173112399404108
# epoch_corrects:2621.0,epochsize:4988
# valid Loss: 1.817311 Acc: 0.525461
# Epoch 183/3000
# epoch_loss:1.89430186409525
# epoch_corrects:2588.0,epochsize:5472
# train Loss: 1.894302 Acc: 0.472953
# epoch_loss:1.8170371233891178
# epoch_corrects:2626.0,epochsize:4988
# valid Loss: 1.817037 Acc: 0.526464
# Epoch 184/3000
# epoch_loss:1.894559146934434
# epoch_corrects:2619.0,epochsize:5472
# train Loss: 1.894559 Acc: 0.478618
# epoch_loss:1.8167848638180455
# epoch_corrects:2633.0,epochsize:4988
# valid Loss: 1.816785 Acc: 0.527867
# Epoch 185/3000
# epoch_loss:1.8945014439305368
# epoch_corrects:2581.0,epochsize:5472
# train Loss: 1.894501 Acc: 0.471674
# epoch_loss:1.8165120071378247
# epoch_corrects:2637.0,epochsize:4988
# valid Loss: 1.816512 Acc: 0.528669
# Epoch 186/3000
# epoch_loss:1.8944900702053344
# epoch_corrects:2598.0,epochsize:5472
# train Loss: 1.894490 Acc: 0.474781
# epoch_loss:1.8162404029677177
# epoch_corrects:2638.0,epochsize:4988
# valid Loss: 1.816240 Acc: 0.528869
# Epoch 187/3000
# epoch_loss:1.8940997663558574
# epoch_corrects:2643.0,epochsize:5472
# train Loss: 1.894100 Acc: 0.483004
# epoch_loss:1.815973483474138
# epoch_corrects:2649.0,epochsize:4988
# valid Loss: 1.815973 Acc: 0.531075
# Epoch 188/3000
# epoch_loss:1.8935378376416296
# epoch_corrects:2647.0,epochsize:5472
# train Loss: 1.893538 Acc: 0.483735
# epoch_loss:1.8156982689928607
# epoch_corrects:2651.0,epochsize:4988
# valid Loss: 1.815698 Acc: 0.531476
# Epoch 189/3000
# epoch_loss:1.8941223456671363
# epoch_corrects:2614.0,epochsize:5472
# train Loss: 1.894122 Acc: 0.477705
# epoch_loss:1.815446698388388
# epoch_corrects:2650.0,epochsize:4988
# valid Loss: 1.815447 Acc: 0.531275
# Epoch 190/3000
# epoch_loss:1.8941203473865638
# epoch_corrects:2627.0,epochsize:5472
# train Loss: 1.894120 Acc: 0.480080
# epoch_loss:1.8152086153542795
# epoch_corrects:2657.0,epochsize:4988
# valid Loss: 1.815209 Acc: 0.532678
# Epoch 191/3000
# epoch_loss:1.8942309038506613
# epoch_corrects:2618.0,epochsize:5472
# train Loss: 1.894231 Acc: 0.478436
# epoch_loss:1.8149419844198342
# epoch_corrects:2660.0,epochsize:4988
# valid Loss: 1.814942 Acc: 0.533280
# Epoch 192/3000
# epoch_loss:1.8938751433763588
# epoch_corrects:2613.0,epochsize:5472
# train Loss: 1.893875 Acc: 0.477522
# epoch_loss:1.8147015604097172
# epoch_corrects:2658.0,epochsize:4988
# valid Loss: 1.814702 Acc: 0.532879
# Epoch 193/3000
# epoch_loss:1.894069522924242
# epoch_corrects:2610.0,epochsize:5472
# train Loss: 1.894070 Acc: 0.476974
# epoch_loss:1.8144810841192507
# epoch_corrects:2663.0,epochsize:4988
# valid Loss: 1.814481 Acc: 0.533881
# Epoch 194/3000
# epoch_loss:1.8937740830911531
# epoch_corrects:2636.0,epochsize:5472
# train Loss: 1.893774 Acc: 0.481725
# epoch_loss:1.8142294102223664
# epoch_corrects:2668.0,epochsize:4988
# valid Loss: 1.814229 Acc: 0.534884
# Epoch 195/3000
# epoch_loss:1.8938129473237963
# epoch_corrects:2638.0,epochsize:5472
# train Loss: 1.893813 Acc: 0.482091
# epoch_loss:1.8139947530930771
# epoch_corrects:2672.0,epochsize:4988
# valid Loss: 1.813995 Acc: 0.535686
# Epoch 196/3000
# epoch_loss:1.8939632289765174
# epoch_corrects:2632.0,epochsize:5472
# train Loss: 1.893963 Acc: 0.480994
# epoch_loss:1.8137591048155006
# epoch_corrects:2675.0,epochsize:4988
# valid Loss: 1.813759 Acc: 0.536287
# Epoch 197/3000
# epoch_loss:1.8941926969683658
# epoch_corrects:2632.0,epochsize:5472
# train Loss: 1.894193 Acc: 0.480994
# epoch_loss:1.8135086638313729
# epoch_corrects:2678.0,epochsize:4988
# valid Loss: 1.813509 Acc: 0.536889
# Epoch 198/3000
# epoch_loss:1.8940171085254491
# epoch_corrects:2615.0,epochsize:5472
# train Loss: 1.894017 Acc: 0.477887
# epoch_loss:1.8132636309530417
# epoch_corrects:2680.0,epochsize:4988
# valid Loss: 1.813264 Acc: 0.537289
# Epoch 199/3000
# epoch_loss:1.893989906150695
# epoch_corrects:2621.0,epochsize:5472
# train Loss: 1.893990 Acc: 0.478984
# epoch_loss:1.8130204143195316
# epoch_corrects:2681.0,epochsize:4988
# valid Loss: 1.813020 Acc: 0.537490
# Epoch 200/3000
# epoch_loss:1.8939348065800834
# epoch_corrects:2617.0,epochsize:5472
# train Loss: 1.893935 Acc: 0.478253
# epoch_loss:1.8128052569429876
# epoch_corrects:2688.0,epochsize:4988
# valid Loss: 1.812805 Acc: 0.538893
# Epoch 201/3000
# epoch_loss:1.8939972687621562
# epoch_corrects:2632.0,epochsize:5472
# train Loss: 1.893997 Acc: 0.480994
# epoch_loss:1.8125614947381743
# epoch_corrects:2690.0,epochsize:4988
# valid Loss: 1.812561 Acc: 0.539294
# Epoch 202/3000
# epoch_loss:1.8938204791200788
# epoch_corrects:2633.0,epochsize:5472
# train Loss: 1.893820 Acc: 0.481177
# epoch_loss:1.8123243038140016
# epoch_corrects:2692.0,epochsize:4988
# valid Loss: 1.812324 Acc: 0.539695
# Epoch 203/3000
# epoch_loss:1.8933968067343472
# epoch_corrects:2625.0,epochsize:5472
# train Loss: 1.893397 Acc: 0.479715
# epoch_loss:1.812108688146091
# epoch_corrects:2695.0,epochsize:4988
# valid Loss: 1.812109 Acc: 0.540297
# Epoch 204/3000
# epoch_loss:1.8936142672659362
# epoch_corrects:2633.0,epochsize:5472
# train Loss: 1.893614 Acc: 0.481177
# epoch_loss:1.8118537719859633
# epoch_corrects:2699.0,epochsize:4988
# valid Loss: 1.811854 Acc: 0.541099
# Epoch 205/3000
# epoch_loss:1.8933708991485032
# epoch_corrects:2623.0,epochsize:5472
# train Loss: 1.893371 Acc: 0.479349
# epoch_loss:1.8115892656918229
# epoch_corrects:2695.0,epochsize:4988
# valid Loss: 1.811589 Acc: 0.540297
# Epoch 206/3000
# epoch_loss:1.8941588881942961
# epoch_corrects:2638.0,epochsize:5472
# train Loss: 1.894159 Acc: 0.482091
# epoch_loss:1.8113341755454027
# epoch_corrects:2700.0,epochsize:4988
# valid Loss: 1.811334 Acc: 0.541299
# Epoch 207/3000
# epoch_loss:1.8941244197606344
# epoch_corrects:2641.0,epochsize:5472
# train Loss: 1.894124 Acc: 0.482639
# epoch_loss:1.8111353043374196
# epoch_corrects:2703.0,epochsize:4988
# valid Loss: 1.811135 Acc: 0.541901
# Epoch 208/3000
# epoch_loss:1.8934629869739912
# epoch_corrects:2633.0,epochsize:5472
# train Loss: 1.893463 Acc: 0.481177
# epoch_loss:1.810923452174654
# epoch_corrects:2703.0,epochsize:4988
# valid Loss: 1.810923 Acc: 0.541901
# Epoch 209/3000
# epoch_loss:1.8937777377970038
# epoch_corrects:2646.0,epochsize:5472
# train Loss: 1.893778 Acc: 0.483553
# epoch_loss:1.8107061889425888
# epoch_corrects:2707.0,epochsize:4988
# valid Loss: 1.810706 Acc: 0.542702
# Epoch 210/3000
# epoch_loss:1.8931166226839462
# epoch_corrects:2673.0,epochsize:5472
# train Loss: 1.893117 Acc: 0.488487
# epoch_loss:1.8105030984714114
# epoch_corrects:2712.0,epochsize:4988
# valid Loss: 1.810503 Acc: 0.543705
# Epoch 211/3000
# epoch_loss:1.893591872999194
# epoch_corrects:2626.0,epochsize:5472
# train Loss: 1.893592 Acc: 0.479898
# epoch_loss:1.8102806069990494
# epoch_corrects:2716.0,epochsize:4988
# valid Loss: 1.810281 Acc: 0.544507
# Epoch 212/3000
# epoch_loss:1.8934531546475595
# epoch_corrects:2626.0,epochsize:5472
# train Loss: 1.893453 Acc: 0.479898
# epoch_loss:1.810085530890975
# epoch_corrects:2719.0,epochsize:4988
# valid Loss: 1.810086 Acc: 0.545108
# Epoch 213/3000
# epoch_loss:1.8933960489536588
# epoch_corrects:2648.0,epochsize:5472
# train Loss: 1.893396 Acc: 0.483918
# epoch_loss:1.8098617897286067
# epoch_corrects:2720.0,epochsize:4988
# valid Loss: 1.809862 Acc: 0.545309
# Epoch 214/3000
# epoch_loss:1.8931984800780028
# epoch_corrects:2666.0,epochsize:5472
# train Loss: 1.893198 Acc: 0.487208
# epoch_loss:1.8096584464993206
# epoch_corrects:2725.0,epochsize:4988
# valid Loss: 1.809658 Acc: 0.546311
# Epoch 215/3000
# epoch_loss:1.8927804846425502
# epoch_corrects:2656.0,epochsize:5472
# train Loss: 1.892780 Acc: 0.485380
# epoch_loss:1.8094571059765392
# epoch_corrects:2726.0,epochsize:4988
# valid Loss: 1.809457 Acc: 0.546512
# Epoch 216/3000
# epoch_loss:1.8936806183896566
# epoch_corrects:2648.0,epochsize:5472
# train Loss: 1.893681 Acc: 0.483918
# epoch_loss:1.8092439570423118
# epoch_corrects:2728.0,epochsize:4988
# valid Loss: 1.809244 Acc: 0.546913
# Epoch 217/3000
# epoch_loss:1.8935840152509031
# epoch_corrects:2659.0,epochsize:5472
# train Loss: 1.893584 Acc: 0.485928
# epoch_loss:1.8090509298140274
# epoch_corrects:2728.0,epochsize:4988
# valid Loss: 1.809051 Acc: 0.546913
# Epoch 218/3000
# epoch_loss:1.8932165691727085
# epoch_corrects:2644.0,epochsize:5472
# train Loss: 1.893217 Acc: 0.483187
# epoch_loss:1.8088850789578705
# epoch_corrects:2734.0,epochsize:4988
# valid Loss: 1.808885 Acc: 0.548115
# Epoch 219/3000
# epoch_loss:1.8936213470167584
# epoch_corrects:2646.0,epochsize:5472
# train Loss: 1.893621 Acc: 0.483553
# epoch_loss:1.808695803285123
# epoch_corrects:2735.0,epochsize:4988
# valid Loss: 1.808696 Acc: 0.548316
# Epoch 220/3000
# epoch_loss:1.8928938454441857
# epoch_corrects:2659.0,epochsize:5472
# train Loss: 1.892894 Acc: 0.485928
# epoch_loss:1.8084758034016288
# epoch_corrects:2737.0,epochsize:4988
# valid Loss: 1.808476 Acc: 0.548717
# Epoch 221/3000
# ...
# epoch_corrects:3339.0,epochsize:5472
# train Loss: 1.874333 Acc: 0.610197
# epoch_loss:1.76496930015307
# epoch_corrects:3140.0,epochsize:4988
# valid Loss: 1.764969 Acc: 0.629511
# Epoch 2929/3000
# epoch_loss:1.8741868021108254
# epoch_corrects:3354.0,epochsize:5472
# train Loss: 1.874187 Acc: 0.612939
# epoch_loss:1.7649481304187056
# epoch_corrects:3140.0,epochsize:4988
# valid Loss: 1.764948 Acc: 0.629511
# Epoch 2930/3000
# epoch_loss:1.874615143309211
# epoch_corrects:3310.0,epochsize:5472
# train Loss: 1.874615 Acc: 0.604898
# epoch_loss:1.7649627989449306
# epoch_corrects:3139.0,epochsize:4988
# valid Loss: 1.764963 Acc: 0.629310
# Epoch 2931/3000
# epoch_loss:1.87394120060561
# epoch_corrects:3354.0,epochsize:5472
# train Loss: 1.873941 Acc: 0.612939
# epoch_loss:1.7649478050069802
# epoch_corrects:3139.0,epochsize:4988
# valid Loss: 1.764948 Acc: 0.629310
# Epoch 2932/3000
# epoch_loss:1.8746297958562945
# epoch_corrects:3328.0,epochsize:5472
# train Loss: 1.874630 Acc: 0.608187
# epoch_loss:1.7649444048177174
# epoch_corrects:3138.0,epochsize:4988
# valid Loss: 1.764944 Acc: 0.629110
# Epoch 2933/3000
# epoch_loss:1.873987322270173
# epoch_corrects:3335.0,epochsize:5472
# train Loss: 1.873987 Acc: 0.609466
# epoch_loss:1.764949507921719
# epoch_corrects:3138.0,epochsize:4988
# valid Loss: 1.764950 Acc: 0.629110
# Epoch 2934/3000
# epoch_loss:1.8742724816091576
# epoch_corrects:3343.0,epochsize:5472
# train Loss: 1.874272 Acc: 0.610928
# epoch_loss:1.7649748462051416
# epoch_corrects:3138.0,epochsize:4988
# valid Loss: 1.764975 Acc: 0.629110
# Epoch 2935/3000
# epoch_loss:1.8740851837292052
# epoch_corrects:3321.0,epochsize:5472
# train Loss: 1.874085 Acc: 0.606908
# epoch_loss:1.7649594017191705
# epoch_corrects:3139.0,epochsize:4988
# valid Loss: 1.764959 Acc: 0.629310
# Epoch 2936/3000
# epoch_loss:1.874179161867203
# epoch_corrects:3328.0,epochsize:5472
# train Loss: 1.874179 Acc: 0.608187
# epoch_loss:1.764989732262031
# epoch_corrects:3141.0,epochsize:4988
# valid Loss: 1.764990 Acc: 0.629711
# Epoch 2937/3000
# epoch_loss:1.874371223979526
# epoch_corrects:3345.0,epochsize:5472
# train Loss: 1.874371 Acc: 0.611294
# epoch_loss:1.7649901316179308
# epoch_corrects:3141.0,epochsize:4988
# valid Loss: 1.764990 Acc: 0.629711
# Epoch 2938/3000
# epoch_loss:1.8740723184064816
# epoch_corrects:3334.0,epochsize:5472
# train Loss: 1.874072 Acc: 0.609284
# epoch_loss:1.7649886356226043
# epoch_corrects:3141.0,epochsize:4988
# valid Loss: 1.764989 Acc: 0.629711
# Epoch 2939/3000
# epoch_loss:1.8742384193846358
# epoch_corrects:3325.0,epochsize:5472
# train Loss: 1.874238 Acc: 0.607639
# epoch_loss:1.7650056539197492
# epoch_corrects:3142.0,epochsize:4988
# valid Loss: 1.765006 Acc: 0.629912
# Epoch 2940/3000
# epoch_loss:1.8736752885562635
# epoch_corrects:3339.0,epochsize:5472
# train Loss: 1.873675 Acc: 0.610197
# epoch_loss:1.764955176720164
# epoch_corrects:3139.0,epochsize:4988
# valid Loss: 1.764955 Acc: 0.629310
# Epoch 2941/3000
# epoch_loss:1.8739233704076872
# epoch_corrects:3347.0,epochsize:5472
# train Loss: 1.873923 Acc: 0.611659
# epoch_loss:1.7649615113985664
# epoch_corrects:3139.0,epochsize:4988
# valid Loss: 1.764962 Acc: 0.629310
# Epoch 2942/3000
# epoch_loss:1.8743310035669316
# epoch_corrects:3343.0,epochsize:5472
# train Loss: 1.874331 Acc: 0.610928
# epoch_loss:1.7650207469438493
# epoch_corrects:3140.0,epochsize:4988
# valid Loss: 1.765021 Acc: 0.629511
# Epoch 2943/3000
# epoch_loss:1.8743057223527055
# epoch_corrects:3375.0,epochsize:5472
# train Loss: 1.874306 Acc: 0.616776
# epoch_loss:1.7650405286117468
# epoch_corrects:3139.0,epochsize:4988
# valid Loss: 1.765041 Acc: 0.629310
# Epoch 2944/3000
# epoch_loss:1.8739368774824672
# epoch_corrects:3332.0,epochsize:5472
# train Loss: 1.873937 Acc: 0.608918
# epoch_loss:1.7650718196640993
# epoch_corrects:3140.0,epochsize:4988
# valid Loss: 1.765072 Acc: 0.629511
# Epoch 2945/3000
# epoch_loss:1.874300986964103
# epoch_corrects:3339.0,epochsize:5472
# train Loss: 1.874301 Acc: 0.610197
# epoch_loss:1.765073165094365
# epoch_corrects:3139.0,epochsize:4988
# valid Loss: 1.765073 Acc: 0.629310
# Epoch 2946/3000
# epoch_loss:1.8730592422666605
# epoch_corrects:3374.0,epochsize:5472
# train Loss: 1.873059 Acc: 0.616594
# epoch_loss:1.7650977272268478
# epoch_corrects:3138.0,epochsize:4988
# valid Loss: 1.765098 Acc: 0.629110
# Epoch 2947/3000
# epoch_loss:1.8743720000598862
# epoch_corrects:3354.0,epochsize:5472
# train Loss: 1.874372 Acc: 0.612939
# epoch_loss:1.7650934000347935
# epoch_corrects:3139.0,epochsize:4988
# valid Loss: 1.765093 Acc: 0.629310
# Epoch 2948/3000
# epoch_loss:1.873636074407756
# epoch_corrects:3354.0,epochsize:5472
# train Loss: 1.873636 Acc: 0.612939
# epoch_loss:1.765056765882512
# epoch_corrects:3139.0,epochsize:4988
# valid Loss: 1.765057 Acc: 0.629310
# Epoch 2949/3000
# epoch_loss:1.8742326636586273
# epoch_corrects:3360.0,epochsize:5472
# train Loss: 1.874233 Acc: 0.614035
# epoch_loss:1.7650675204819264
# epoch_corrects:3138.0,epochsize:4988
# valid Loss: 1.765068 Acc: 0.629110
# Epoch 2950/3000
# epoch_loss:1.8742134454741812
# epoch_corrects:3343.0,epochsize:5472
# train Loss: 1.874213 Acc: 0.610928
# epoch_loss:1.7650644373874618
# epoch_corrects:3138.0,epochsize:4988
# valid Loss: 1.765064 Acc: 0.629110
# Epoch 2951/3000
# epoch_loss:1.874346637107127
# epoch_corrects:3359.0,epochsize:5472
# train Loss: 1.874347 Acc: 0.613852
# epoch_loss:1.7650365690374337
# epoch_corrects:3139.0,epochsize:4988
# valid Loss: 1.765037 Acc: 0.629310
# Epoch 2952/3000
# epoch_loss:1.874362549804456
# epoch_corrects:3342.0,epochsize:5472
# train Loss: 1.874363 Acc: 0.610746
# epoch_loss:1.765014444433792
# epoch_corrects:3137.0,epochsize:4988
# valid Loss: 1.765014 Acc: 0.628909
# Epoch 2953/3000
# epoch_loss:1.874866019956201
# epoch_corrects:3333.0,epochsize:5472
# train Loss: 1.874866 Acc: 0.609101
# epoch_loss:1.7650531475890037
# epoch_corrects:3137.0,epochsize:4988
# valid Loss: 1.765053 Acc: 0.628909
# Epoch 2954/3000
# epoch_loss:1.8741788433222046
# epoch_corrects:3338.0,epochsize:5472
# train Loss: 1.874179 Acc: 0.610015
# epoch_loss:1.7650587020058008
# epoch_corrects:3137.0,epochsize:4988
# valid Loss: 1.765059 Acc: 0.628909
# Epoch 2955/3000
# epoch_loss:1.8740651641062827
# epoch_corrects:3338.0,epochsize:5472
# train Loss: 1.874065 Acc: 0.610015
# epoch_loss:1.7650393928254042
# epoch_corrects:3136.0,epochsize:4988
# valid Loss: 1.765039 Acc: 0.628709
# Epoch 2956/3000
# epoch_loss:1.8744655914648234
# epoch_corrects:3358.0,epochsize:5472
# train Loss: 1.874466 Acc: 0.613670
# epoch_loss:1.7650317169229985
# epoch_corrects:3135.0,epochsize:4988
# valid Loss: 1.765032 Acc: 0.628508
# Epoch 2957/3000
# epoch_loss:1.8743418028131562
# epoch_corrects:3360.0,epochsize:5472
# train Loss: 1.874342 Acc: 0.614035
# epoch_loss:1.7650187007407714
# epoch_corrects:3136.0,epochsize:4988
# valid Loss: 1.765019 Acc: 0.628709
# Epoch 2958/3000
# epoch_loss:1.8748992763851817
# epoch_corrects:3310.0,epochsize:5472
# train Loss: 1.874899 Acc: 0.604898
# epoch_loss:1.7649831225514507
# epoch_corrects:3136.0,epochsize:4988
# valid Loss: 1.764983 Acc: 0.628709
# Epoch 2959/3000
# epoch_loss:1.8743415291023533
# epoch_corrects:3343.0,epochsize:5472
# train Loss: 1.874342 Acc: 0.610928
# epoch_loss:1.7649788242296496
# epoch_corrects:3137.0,epochsize:4988
# valid Loss: 1.764979 Acc: 0.628909
# Epoch 2960/3000
# epoch_loss:1.8738920049447763
# epoch_corrects:3343.0,epochsize:5472
# train Loss: 1.873892 Acc: 0.610928
# epoch_loss:1.764989633606067
# epoch_corrects:3137.0,epochsize:4988
# valid Loss: 1.764990 Acc: 0.628909
# Epoch 2961/3000
# epoch_loss:1.8739293434640818
# epoch_corrects:3341.0,epochsize:5472
# train Loss: 1.873929 Acc: 0.610563
# epoch_loss:1.7649746585484973
# epoch_corrects:3138.0,epochsize:4988
# valid Loss: 1.764975 Acc: 0.629110
# Epoch 2962/3000
# epoch_loss:1.8741729220277386
# epoch_corrects:3332.0,epochsize:5472
# train Loss: 1.874173 Acc: 0.608918
# epoch_loss:1.7649772361745428
# epoch_corrects:3136.0,epochsize:4988
# valid Loss: 1.764977 Acc: 0.628709
# Epoch 2963/3000
# epoch_loss:1.8737162799514524
# epoch_corrects:3340.0,epochsize:5472
# train Loss: 1.873716 Acc: 0.610380
# epoch_loss:1.7650171808940271
# epoch_corrects:3137.0,epochsize:4988
# valid Loss: 1.765017 Acc: 0.628909
# Epoch 2964/3000
# epoch_loss:1.8741614428180002
# epoch_corrects:3363.0,epochsize:5472
# train Loss: 1.874161 Acc: 0.614583
# epoch_loss:1.7650186834855375
# epoch_corrects:3136.0,epochsize:4988
# valid Loss: 1.765019 Acc: 0.628709
# Epoch 2965/3000
# epoch_loss:1.8742017223559626
# epoch_corrects:3351.0,epochsize:5472
# train Loss: 1.874202 Acc: 0.612390
# epoch_loss:1.7650144116440676
# epoch_corrects:3136.0,epochsize:4988
# valid Loss: 1.765014 Acc: 0.628709
# Epoch 2966/3000
# epoch_loss:1.8740318727772138
# epoch_corrects:3352.0,epochsize:5472
# train Loss: 1.874032 Acc: 0.612573
# epoch_loss:1.7650195791803558
# epoch_corrects:3136.0,epochsize:4988
# valid Loss: 1.765020 Acc: 0.628709
# Epoch 2967/3000
# epoch_loss:1.8743403833250554
# epoch_corrects:3331.0,epochsize:5472
# train Loss: 1.874340 Acc: 0.608735
# epoch_loss:1.7650452808752572
# epoch_corrects:3138.0,epochsize:4988
# valid Loss: 1.765045 Acc: 0.629110
# Epoch 2968/3000
# epoch_loss:1.8738850969494434
# epoch_corrects:3359.0,epochsize:5472
# train Loss: 1.873885 Acc: 0.613852
# epoch_loss:1.7650222300813976
# epoch_corrects:3138.0,epochsize:4988
# valid Loss: 1.765022 Acc: 0.629110
# Epoch 2969/3000
# epoch_loss:1.87427328073839
# epoch_corrects:3346.0,epochsize:5472
# train Loss: 1.874273 Acc: 0.611477
# epoch_loss:1.7650316891521096
# epoch_corrects:3136.0,epochsize:4988
# valid Loss: 1.765032 Acc: 0.628709
# Epoch 2970/3000
# epoch_loss:1.8737390675739936
# epoch_corrects:3325.0,epochsize:5472
# train Loss: 1.873739 Acc: 0.607639
# epoch_loss:1.7649891304797714
# epoch_corrects:3136.0,epochsize:4988
# valid Loss: 1.764989 Acc: 0.628709
# Epoch 2971/3000
# epoch_loss:1.8741509218139258
# epoch_corrects:3352.0,epochsize:5472
# train Loss: 1.874151 Acc: 0.612573
# epoch_loss:1.7649664984001765
# epoch_corrects:3135.0,epochsize:4988
# valid Loss: 1.764966 Acc: 0.628508
# Epoch 2972/3000
# epoch_loss:1.8739560160633417
# epoch_corrects:3340.0,epochsize:5472
# train Loss: 1.873956 Acc: 0.610380
# epoch_loss:1.765005853382606
# epoch_corrects:3136.0,epochsize:4988
# valid Loss: 1.765006 Acc: 0.628709
# Epoch 2973/3000
# epoch_loss:1.8741851533975518
# epoch_corrects:3344.0,epochsize:5472
# train Loss: 1.874185 Acc: 0.611111
# epoch_loss:1.765029395639944
# epoch_corrects:3137.0,epochsize:4988
# valid Loss: 1.765029 Acc: 0.628909
# Epoch 2974/3000
# epoch_loss:1.8741090427539502
# epoch_corrects:3349.0,epochsize:5472
# train Loss: 1.874109 Acc: 0.612025
# epoch_loss:1.7650776894549514
# epoch_corrects:3137.0,epochsize:4988
# valid Loss: 1.765078 Acc: 0.628909
# Epoch 2975/3000
# epoch_loss:1.8742296768907916
# epoch_corrects:3346.0,epochsize:5472
# train Loss: 1.874230 Acc: 0.611477
# epoch_loss:1.7650774480728695
# epoch_corrects:3137.0,epochsize:4988
# valid Loss: 1.765077 Acc: 0.628909
# Epoch 2976/3000
# epoch_loss:1.874379700953849
# epoch_corrects:3324.0,epochsize:5472
# train Loss: 1.874380 Acc: 0.607456
# epoch_loss:1.7650602274449616
# epoch_corrects:3137.0,epochsize:4988
# valid Loss: 1.765060 Acc: 0.628909
# Epoch 2977/3000
# epoch_loss:1.8738169993399179
# epoch_corrects:3352.0,epochsize:5472
# train Loss: 1.873817 Acc: 0.612573
# epoch_loss:1.7650724119822694
# epoch_corrects:3136.0,epochsize:4988
# valid Loss: 1.765072 Acc: 0.628709
# Epoch 2978/3000
# epoch_loss:1.874126944974152
# epoch_corrects:3341.0,epochsize:5472
# train Loss: 1.874127 Acc: 0.610563
# epoch_loss:1.7650894665106258
# epoch_corrects:3138.0,epochsize:4988
# valid Loss: 1.765089 Acc: 0.629110
# Epoch 2979/3000
# epoch_loss:1.8743352076550672
# epoch_corrects:3342.0,epochsize:5472
# train Loss: 1.874335 Acc: 0.610746
# epoch_loss:1.7650637234700806
# epoch_corrects:3135.0,epochsize:4988
# valid Loss: 1.765064 Acc: 0.628508
# Epoch 2980/3000
# epoch_loss:1.8741763989653504
# epoch_corrects:3356.0,epochsize:5472
# train Loss: 1.874176 Acc: 0.613304
# epoch_loss:1.7650392364289347
# epoch_corrects:3135.0,epochsize:4988
# valid Loss: 1.765039 Acc: 0.628508
# Epoch 2981/3000
# epoch_loss:1.8743337241616862
# epoch_corrects:3348.0,epochsize:5472
# train Loss: 1.874334 Acc: 0.611842
# epoch_loss:1.765092741515795
# epoch_corrects:3135.0,epochsize:4988
# valid Loss: 1.765093 Acc: 0.628508
# Epoch 2982/3000
# epoch_loss:1.8739758053718254
# epoch_corrects:3315.0,epochsize:5472
# train Loss: 1.873976 Acc: 0.605811
# epoch_loss:1.7650384935457035
# epoch_corrects:3135.0,epochsize:4988
# valid Loss: 1.765038 Acc: 0.628508
# Epoch 2983/3000
# epoch_loss:1.8742517638973326
# epoch_corrects:3330.0,epochsize:5472
# train Loss: 1.874252 Acc: 0.608553
# epoch_loss:1.7650286656622898
# epoch_corrects:3135.0,epochsize:4988
# valid Loss: 1.765029 Acc: 0.628508
# Epoch 2984/3000
# epoch_loss:1.8742202866321418
# epoch_corrects:3313.0,epochsize:5472
# train Loss: 1.874220 Acc: 0.605446
# epoch_loss:1.7650267052573974
# epoch_corrects:3135.0,epochsize:4988
# valid Loss: 1.765027 Acc: 0.628508
# Epoch 2985/3000
# epoch_loss:1.8735954189858242
# epoch_corrects:3333.0,epochsize:5472
# train Loss: 1.873595 Acc: 0.609101
# epoch_loss:1.7650592584751468
# epoch_corrects:3136.0,epochsize:4988
# valid Loss: 1.765059 Acc: 0.628709
# Epoch 2986/3000
# epoch_loss:1.8740174636157632
# epoch_corrects:3336.0,epochsize:5472
# train Loss: 1.874017 Acc: 0.609649
# epoch_loss:1.7650275875208563
# epoch_corrects:3135.0,epochsize:4988
# valid Loss: 1.765028 Acc: 0.628508
# Epoch 2987/3000
# epoch_loss:1.873901942712173
# epoch_corrects:3362.0,epochsize:5472
# train Loss: 1.873902 Acc: 0.614401
# epoch_loss:1.7650213821850114
# epoch_corrects:3136.0,epochsize:4988
# valid Loss: 1.765021 Acc: 0.628709
# Epoch 2988/3000
# epoch_loss:1.8743090110215528
# epoch_corrects:3348.0,epochsize:5472
# train Loss: 1.874309 Acc: 0.611842
# epoch_loss:1.76504802503104
# epoch_corrects:3136.0,epochsize:4988
# valid Loss: 1.765048 Acc: 0.628709
# Epoch 2989/3000
# epoch_loss:1.8737828513683632
# epoch_corrects:3347.0,epochsize:5472
# train Loss: 1.873783 Acc: 0.611659
# epoch_loss:1.7650537714063403
# epoch_corrects:3135.0,epochsize:4988
# valid Loss: 1.765054 Acc: 0.628508
# Epoch 2990/3000
# epoch_loss:1.8742118895228146
# epoch_corrects:3331.0,epochsize:5472
# train Loss: 1.874212 Acc: 0.608735
# epoch_loss:1.7650707666168428
# epoch_corrects:3134.0,epochsize:4988
# valid Loss: 1.765071 Acc: 0.628308
# Epoch 2991/3000
# epoch_loss:1.8740983484258429
# epoch_corrects:3356.0,epochsize:5472
# train Loss: 1.874098 Acc: 0.613304
# epoch_loss:1.7650524080994614
# epoch_corrects:3134.0,epochsize:4988
# valid Loss: 1.765052 Acc: 0.628308
# Epoch 2992/3000
# epoch_loss:1.873878416741452
# epoch_corrects:3376.0,epochsize:5472
# train Loss: 1.873878 Acc: 0.616959
# epoch_loss:1.7650299787330168
# epoch_corrects:3133.0,epochsize:4988
# valid Loss: 1.765030 Acc: 0.628107
# Epoch 2993/3000
# epoch_loss:1.8743344395481356
# epoch_corrects:3318.0,epochsize:5472
# train Loss: 1.874334 Acc: 0.606360
# epoch_loss:1.7650135286636321
# epoch_corrects:3133.0,epochsize:4988
# valid Loss: 1.765014 Acc: 0.628107
# Epoch 2994/3000
# epoch_loss:1.873945035737509
# epoch_corrects:3320.0,epochsize:5472
# train Loss: 1.873945 Acc: 0.606725
# epoch_loss:1.7650157926363665
# epoch_corrects:3133.0,epochsize:4988
# valid Loss: 1.765016 Acc: 0.628107
# Epoch 2995/3000
# epoch_loss:1.8740795453389485
# epoch_corrects:3331.0,epochsize:5472
# train Loss: 1.874080 Acc: 0.608735
# epoch_loss:1.7650380394128005
# epoch_corrects:3133.0,epochsize:4988
# valid Loss: 1.765038 Acc: 0.628107
# Epoch 2996/3000
# epoch_loss:1.8739520060388666
# epoch_corrects:3362.0,epochsize:5472
# train Loss: 1.873952 Acc: 0.614401
# epoch_loss:1.7650481026556937
# epoch_corrects:3133.0,epochsize:4988
# valid Loss: 1.765048 Acc: 0.628107
# Epoch 2997/3000
# epoch_loss:1.8740724535626279
# epoch_corrects:3379.0,epochsize:5472
# train Loss: 1.874072 Acc: 0.617507
# epoch_loss:1.7650659824239796
# epoch_corrects:3135.0,epochsize:4988
# valid Loss: 1.765066 Acc: 0.628508
# Epoch 2998/3000
# epoch_loss:1.8739936985729033
# epoch_corrects:3337.0,epochsize:5472
# train Loss: 1.873994 Acc: 0.609832
# epoch_loss:1.7651314539917011
# epoch_corrects:3137.0,epochsize:4988
# valid Loss: 1.765131 Acc: 0.628909
# Epoch 2999/3000
# epoch_loss:1.873995515033167
# epoch_corrects:3354.0,epochsize:5472
# train Loss: 1.873996 Acc: 0.612939
# epoch_loss:1.7651339619276327
# epoch_corrects:3137.0,epochsize:4988
# valid Loss: 1.765134 Acc: 0.628909
# Epoch 3000/3000
# epoch_loss:1.8741436500472632
# epoch_corrects:3371.0,epochsize:5472
# train Loss: 1.874144 Acc: 0.616045
# epoch_loss:1.765099765495386
# epoch_corrects:3136.0,epochsize:4988
# valid Loss: 1.765100 Acc: 0.628709

# %%
mymodel.graph()

mymodel.eval(dataloader_dict)
mymodel.getKondou()
# Out:
# 正解数/入力数:3136/4988
# 正解率:0.629
#                         Car  Emergency vehicle  Motor vehicle (road)  Water  \
# Car                   713.0               43.0                   0.0   20.0
# Emergency vehicle      75.0              369.0                   0.0    1.0
# Motor vehicle (road)  282.0               10.0                   0.0    5.0
# Water                  98.0                7.0                   0.0  619.0
# Animal                 95.0               21.0                   0.0   43.0
# Rail transport        125.0               36.0                   0.0   19.0
# Buzzer                 33.0               16.0                   0.0    7.0
#
#                       Animal  Rail transport  Buzzer
# Car                    116.0            93.0    15.0
# Emergency vehicle       61.0            38.0    31.0
# Motor vehicle (road)    20.0            44.0     9.0
# Water                  198.0            50.0    28.0
# Animal                 794.0            13.0    34.0
# Rail transport          62.0           539.0     9.0
# Buzzer                  90.0             5.0   102.0

# %%
mymodel.saveModel(addname="aaa")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-e3798d63dd32> in <module>
# ----> 1 mymodel.saveModel(addname="aaa")
#
# ~\git\MyVggishLearning\mylibs\trainer.py in saveModel(self, addname)
#     253         filename="".join(self.labels)+classstr.replace(".","")+addname+".pth"
#     254         filepath=os.path.join(mydir,"models",filename.replace("\n","").replace(" ","").replace(":","").replace(",","").replace("(","").replace(")",""))
# --> 255         torch.save(self.model.state_dict(), filepath)
#     256
#     257     def loadModel(self,addname=""):
#
# ~\anaconda3\lib\site-packages\torch\serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     367     _check_dill_version(pickle_module)
#     368
# --> 369     with _open_file_like(f, 'wb') as opened_file:
#     370         if _use_new_zipfile_serialization:
#     371             with _open_zipfile_writer(opened_file) as opened_zipfile:
#
# ~\anaconda3\lib\site-packages\torch\serialization.py in _open_file_like(name_or_buffer, mode)
#     228 def _open_file_like(name_or_buffer, mode):
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#     232         if 'w' in mode:
#
# ~\anaconda3\lib\site-packages\torch\serialization.py in __init__(self, name, mode)
#     209 class _open_file(_opener):
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#     213     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\hase\\git\\MyVggishLearning\\mylibs\\models\\CarEmergencyvehicleMotorvehicleroadWaterAnimalRailtransportBuzzerSequential0Linearin_features=128out_features=64bias=True1Dropoutp=075inplace=False2Sigmoid3Linearin_features=64out_features=7bias=True4Softmaxdim=1aaa.pth'

# %%
from pathlib import Path
model=mymodel.model
model.eval()
DIR=Path().resolve()
count=0
os.makedirs(os.path.join(DIR,"acc"),exist_ok=True)
os.makedirs(os.path.join(DIR,"bat"),exist_ok=True)
for inputs,la in dataloader_dict["valid"]:
    outputs=model(inputs)
    print(la,outputs)
    for i in range(len(inputs)):
        fig=plt.figure()
        plt.imshow(inputs[i][0].to('cpu').detach().numpy().copy().T)
        plt.title(labels[int(la[i])])
        isans='acc' if labels[int(la[i])]==labels[int(outputs[i])] else 'bat'
        filepath=os.path.join(DIR,isans,str(count)+".png")
        count+=1
        fig.savefig(filepath)
# Out:
# tensor([1, 1, 3, 0, 1, 2, 3, 0, 1, 4]) tensor([[0.0919, 0.2580, 0.2334, 0.1538, 0.0932, 0.0605, 0.1090],
#         [0.2619, 0.2304, 0.1652, 0.1001, 0.0516, 0.0762, 0.1147],
#         [0.1217, 0.1003, 0.1359, 0.3603, 0.0960, 0.0818, 0.1040],
#         [0.3573, 0.1500, 0.1479, 0.1109, 0.0488, 0.0812, 0.1039],
#         [0.1106, 0.4515, 0.1462, 0.0915, 0.0352, 0.0548, 0.1101],
#         [0.1169, 0.0790, 0.5239, 0.0817, 0.0654, 0.0522, 0.0809],
#         [0.2103, 0.1199, 0.3552, 0.0888, 0.0667, 0.0645, 0.0946],
#         [0.3798, 0.1817, 0.1456, 0.0719, 0.0413, 0.0785, 0.1012],
#         [0.0980, 0.3569, 0.1818, 0.1362, 0.0483, 0.0606, 0.1181],
#         [0.1018, 0.1014, 0.3232, 0.1889, 0.1207, 0.0641, 0.0999]],
#        device='cuda:0', grad_fn=<SoftmaxBackward>)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-1f25877f6ba7> in <module>
#      13         plt.imshow(inputs[i][0].to('cpu').detach().numpy().copy().T)
#      14         plt.title(labels[int(la[i])])
# ---> 15         isans='acc' if labels[int(la[i])]==labels[int(outputs[i])] else 'bat'
#      16         filepath=os.path.join(DIR,isans,str(count)+".png")
#      17         count+=1
#
# ValueError: only one element tensors can be converted to Python scalars

# %%
torch.save(mymodel.model,"mylibs/models/CarSirenSpeechotherMusicAnimal.pth")

# %%
Sequential0Linearin_features=128out_features=64bias=True1Dropoutp=0.5inplace=False2Sigmoid3Linearin_features=64out_features=4bias=True4Softmaxdim=11201500datasotherMusicAnimal.pthCarCivildefensesirenPolicecarsirenFireenginefiretrucksirenMusicAnimalSpeechSequential0Linearin_features=128out_features=64bias=True1Dropoutp=0.5inplace=False2Sigmoid3Linearin_features=64out_features=7bias=True4Softmaxdim=1

# %%
mymodel.model=torch.load("mylibs/models/CarSirenSpeechotherMusicAnimal.pth")

# %%
mymodel.eval(dataloader_dict)
mymodel.getKondou()
# Out:
# 正解数/入力数:1234/2300
# 正解率:0.537
#                                    Car  Civil defense siren  \
# Car                              157.0                 53.0
# Civil defense siren                8.0                175.0
# Police car (siren)                 6.0                 21.0
# Fire engine, fire truck (siren)   14.0                 37.0
# Music                              3.0                 13.0
# Animal                             1.0                 13.0
# Speech                             9.0                  7.0
#
#                                  Police car (siren)  \
# Car                                             1.0
# Civil defense siren                             0.0
# Police car (siren)                              2.0
# Fire engine, fire truck (siren)                 1.0
# Music                                           0.0
# Animal                                          1.0
# Speech                                          0.0
#
#                                  Fire engine, fire truck (siren)  Music  \
# Car                                                         16.0   31.0
# Civil defense siren                                         20.0   33.0
# Police car (siren)                                         112.0   50.0
# Fire engine, fire truck (siren)                            131.0   16.0
# Music                                                        0.0  300.0
# Animal                                                       4.0   34.0
# Speech                                                       1.0   84.0
#
#                                  Animal  Speech
# Car                                83.0    59.0
# Civil defense siren                22.0     7.0
# Police car (siren)                 44.0     5.0
# Fire engine, fire truck (siren)    15.0    21.0
# Music                              37.0    47.0
# Animal                            313.0    34.0
# Speech                            103.0   156.0

# %%
t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2a9af0be2990> in <module>
# ----> 1 trainer.eval(dataloader_dict)
#
# TypeError: eval() missing 1 required positional argument: 'dataloader_dict'

# %%
mymodel.eval(dataloader_dict=dataloader_dict,mode="2")
